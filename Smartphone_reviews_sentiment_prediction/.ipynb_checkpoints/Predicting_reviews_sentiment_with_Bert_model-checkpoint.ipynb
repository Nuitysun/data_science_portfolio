# %% [markdown]
# # Predicting sentiment of smartphone reviews from Ukrainian eCommerce marketplace

# %% [markdown]
# # Step 1: Read dataset and perform basic preprocessing

# %% [markdown]
# ## Read datasets

# %%
#Import necessary libraries
from datetime import datetime
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import dateparser
from datetime import timedelta
from datetime import date
import ktrain
from ktrain import text
import advertools as adv
from langdetect import detect
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score

# %config IPCompleter.greedy=True

#Remove limitations for displaying of tables in pandas
pd.options.display.max_rows = 100
pd.set_option('display.max_colwidth', -1)

# %%
#Get the list of file names from the folder where this script is located 
files_names = glob.glob("./reviews_data/smartphone_reviews_*.csv")

#Iterate through retrieved file names to read files into DataFrames.
#File name contains date when the import was made, we will extract it to replace  "today" and "yesterday" values in review_date column in dataframes with the appropriate values. 
df_names = []
for i, j in enumerate(files_names):
    date = datetime.strptime(j.split('smartphone_reviews_')[1].split('.csv')[0], '%Y-%m-%d')
    date_yesterday = date - timedelta(1)
    data = pd.read_csv(files_names[i])
    data['review_date'] = [i.replace('сьогодні', str(date)) if 'сьогодні' in i else i for i in data['review_date']]
    data['review_date'] = [i.replace('вчора', str(date_yesterday)) if 'вчора' in i else i for i in data['review_date']]
    globals()['data_%s' % i] = data
    print('DataFrame {} was added'.format('data_%s' % i))
    df_names.append(globals()['data_%s' % i])
# Out:
# DataFrame data_0 was added
# DataFrame data_1 was added
# DataFrame data_2 was added

# %%
#Concatenate DataFrames and drop duplicates
data = pd.concat(df_names)
data.drop_duplicates(subset=['review_id'], inplace=True)

# %%
#Look at short info of DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7106 entries, 0 to 5119
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   comment_link                     7106 non-null   object
#  1   product_title                    7106 non-null   object
#  2   product_price                    7106 non-null   float64
#  3   review_id                        7106 non-null   int64
#  4   review_date                      7106 non-null   object
#  5   review_text                      7106 non-null   object
#  6   review_rating                    7106 non-null   int64
#  7   thumbs_up                        7106 non-null   int64
#  8   thumbs_down                      7106 non-null   int64
#  9   product_advatages_disadvantages  7106 non-null   object
#  10  product_advatages                7106 non-null   object
#  11  product_disadvantages            7105 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 721.7+ KB

# %%
#Unique values count for all columns
for i in data.columns:
   print("{} -- {} unique values".format(i, len(data[i].unique())))
# Out:
# comment_link -- 7106 unique values
# product_title -- 849 unique values
# product_price -- 358 unique values
# review_id -- 7106 unique values
# review_date -- 1135 unique values
# review_text -- 6720 unique values
# review_rating -- 6 unique values
# thumbs_up -- 83 unique values
# thumbs_down -- 58 unique values
# product_advatages_disadvantages -- 4008 unique values
# product_advatages -- 3741 unique values
# product_disadvantages -- 2849 unique values

# %%
#Check unique values for columns with <100 unique values
for i in ['review_rating', 'thumbs_up', 'thumbs_down']:
    print(data[i].value_counts())
# Out:
# 0    3030
# 5    2532
# 4    625
# 1    449
# 3    251
# 2    219
# Name: review_rating, dtype: int64
# 0      3332
# 1      1331
# 2      680
# 3      425
# 4      257
# 5      189
# 6      108
# 7      98
# 13     65
# 8      52
# 9      52
# 10     51
# 12     43
# 11     35
# 14     28
# 18     26
# 16     23
# 17     23
# 20     22
# 15     21
# 19     20
# 23     15
# 24     13
# 22     13
# 21     11
# 25     10
# 30     9
# 27     9
# 26     7
# 37     6
# 41     6
# 36     6
# 56     6
# 38     5
# 29     5
# 40     5
# 31     5
# 35     5
# 39     5
# 33     4
# 32     4
# 48     4
# 28     4
# 34     3
# 44     3
# 43     3
# 62     3
# 54     3
# 79     3
# 42     3
# 77     2
# 46     2
# 63     2
# 98     2
# 58     2
# 50     2
# 64     2
# 73     2
# 113    2
# 52     2
# 49     2
# 53     2
# 57     2
# 69     2
# 80     1
# 91     1
# 108    1
# 94     1
# 71     1
# 59     1
# 55     1
# 47     1
# 158    1
# 114    1
# 86     1
# 116    1
# 82     1
# 66     1
# 101    1
# 61     1
# 45     1
# 144    1
# 129    1
# Name: thumbs_up, dtype: int64
# 0     4436
# 1     1206
# 2     450
# 3     260
# 4     163
# 5     100
# 6     80
# 7     54
# 9     50
# 8     46
# 11    34
# 10    30
# 13    28
# 12    23
# 14    16
# 15    15
# 18    14
# 16    9
# 26    7
# 20    6
# 33    5
# 17    5
# 19    5
# 27    5
# 21    4
# 25    4
# 29    4
# 28    4
# 22    3
# 24    3
# 37    3
# 23    3
# 41    2
# 36    2
# 31    2
# 38    2
# 32    2
# 48    1
# 44    1
# 76    1
# 67    1
# 45    1
# 46    1
# 59    1
# 39    1
# 35    1
# 78    1
# 58    1
# 50    1
# 34    1
# 49    1
# 30    1
# 77    1
# 73    1
# 63    1
# 61    1
# 57    1
# 65    1
# Name: thumbs_down, dtype: int64

# %% [markdown]
# ## Fix data format, parsing issues, check for duplicates
#
# From the head of the dataset and statistics we can see:
# - comment_link, product_title, product_price, review_id, review_rating, thumbs_up, product_disadvantages – these columns looks good
# - review_date – needs to be converted to datatime format
# - review_text – let's look at records with the same text to check for duplicates
# - product_advatages_disadvantages – this column is duplicating, it was left in the scaping script in case there is a need to  check that we have full information in product_advatages/product_disadvantages clolumns. Seems like everything is fine, so we can drop this column.
# - product_advatages – we need to strip redundant symbols from this column and leave only text about product advantages, we can do this by striping everything after ‘/dd></div>’
#
# Also let’s add a column which will contain all text related to the review: Concatenation of review_text, product_advatages, product_disadvantages columns, so we can use it later on modeling stage.

# %%
#Lets have a closer look at format of review_date values
print(data.review_date.value_counts()[:30])
# Out:
#  20 лютого 2021          74
#  06 квітня 2021          64
#  05 квітня 2021          63
#  21 лютого 2021          63
#  2021-04-07 00:00:00     58
#  18 лютого 2021          58
#  17 лютого 2021          57
#  22 лютого 2021          55
#  04 квітня 2021          52
#  15 лютого 2021          51
#  16 лютого 2021          46
#  2021-02-23 00:00:00     45
#  24 березня 2021         45
#  25 березня 2021         45
#  10 лютого 2021          45
#  13 лютого 2021          45
#  08 лютого 2021          44
#  14 лютого 2021          43
#  19 лютого 2021          42
#  09 лютого 2021          41
#  27 березня 2021         37
#  01 квітня 2021          36
#  31 березня 2021         34
#  07 лютого 2021          34
#  22 березня 2021         33
#  20 березня 2021         33
#  12 лютого 2021          33
#  21 березня 2021         33
#  29 березня 2021         32
#  28 березня 2021         32
# Name: review_date, dtype: int64

# %%
#Convert review_date to datetime format and look at the results
data.review_date = [dateparser.parse(date, date_formats=['%d %m %Y']) for date in data.review_date]
print(data.review_date.value_counts()[:30])
# Out:
# 2021-02-20    74
# 2021-04-06    64
# 2021-02-21    63
# 2021-04-05    63
# 2021-04-07    58
# 2021-02-18    58
# 2021-02-17    57
# 2021-02-22    55
# 2021-04-04    52
# 2021-02-15    51
# 2021-02-23    48
# 2021-02-16    46
# 2021-03-24    45
# 2021-02-10    45
# 2021-02-13    45
# 2021-03-25    45
# 2021-02-08    44
# 2021-02-14    43
# 2021-02-19    42
# 2021-02-09    41
# 2021-03-27    37
# 2021-04-01    36
# 2021-03-31    34
# 2021-02-07    34
# 2021-03-20    33
# 2021-03-22    33
# 2021-02-12    33
# 2021-03-21    33
# 2021-03-28    32
# 2021-03-29    32
# Name: review_date, dtype: int64

# %%
#Delete product_advatages_disadvantages column
data = data.drop(columns=['product_advatages_disadvantages'])

# %%
#review_text – look at records with the same text to check for duplicates
display(pd.concat(g for _, g in data.groupby("review_text") if len(g) > 1))
# Out:
#                                                                                       comment_link  \
# 3197  https://rozetka.com.ua/ua/tecno_spark_4_kc2_royal_purple/p141981519/comments/#id=47568233
# 139   https://rozetka.com.ua/ua/xiaomi_749703/p282416913/comments/#id=49706561
# 1141  https://rozetka.com.ua/ua/apple_iphone_12_256gb_green/p245162317/comments/#id=49150262
# 2016  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49552939
# 1701  https://rozetka.com.ua/ua/samsung_sm_a207fzrdsek/p138459953/comments/#id=48346233
# ...                                                                                 ...
# 5247  https://rozetka.com.ua/ua/80542425/p80542425/comments/#id=46076690
# 1614  https://rozetka.com.ua/ua/ulefone_6937748733225/p114835363/comments/#id=45900336
# 1874  https://rozetka.com.ua/ua/63430022/p63430022/comments/#id=45900346
# 3692  https://rozetka.com.ua/ua/doogee_bl5500_lite_blue/p61682227/comments/#id=48706023
# 254   https://rozetka.com.ua/ua/motorola_e7_plus_4_64gb_blue/p245796667/comments/#id=49477721
#
#                                                                   product_title  \
# 3197   Мобільний телефон Tecno Spark 4 (KC2) Royal Purple
# 139    Мобільний телефон Xiaomi Redmi 9T 4/128 Twilight Blue (749703)
# 1141   Мобільний телефон Apple iPhone 12 256GB Green Офіційна гарантія
# 2016   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 1701   Мобільний телефон Samsung Galaxy A20s A207F 3/32GB Red (SM-A207FZRDSEK)
# ...                                                                         ...
# 5247   Смартфон LEAGOO Z9 1/8GB Gold
# 1614   Мобільний телефон Ulefone Armor X3 2/32GB Black-Red
# 1874   Ruggear rg 702
# 3692   Мобільний телефон Doogee BL5500 Lite Blue
# 254    Мобільний телефон Motorola E7 Plus 4/64 GB Blue (PAKX0008RS)
#
#       product_price  review_id review_date  \
# 3197  2999.0         47568233  2020-09-13
# 139   5499.0         49706561  2021-03-26
# 1141  35999.0        49150262  2021-02-01
# 2016  3999.0         49552939  2021-03-11
# 1701  4299.0         48346233  2020-11-28
# ...      ...              ...         ...
# 5247  1199.0         46076690  2020-04-21
# 1614  3599.0         45900336  2020-04-05
# 1874  2999.0         45900346  2020-04-05
# 3692  1899.0         48706023  2020-12-25
# 254   3761.0         49477721  2021-03-03
#
#                              review_text  review_rating  thumbs_up  \
# 3197  #мояраспаковка                      5              1
# 139   #мояраспаковка                      5              1
# 1141  #моєрозпакування                    5              0
# 2016  #моєрозпакування                    5              2
# 1701  +++                                 0              0
# ...   ...                                ..             ..
# 5247  Яка версія Android? Скільки ядер ?  0              1
# 1614  аккумулятор съемный в этой модели?  0              0
# 1874  аккумулятор съемный в этой модели?  0              2
# 3692  не рекомендую                       1              0
# 254   не рекомендую                       1              3
#
#       thumbs_down  \
# 3197  0
# 139   1
# 1141  0
# 2016  0
# 1701  0
# ...  ..
# 5247  0
# 1614  0
# 1874  1
# 3692  0
# 254   1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           product_advatages  \
# 3197  None
# 139   None
# 1141  Отличный гаджет</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>управление, к которому нужно привыкнуть после Андроида
# 2016  Цена какчество</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>нет
# 1701  Бренд країна виробник</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>Відсутні
# ...                                                                                                                                               ...
# 5247  None
# 1614  None
# 1874  None
# 3692  цена</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>батарея не держит, сообщения показывает иногда и как-то странно, точно что "живет своей жизнью :-)"
# 254   ціна , дизайн ,камера, екран</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>Змушений змінити свою думку про телефон. Щось не так з програмним забезпеченням( на мою думку) Страшенно починає глючить, коли на нього надходить виклик. Він починає жити своїм життям, вмикає - вимикає ліхтар, режим енергозбереження, нічний режим, не турбувати, режим літака,відкриваються якісь сповіщення, вайбер,а потім ще й сам перериває зв*язок.  І так ,практично, щоразу
#
#                                                                                                                                                                                                                                                                                                                                                                         product_disadvantages
# 3197  None
# 139   None
# 1141  управление, к которому нужно привыкнуть после Андроида
# 2016  нет
# 1701  Відсутні
# ...        ...
# 5247  None
# 1614  None
# 1874  None
# 3692  батарея не держит, сообщения показывает иногда и как-то странно, точно что "живет своей жизнью :-)"
# 254   Змушений змінити свою думку про телефон. Щось не так з програмним забезпеченням( на мою думку) Страшенно починає глючить, коли на нього надходить виклик. Він починає жити своїм життям, вмикає - вимикає ліхтар, режим енергозбереження, нічний режим, не турбувати, режим літака,відкриваються якісь сповіщення, вайбер,а потім ще й сам перериває зв*язок.  І так ,практично, щоразу
#
# [453 rows x 11 columns]

# %%
#lets remove "None" values from the result
display(pd.concat(g for _, g in data[data.review_text != 'None'].groupby("review_text") if len(g) > 1))
# Out:
#                                                                                       comment_link  \
# 3197  https://rozetka.com.ua/ua/tecno_spark_4_kc2_royal_purple/p141981519/comments/#id=47568233
# 139   https://rozetka.com.ua/ua/xiaomi_749703/p282416913/comments/#id=49706561
# 1141  https://rozetka.com.ua/ua/apple_iphone_12_256gb_green/p245162317/comments/#id=49150262
# 2016  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49552939
# 1701  https://rozetka.com.ua/ua/samsung_sm_a207fzrdsek/p138459953/comments/#id=48346233
# ...                                                                                 ...
# 5247  https://rozetka.com.ua/ua/80542425/p80542425/comments/#id=46076690
# 1614  https://rozetka.com.ua/ua/ulefone_6937748733225/p114835363/comments/#id=45900336
# 1874  https://rozetka.com.ua/ua/63430022/p63430022/comments/#id=45900346
# 3692  https://rozetka.com.ua/ua/doogee_bl5500_lite_blue/p61682227/comments/#id=48706023
# 254   https://rozetka.com.ua/ua/motorola_e7_plus_4_64gb_blue/p245796667/comments/#id=49477721
#
#                                                                   product_title  \
# 3197   Мобільний телефон Tecno Spark 4 (KC2) Royal Purple
# 139    Мобільний телефон Xiaomi Redmi 9T 4/128 Twilight Blue (749703)
# 1141   Мобільний телефон Apple iPhone 12 256GB Green Офіційна гарантія
# 2016   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 1701   Мобільний телефон Samsung Galaxy A20s A207F 3/32GB Red (SM-A207FZRDSEK)
# ...                                                                         ...
# 5247   Смартфон LEAGOO Z9 1/8GB Gold
# 1614   Мобільний телефон Ulefone Armor X3 2/32GB Black-Red
# 1874   Ruggear rg 702
# 3692   Мобільний телефон Doogee BL5500 Lite Blue
# 254    Мобільний телефон Motorola E7 Plus 4/64 GB Blue (PAKX0008RS)
#
#       product_price  review_id review_date  \
# 3197  2999.0         47568233  2020-09-13
# 139   5499.0         49706561  2021-03-26
# 1141  35999.0        49150262  2021-02-01
# 2016  3999.0         49552939  2021-03-11
# 1701  4299.0         48346233  2020-11-28
# ...      ...              ...         ...
# 5247  1199.0         46076690  2020-04-21
# 1614  3599.0         45900336  2020-04-05
# 1874  2999.0         45900346  2020-04-05
# 3692  1899.0         48706023  2020-12-25
# 254   3761.0         49477721  2021-03-03
#
#                              review_text  review_rating  thumbs_up  \
# 3197  #мояраспаковка                      5              1
# 139   #мояраспаковка                      5              1
# 1141  #моєрозпакування                    5              0
# 2016  #моєрозпакування                    5              2
# 1701  +++                                 0              0
# ...   ...                                ..             ..
# 5247  Яка версія Android? Скільки ядер ?  0              1
# 1614  аккумулятор съемный в этой модели?  0              0
# 1874  аккумулятор съемный в этой модели?  0              2
# 3692  не рекомендую                       1              0
# 254   не рекомендую                       1              3
#
#       thumbs_down  \
# 3197  0
# 139   1
# 1141  0
# 2016  0
# 1701  0
# ...  ..
# 5247  0
# 1614  0
# 1874  1
# 3692  0
# 254   1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           product_advatages  \
# 3197  None
# 139   None
# 1141  Отличный гаджет</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>управление, к которому нужно привыкнуть после Андроида
# 2016  Цена какчество</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>нет
# 1701  Бренд країна виробник</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>Відсутні
# ...                                                                                                                                               ...
# 5247  None
# 1614  None
# 1874  None
# 3692  цена</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>батарея не держит, сообщения показывает иногда и как-то странно, точно что "живет своей жизнью :-)"
# 254   ціна , дизайн ,камера, екран</dd></div><!----><div class="comment__essentials-item"><dt class="comment__essentials-label"> Недоліки: </dt><dd>Змушений змінити свою думку про телефон. Щось не так з програмним забезпеченням( на мою думку) Страшенно починає глючить, коли на нього надходить виклик. Він починає жити своїм життям, вмикає - вимикає ліхтар, режим енергозбереження, нічний режим, не турбувати, режим літака,відкриваються якісь сповіщення, вайбер,а потім ще й сам перериває зв*язок.  І так ,практично, щоразу
#
#                                                                                                                                                                                                                                                                                                                                                                         product_disadvantages
# 3197  None
# 139   None
# 1141  управление, к которому нужно привыкнуть после Андроида
# 2016  нет
# 1701  Відсутні
# ...        ...
# 5247  None
# 1614  None
# 1874  None
# 3692  батарея не держит, сообщения показывает иногда и как-то странно, точно что "живет своей жизнью :-)"
# 254   Змушений змінити свою думку про телефон. Щось не так з програмним забезпеченням( на мою думку) Страшенно починає глючить, коли на нього надходить виклик. Він починає жити своїм життям, вмикає - вимикає ліхтар, режим енергозбереження, нічний режим, не турбувати, режим літака,відкриваються якісь сповіщення, вайбер,а потім ще й сам перериває зв*язок.  І так ,практично, щоразу
#
# [169 rows x 11 columns]

# %% [markdown]
# *Some values in review text are indeed the same, but I would conclude that these are unique records as they are related to different products, written with different dates and sometimes have different product_advatages/ product_disadvantages text. Often the same text is some standard questions or feedback or just the same question that person wrote about different products.*

# %%
#Fix parsing of product_advatages column
data.product_advatages = [i.split('</dd>')[0] if i != "None" else 'None' for i in data.product_advatages]
display(data.head())
# Out:
#                                                                                                  comment_link  \
# 0  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49293156
# 1  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49190491
# 2  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49299159
# 3  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49289173
# 4  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49224598
#
#                                                                                                                  product_title  \
# 0   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 1   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 2   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 3   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 4   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
#
#    product_price  review_id review_date  \
# 0  39999.0        49293156  2021-02-13
# 1  39999.0        49190491  2021-02-04
# 2  39999.0        49299159  2021-02-14
# 3  39999.0        49289173  2021-02-13
# 4  39999.0        49224598  2021-02-07
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           review_text  \
# 0  Розетка, подскажите телефон без сканера лица и желательно без сканера отпечатков пальцев. Спасибо
# 1  Датчик адаптивной яркости работает не корректно в темноте дисплей светит на 90 процентов. Когда тресешь телефон раздается звук как будто внутри что то отвалилось, до этого s9 plus таких проблем не было, да Самсунг уже не тот))
# 2  Я не буду расписывать плюсы телефона - о них можно почитать в обзорах. Поэтому напишу о том, почему лично у меня с телефоном пока не сложились отношения. Отпечаток пальца работает плохо. То срабатывает без проблем, то с 5й попытки не желает. Камера – неплохо, но не очень нравится постобработка - она придает любой фотографии неестественные, перенасыщенные цвета. После активного часа игры в Асфальт 9 телефон перегревается и игра вылетает. Поэтому в чем прикол нового эксиноса я не поняла.Телефон слишком длинный. Ок, я могу прочесть на одну строчку больше текста, но за счет этого телефон габаритный, пальцем не достать до центра экрана, а ряд приложений не поддерживают такую длину. Сам девайс в руках довольно скользкий, поэтому придется покупать чехол. Кстати, похоже, что при создании чехлов устроили соревнование - кто придумает максимально уродливый и неудобный чехол. В результате все идеи номинантов были реализованы. Так что в целом, удовольствия от пользования телефоном у меня нет.
# 3  Доброго дня, при купівлі телефону в кредит подарунок надається чи ні?
# 4  У данной модели присутствует файс айди? Все жалуются на роботу отпечатка. С чем это связано и будет ли исправлено с выходом обновления?
#
#    review_rating  thumbs_up  thumbs_down                    product_advatages  \
# 0  0              0          1            None
# 1  2              3          2            от других флагманских телефонов нет
# 2  3              3          0            Камера, батарея
# 3  0              0          0            None
# 4  0              1          1            None
#
#                           product_disadvantages
# 0  None
# 1  дисплей, при тряске шум
# 2  Сканер отпечатка, эргономичность, аксессуары
# 3  None
# 4  None

# %% [markdown]
# ## Check review_text content to drop rows with not enough information

# %% [markdown]
# During checking reviews content, I noticed that some reviews seem to be quite low-quality. Usually such reviews contained questions instead of actual review or they contained very short text. Lets check these 2 cases.

# %%
#Check review_text with questions
qestions = []
for i in data.review_text:
    if str(i).endswith('?') and (len(i)<170):
        qestions.append(i)
        
print(len(qestions))
display(data[data['review_text'].isin(qestions)])

#After examining different lengths of questions in review_text column it was decided to use 170 symbols as threshold.
#Most of questions below this length doesn’t contain sentiment about product, just question. Some records have advatages/disadvantages description, but since there is not may of them - we will just drop such rows.
data = data[~data['review_text'].isin(qestions)]
# Out:
# 1227
#                                                                                                     comment_link  \
# 3     https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49289173
# 4     https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49224598
# 14    https://rozetka.com.ua/ua/samsung_sma715fzbusek/p174226312/comments/#id=49360664
# 20    https://rozetka.com.ua/ua/samsung_sma715fzbusek/p174226312/comments/#id=49376079
# 38    https://rozetka.com.ua/ua/samsung_sm_a025fzkesek/p268107536/comments/#id=49237413
# ...                                                                                 ...
# 4242  https://rozetka.com.ua/ua/39171344/p39171344/comments/#id=29062800
# 4243  https://rozetka.com.ua/ua/39171344/p39171344/comments/#id=30732696
# 4245  https://rozetka.com.ua/ua/39171344/p39171344/comments/#id=29140064
# 4246  https://rozetka.com.ua/ua/39171344/p39171344/comments/#id=31912486
# 4247  https://rozetka.com.ua/ua/39171344/p39171344/comments/#id=43493500
#
#                                                                                                                     product_title  \
# 3      Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 4      Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 14     Мобільний телефон Samsung Galaxy A71 6/128GB Blue (SM-A715FZBUSEK)
# 20     Мобільний телефон Samsung Galaxy A71 6/128GB Blue (SM-A715FZBUSEK)
# 38     Мобільний телефон Samsung Galaxy A02s 3/32 GB Black (SM-A025FZKESEK)
# ...                                                                      ...
# 4242   Смартфон Vivo X20 4/64GB Black Matte
# 4243   Смартфон Vivo X20 4/64GB Black Matte
# 4245   Смартфон Vivo X20 4/64GB Black Matte
# 4246   Смартфон Vivo X20 4/64GB Black Matte
# 4247   Смартфон Vivo X20 4/64GB Black Matte
#
#       product_price  review_id review_date  \
# 3     39999.0        49289173  2021-02-13
# 4     39999.0        49224598  2021-02-07
# 14    9499.0         49360664  2021-02-20
# 20    9499.0         49376079  2021-02-22
# 38    3799.0         49237413  2021-02-08
# ...      ...              ...         ...
# 4242  7159.0         29062800  2018-06-04
# 4243  7159.0         30732696  2018-07-20
# 4245  7159.0         29140064  2018-06-05
# 4246  7159.0         31912486  2018-08-21
# 4247  7159.0         43493500  2019-06-21
#
#                                                                                                                                   review_text  \
# 3     Доброго дня, при купівлі телефону в кредит подарунок надається чи ні?
# 4     У данной модели присутствует файс айди? Все жалуются на роботу отпечатка. С чем это связано и будет ли исправлено с выходом обновления?
# 14    А что, нет радио? Только в А51 радио в этой линейке?
# 20    Скажите, пожалуйста, стабилизация основной камеры есть?
# 38    Когда будет в наличии?
# ...                      ...
# 4242  С что телефон vivo забыл в разделе google ?
# 4243  Коли з'явиться у наявності?
# 4245  Может хоть напишете какой процессор в телефоне, и какое-нибудь описание?
# 4246  Vivo x20 ud будет?
# 4247  Здравствуйте, а матрица экрана точно Супер Амолед от Самсунг!!!?
#
#       review_rating  thumbs_up  thumbs_down product_advatages  \
# 3     0              0          0            None
# 4     0              1          1            None
# 14    0              0          0            None
# 20    0              0          0            None
# 38    0              0          0            None
# ...  ..             ..         ..             ...
# 4242  3              16         4            None
# 4243  0              4          1            None
# 4245  0              6          10           None
# 4246  0              5          0            None
# 4247  0              0          0            None
#
#      product_disadvantages
# 3     None
# 4     None
# 14    None
# 20    None
# 38    None
# ...    ...
# 4242  None
# 4243  None
# 4245  None
# 4246  None
# 4247  None
#
# [1227 rows x 11 columns]

# %%
#Check short review_text values
short_comments = []
for i in data.review_text:
    if (len(str(i))<2) and i not in qestions and i!='None':
        short_comments.append(i)
        
print(len(short_comments))
display(data[data['review_text'].isin(short_comments)])

#After examining short reviews it was decided to leave them as a lot of short reviews contained reviewer opinion on the product.
#We will drop only 1 row without review_text/product_advatages/product_disadvantages.
data = data[~data['review_id'].isin(['32563944'])]
# Out:
# 2
#                                                             comment_link  \
# 4979  https://rozetka.com.ua/ua/15968704/p15968704/comments/#id=19335260
# 5656  https://rozetka.com.ua/ua/33763271/p33763271/comments/#id=32563944
#
#                       product_title  product_price  review_id review_date  \
# 4979   S-TELL M556 Black             1999.0         19335260  2017-07-12
# 5656   Blackview A10 Barley Golden   2086.0         32563944  2018-09-13
#
#      review_text  review_rating  thumbs_up  thumbs_down  \
# 4979  .           0              0          0
# 5656  .           4              0          0
#
#                                                                                                                                                                               product_advatages  \
# 4979  Неплохая камера для телефона за 70$ ,экран хоть и большеват для такого разрешения но лесенок и пикселей не наблюдается,стекло довольно прочное,технология miravision,углы обзора экрана,.
# 5656  None
#
#                                                                                                                                                                    product_disadvantages
# 4979  Перегрев,он выгружает фоновые приложения из памяти,плохое стандартное приложение камеры ,поганая оптимизация системы , баги системы,динамик тихий ,скользящий задник смартфона   ,
# 5656  None

# %% [markdown]
# ## Create column full_text which contains all text related  to the review: review_text, product_advatages, product_disadvantages

# %%
#Create full_text column
data["full_text"] = data["review_text"] +' Преймущества: ' +data["product_advatages"] + '. Недостатки: ' + data.product_disadvantages

# %% [markdown]
# ## Take care of Missing values

# %%
#At first let's look at review_rating values count
display(data.groupby('review_rating')['comment_link'].count())
#Plot a diagram of review_rating values count
labels, frequencies = np.unique(data.review_rating.values, return_counts = True)
plt.figure(figsize = (5, 5))
plt.pie(frequencies,labels = labels, autopct = '%1.1f%%')
plt.title('review_rating values')
plt.savefig('review_rating_values.png', transparent=True)
plt.show()
# Out:
# review_rating
# 0    1901
# 1    436
# 2    213
# 3    245
# 4    601
# 5    2482
# Name: comment_link, dtype: int64

# %% [markdown]
# *From checking the web-site we can see that there are no reviews with 0 stars, so in fact 32.3% of retrieved reviews don’t have a rating. So predicting sentiment of reviews based on text can be useful, it will allow to get the information about consumers sentiment for significant fraction of the reviews that currently are not classified.*

# %%
#During web-scraping script preparation missing values were marked as None. 
#Lets set 0 in review_rating and None in other columns as NaN 
#Also lets set as NaN values of full_text column in which we don’t have any text
data['review_rating'] = data['review_rating'].replace(0, np.NaN)
data = data.replace('None', np.NaN)
data['full_text'] = data['full_text'].replace('None Преймущества: None. Недостатки: None', np.NaN)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5878 entries, 0 to 5119
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   comment_link           5878 non-null   object
#  1   product_title          5878 non-null   object
#  2   product_price          5878 non-null   float64
#  3   review_id              5878 non-null   int64
#  4   review_date            5878 non-null   datetime64[ns]
#  5   review_text            5594 non-null   object
#  6   review_rating          3977 non-null   float64
#  7   thumbs_up              5878 non-null   int64
#  8   thumbs_down            5878 non-null   int64
#  9   product_advatages      3733 non-null   object
#  10  product_disadvantages  3699 non-null   object
#  11  full_text              5705 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 597.0+ KB

# %% [markdown]
# # Step 2: Exploratory data analysis

# %% [markdown]
# In this section, we will make a cursory exploration of retrieved reviews data.

# %% [markdown]
# ##  review_rating exploration

# %%
#Plot review_rating values for not NA recods
data_wth_rating = pd.DataFrame(data[data.review_rating.notna()])
labels, frequencies = np.unique(data_wth_rating.review_rating.values, return_counts = True)
plt.figure(figsize = (5,5))
plt.pie(frequencies,labels = labels, autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# *The target variable classes are imbalanced.
# We can see that the biggest fraction of reviews is the most positive ones: about 62% percent of reviews have rating 5 stars and the second biggest fraction is also positive reviews with the rating of 4 stars (15%).*

# %% [markdown]
# ## product_price VS review_rating relation

# %%
#Visualize relation of Product price VS Rating
ax = sns.scatterplot(data=data_wth_rating, x="product_price", y="review_rating")
ax.set_title('Product price VS Rating')
plt.show()

# %% [markdown]
# *From the plot above we can see that more expensive products seem to have tendency to have higher ratings.
# To see the trend more clearly lets divide products into 4 price segments and plot average rating.*

# %%
#Plot review_rating in product price_segments
data_wth_rating['price_segments'] = pd.qcut(data_wth_rating.product_price, 4, labels=["0.cheap", "1.below_average", "2. above_average", "3.expensive"])
ax =sns.boxplot(x="price_segments", y="review_rating", data=data_wth_rating)
plt.setp(ax.get_xticklabels(), rotation=10)
ax.set_title('Boxplot of review_rating by product price_segments')
plt.show()

#Create price segments and check avarage rating 
review_rating_by_price_segments = pd.DataFrame(data_wth_rating.groupby('price_segments')['review_rating'].mean())
display(review_rating_by_price_segments)
g = sns.lineplot(data=review_rating_by_price_segments, markers=True)
g.set_title('Average review rating by product price segments')
plt.show()
# Out:
#                   review_rating
# price_segments
# 0.cheap           3.664062
# 1.below_average   4.125767
# 2. above_average  4.301829
# 3.expensive       4.430878

# %% [markdown]
# ## review_date VS review_date relation

# %%
#Explore reviews cretion timeline
display("The earliest review is from {} year and the latest review is from {} year".format(data.review_date.min().year, data.review_date.max().year))

rating_avg = data_wth_rating.groupby('review_date')['review_rating'].mean().reset_index()
ax = sns.scatterplot(data = rating_avg, x='review_date', y='review_rating')
ax.set_title('Average Ratings by review creation date')
ax.set(xlim=(data_wth_rating.review_date.min(), data_wth_rating.review_date.max()))
plt.show()
# Out:
# 'The earliest review is from 2015 year and the latest review is from 2021 year'

# %% [markdown]
# *From the plot above we can see that in our dataset there are more new reviews than old ones and new reviews also seem to have higher ratings.
# Probably it’s connected with the way how reviews were web-scraped: we retrieved only first portion of reviews of each product that was initially displayed in the web-page (before pressing “Show more” button).  It’s could be that the web-site shows the recent and positive reviews first. It could be the reason why we got mainly recent positive reviews.*
#
# Even though there is some specifics on how data was collected it should be enough to test what performance we can expect from the sentiment prediction model, so we can proceed further with the project.

# %%
#Explore reviews timeline with rolling mean to see if there is a trend
rating_avg['rating_30day_avg'] = rating_avg.review_rating.rolling(30).mean().shift(-3)
ax = sns.lineplot(data = rating_avg, x='review_date', y='rating_30day_avg')
ax.set_title('Time Plot with 30-day rolling average for Ratings')
plt.setp(ax.get_xticklabels(), rotation=45)
plt.show()

# %% [markdown]
# *The plot above with 30-day rolling average removes noise from the data and shows more general trend of how average ratings in our dataset have been changing in time. Seems like average rating for smartphones grows up since summer 2019.*

# %% [markdown]
# ## review_text - language detection

# %%
#Drop rows with NA values for review_text
review_text_clean = pd.DataFrame(data_wth_rating.dropna(subset = ['review_text']))

#Detect language
lang=[]
for i in review_text_clean.review_text:
    try:
      lang.append(detect(i))
    except:
        lang.append('None')
review_text_clean['lang'] = lang

# %% [markdown]
# lang=[]
# for i in review_text_clean.review_text:
#     try:
#         b = TextBlob(i)
#         lang.append(b.detect_language())
#     except:
#         lang.append('None')
# review_text_clean['lang'] = lang

# %%
#Plot review_text languages
labels, frequencies = np.unique(review_text_clean.lang.values, return_counts = True)
plt.figure(figsize = (5, 5))
plt.pie(frequencies,labels = labels, autopct = '%1.1f%%')
plt.title('Fractions of review_text languages')
plt.show()

# %%
#Look at rows which was not detected as ru or uk language
review_text_clean[(review_text_clean.lang != 'ru') & (review_text_clean.lang != 'uk')]
# Out:
#                                                                                                                comment_link  \
# 50    https://rozetka.com.ua/ua/samsung_sm_a315fzwvsek/p199478977/comments/#id=49272421
# 60    https://rozetka.com.ua/ua/apple_iphone_12_64gb_product_red/p245162161/comments/#id=49368869
# 62    https://rozetka.com.ua/ua/apple_iphone_12_64gb_product_red/p245162161/comments/#id=49201778
# 78    https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49310861
# 110   https://rozetka.com.ua/ua/realme_7_pro_8_128gb_mirror_blue/p254407693/comments/#id=49233541
# 314   https://rozetka.com.ua/ua/zte_blade_a7_2_32gb_black/p90749888/comments/#id=49315579
# 359   https://rozetka.com.ua/ua/xiaomi_657892/p224063905/comments/#id=48906647
# 430   https://rozetka.com.ua/ua/zte_blade_a7s_3_64gb_blue/p250624431/comments/#id=49395365
# 766   https://rozetka.com.ua/ua/motorola_razr_5g_gold/p247505413/comments/#id=48974568
# 862   https://rozetka.com.ua/ua/apple_iphone_12_pro_max_256gb_pacific_blue/p245162569/comments/#id=48897458
# 946   https://rozetka.com.ua/ua/xiaomi_mi_10t_6_128gb_cosmic_black/p252742451/comments/#id=48073402
# 1036  https://rozetka.com.ua/ua/pocophone_691532/p246763123/comments/#id=47563259
# 1308  https://rozetka.com.ua/ua/tecno_spark_6_4_64gb_comet_black/p261915406/comments/#id=49311818
# 1357  https://rozetka.com.ua/ua/tecno_spark_6_4_128gb_ocean_blue/p261922161/comments/#id=49325003
# 1664  https://rozetka.com.ua/ua/logic_instrument_fbf1b00/p70749578/comments/#id=45815765
# 1794  https://rozetka.com.ua/ua/61852957/p61852957/comments/#id=48192626
# 1798  https://rozetka.com.ua/ua/61852957/p61852957/comments/#id=48470597
# 1894  https://rozetka.com.ua/ua/83793234/p83793234/comments/#id=45043031
# 2202  https://rozetka.com.ua/ua/samsung_galaxy_a01_2_16gb_red/p173920111/comments/#id=49139856
# 2234  https://rozetka.com.ua/ua/samsung_sm_m115fzknsek/p208369267/comments/#id=48925200
# 2270  https://rozetka.com.ua/ua/oppo_a31_lake_green/p193260096/comments/#id=47398542
# 2414  https://rozetka.com.ua/ua/realme_6941399004832/p208489687/comments/#id=49144032
# 2453  https://rozetka.com.ua/ua/huawei_y6_2019_blue/p76631166/comments/#id=41646594
# 2717  https://rozetka.com.ua/ua/2e_e450a_2018_dualsim_black/p51927996/comments/#id=47320002
# 2852  https://rozetka.com.ua/ua/realme_6941399000230/p237047725/comments/#id=48691424
# 2919  https://rozetka.com.ua/ua/oppo_find_x2_ocean_black/p194528244/comments/#id=47452668
# 3154  https://rozetka.com.ua/ua/oppo_reno3_8_128gb_auroral_blue/p200222839/comments/#id=47174165
# 3162  https://rozetka.com.ua/ua/huawei_p30_lite_4_64gb_midnightblack/p158250128/comments/#id=47921979
# 3237  https://rozetka.com.ua/ua/realme_5_3_64_blue/p193006570/comments/#id=48392236
# 3595  https://rozetka.com.ua/ua/general_mobile_8go_1_16_gold/p46108264/comments/#id=44988835
# 3600  https://rozetka.com.ua/ua/general_mobile_8go_1_16_gold/p46108264/comments/#id=44594569
# 3683  https://rozetka.com.ua/ua/tp_link_neffos_tp7071a55ua/p106788753/comments/#id=48864668
# 3738  https://rozetka.com.ua/ua/blackview_6931548305545/p120379858/comments/#id=47411282
# 3778  https://rozetka.com.ua/ua/tplink_neffos_tp903a46ua/p25379089/comments/#id=45127067
# 3841  https://rozetka.com.ua/ua/ulefone_s1_1_8gb_black/p65632560/comments/#id=48142423
# 4037  https://rozetka.com.ua/ua/68056643/p68056643/comments/#id=49211581
# 4196  https://rozetka.com.ua/ua/91537124/p91537124/comments/#id=44473115
# 4254  https://rozetka.com.ua/ua/107415672/p107415672/comments/#id=49348928
# 4439  https://rozetka.com.ua/ua/55909158/p55909158/comments/#id=45620960
# 4566  https://rozetka.com.ua/ua/39173264/p39173264/comments/#id=31892374
# 4830  https://rozetka.com.ua/ua/34523263/p34523263/comments/#id=28263832
# 4886  https://rozetka.com.ua/ua/15968760/p15968760/comments/#id=18627492
# 5046  https://rozetka.com.ua/ua/69303674/p69303674/comments/#id=45118126
# 5113  https://rozetka.com.ua/ua/65279760/p65279760/comments/#id=27654304
# 5393  https://rozetka.com.ua/ua/63393468/p63393468/comments/#id=39691818
# 5445  https://rozetka.com.ua/ua/84250194/p84250194/comments/#id=44358907
# 5626  https://rozetka.com.ua/ua/40648704/p40648704/comments/#id=48227267
# 5701  https://rozetka.com.ua/ua/32906975/p32906975/comments/#id=37560969
# 59    https://rozetka.com.ua/ua/samsung_galaxy_a72_6_128gb_blue/p280539398/comments/#id=49800822
# 131   https://rozetka.com.ua/ua/samsung_galaxy_a52_4_128gb_blue/p280536193/comments/#id=49717567
# 165   https://rozetka.com.ua/ua/xiaomi_657892/p224063905/comments/#id=49813968
# 201   https://rozetka.com.ua/ua/huawei_p_smart_2021_nfc_128gb_black/p272525976/comments/#id=49586107
# 202   https://rozetka.com.ua/ua/huawei_p_smart_2021_nfc_128gb_black/p272525976/comments/#id=49505812
# 204   https://rozetka.com.ua/ua/samsung_galaxy_a72_8_256gb_black/p280544643/comments/#id=49647327
# 217   https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_silver_sm_g998bzsgsek/p272562741/comments/#id=49574041
# 291   https://rozetka.com.ua/ua/apple_mhda3/p260862296/comments/#id=49804376
# 428   https://rozetka.com.ua/ua/xiaomi_redmi_note_9_4_128gb_forest_green/p209755849/comments/#id=49774439
# 736   https://rozetka.com.ua/ua/xiaomi_660925/p244791319/comments/#id=49695170
# 793   https://rozetka.com.ua/ua/xiaomi_660924/p244789591/comments/#id=49805187
# 881   https://rozetka.com.ua/ua/realme_6941399013223/p208494043/comments/#id=49521130
# 999   https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_silver_sm_g998bzshsek/p272563631/comments/#id=49752489
# 1227  https://rozetka.com.ua/ua/samsung_sm_f916bzkqsek/p239193979/comments/#id=49681447
# 1687  https://rozetka.com.ua/ua/xiaomi_redmi_8_4_64_red_global_rom_ota/p223083685/comments/#id=49824762
# 1712  https://rozetka.com.ua/ua/xiaomi_redmi_9a_4_64gb_carbon_grey__global_rom___ota_/p273277228/comments/#id=49786318
# 1751  https://rozetka.com.ua/ua/xiaomi_redmi_9_4_64gb_carbon_grey_global_rom_ota/p256363376/comments/#id=49435779
# 1975  https://rozetka.com.ua/ua/zte_blade_a5_2020_2_32gb_black/p155744723/comments/#id=49695996
# 2092  https://rozetka.com.ua/ua/motorola_pajw0006rs/p245662303/comments/#id=49639780
# 2202  https://rozetka.com.ua/ua/samsung_sm_m317fzbnsek/p244007101/comments/#id=49815109
# 2263  https://rozetka.com.ua/ua/xiaomi_redmi_note_8_pro_6_64gb_green/p124546131/comments/#id=49791396
# 2274  https://rozetka.com.ua/ua/xiaomi_redmi_note_8_pro_6_64gb_green/p124546131/comments/#id=49662099
# 2303  https://rozetka.com.ua/ua/apple_iphone_7_32gb_gold/p11256403/comments/#id=47465833
# 2305  https://rozetka.com.ua/ua/apple_iphone_7_32gb_gold/p11256403/comments/#id=47434719
# 2350  https://rozetka.com.ua/ua/xiaomi_redmi_note_9_pro_4_64gb_interstellar_grey/p195066187/comments/#id=49423287
# 2358  https://rozetka.com.ua/ua/samsung_galaxy_note_10_lite_6_128_gb_silver_sm_n770fzsdsek/p172570007/comments/#id=49592885
# 5104  https://rozetka.com.ua/ua/zte_axon_20_5g_12_256gb_purple/p247366861/comments/#id=49825376
#
#                                                                                                                               product_title  \
# 50     Мобільний телефон Samsung Galaxy A31 4/128GB Prism Crush White (SM-A315FZWVSEK)
# 60     Мобільний телефон Apple iPhone 12 64GB PRODUCT Red Офіційна гарантія
# 62     Мобільний телефон Apple iPhone 12 64GB PRODUCT Red Офіційна гарантія
# 78     Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 110    Мобільний телефон Realme 7 Pro 8/128GB Mirror Blue
# 314    Мобільний телефон ZTE Blade A7 2/32GB Black
# 359    Мобільний телефон Xiaomi Redmi 9 3/32GB Carbon Grey (657892)
# 430    Мобільний телефон ZTE Blade A7s 2020 3/64 GB Blue
# 766    Мобільний телефон Motorola RAZR 2019 XT200-2 Blush Gold
# 862    Мобільний телефон Apple iPhone 12 Pro Max 256 GB Pacific Blue Офіційна гарантія
# 946    Мобільний телефон Xiaomi Mi 10T 6/128 GB Cosmic Black
# 1036   Мобільний телефон Poco X3 6/64 GB Cobalt Blue (691532)
# 1308   Мобільний телефон Tecno Spark 6 4/64 GB Comet Black
# 1357   Мобільний телефон Tecno Spark 6 4/128 GB Ocean Blue
# 1664   Мобільний телефон Logic Instrument Fieldbook F1B
# 1794   Мобільний телефон Blackview BV9500 (4+64Gb) Black
# 1798   Мобільний телефон Blackview BV9500 (4+64Gb) Black
# 1894   Blackview BV9600 Pro Black
# 2202   Мобільний телефон Samsung Galaxy A01 2/16GB Red (SM-A015FZRDSEK)
# 2234   Мобільний телефон Samsung Galaxy M11 3/32GB Black (SM-M115FZKNSEK)
# 2270   Мобільний телефон OPPO A31 Lake Green
# 2414   Мобільний телефон Realme C3 3/64GB Blue
# 2453   Мобільний телефон Huawei Y6 2019 Blue
# 2717   Мобільний телефон 2E E450A 2018 DualSim Black
# 2852   Мобільний телефон Realme X2 Pro 12/256 GB White
# 2919   Мобільний телефон OPPO Find X2 Ocean Black
# 3154   Мобільний телефон OPPO Reno3 8/128GB Auroral Blue
# 3162   Мобільний телефон Huawei P30 Lite 4/64GB Midnight Black
# 3237   Мобільний телефон Realme 5 3/64GB Blue
# 3595   Мобільний телефон General Mobile 8GO 1/16 Gold
# 3600   Мобільний телефон General Mobile 8GO 1/16 Gold
# 3683   Мобільний телефон TP-Link Neffos X20 Black
# 3738   Мобільний телефон Blackview A30 2/16GB Gold (Українська версія)
# 3778   Мобільний телефон TP-Link Neffos X1 Max Gold (TP903A46UA)
# 3841   Мобільний телефон Ulefone S1 1/8GB Black
# 4037   Google Pixel 2 64GB Kinda Blue
# 4196   Мобільний телефон Doogee S90 (6+128Gb) Black
# 4254   Мобильный телефон Doogee S40 Lite Black
# 4439   Blackview BV6000 Yellow
# 4566   Смартфон OnePlus 5T 6/64GB Midnight Black
# 4830   Homtom HT37 Pro 3/32Gb Rose/Gold
# 4886   S-TELL M621 Black
# 5046   Мобільний телефон ZOJI Z9 (6+64Gb) Black
# 5113   Doopro P5 1/8GB Black
# 5393   DOOGEE X6 Pro White
# 5445   LEAGOO T8S 4/32GB Gold
# 5626   Blackview BV4000 Pro Green
# 5701   Мобільний телефон Doogee X9 Mini White
# 59     Мобільний телефон Samsung Galaxy A72 6/128 GB Blue
# 131    Мобільний телефон Samsung Galaxy A52 4/128 GB Blue
# 165    Мобільний телефон Xiaomi Redmi 9 3/32GB Carbon Grey (657892)
# 201    Мобільний телефон Huawei P Smart 2021 NFC 128 GB Black
# 202    Мобільний телефон Huawei P Smart 2021 NFC 128 GB Black
# 204    Мобільний телефон Samsung Galaxy A72 8/256 GB Black
# 217    Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Silver (SM-G998BZSGSEK) + Наушники Samsung Galaxy Buds Live в подарок!
# 291    Мобільний телефон Apple iPhone 11 64 GB Black Slim Box (MHDA3) Офіційна гарантія
# 428    Мобільний телефон Xiaomi Redmi Note 9 4/128GB Forest Green
# 736    Мобільний телефон Xiaomi Redmi 9C 3/64 GB Midnight Gray (660925)
# 793    Мобільний телефон Xiaomi Redmi 9C 2/32 GB Sunrise Orange (660924)
# 881    Мобільний телефон Realme 6 Pro 8/128GB Blue
# 999    Мобільний телефон Samsung Galaxy S21 Ultra 16/512 GB Phantom Silver (SM-G998BZSHSEK) + Наушники Samsung Galaxy Buds Live в подарок!
# 1227   Мобільний телефон Samsung Galaxy Z Fold2 12/256 GB Black (SM-F916BZKQSEK)
# 1687   Мобільний телефон Xiaomi Redmi 8 4/64GB Ruby Red (Global ROM + OTA)
# 1712   Мобільний телефон Xiaomi Redmi 9A 4/64GB Carbon Grey (Global ROM + OTA)
# 1751   Мобільний телефон Xiaomi Redmi 9 4/64GB Carbon Grey (Global ROM + OTA)
# 1975   Мобільний телефон ZTE Blade A5 2020 2/32GB Black
# 2092   Мобільний телефон Motorola One Fusion+ 6/128GB Blue (PAJW0006RS)
# 2202   Мобільний телефон Samsung Galaxy M31s 6/128 GB Blue (SM-M317FZBNSEK)
# 2263   Мобільний телефон Xiaomi Redmi Note 8 Pro 6/64GB Green
# 2274   Мобільний телефон Xiaomi Redmi Note 8 Pro 6/64GB Green
# 2303   Мобільний телефон Apple iPhone 7 32GB Gold Офіційна гарантія
# 2305   Мобільний телефон Apple iPhone 7 32GB Gold Офіційна гарантія
# 2350   Мобільний телефон Xiaomi Redmi Note 9S 4/64GB Interstellar Grey
# 2358   Мобільний телефон Samsung Galaxy Note 10 Lite (SM-N770) 6/128GB Aura Silver (SM-N770FZSDSEK)
# 5104   Мобільний телефон ZTE Axon 20 5G 12/256GB Purple
#
#       product_price  review_id review_date  \
# 50    5999.0         49272421  2021-02-11
# 60    28999.0        49368869  2021-02-21
# 62    28999.0        49201778  2021-02-05
# 78    4499.0         49310861  2021-02-15
# 110   8999.0         49233541  2021-02-08
# 314   2499.0         49315579  2021-02-16
# 359   4199.0         48906647  2021-01-12
# 430   3299.0         49395365  2021-02-23
# 766   36999.0        48974568  2021-01-18
# 862   44499.0        48897458  2021-01-11
# 946   12999.0        48073402  2020-11-06
# 1036  6499.0         47563259  2020-09-12
# 1308  3999.0         49311818  2021-02-15
# 1357  4399.0         49325003  2021-02-16
# 1664  15250.0        45815765  2020-03-27
# 1794  6199.0         48192626  2020-11-17
# 1798  6199.0         48470597  2020-12-07
# 1894  8799.0         45043031  2019-12-20
# 2202  2999.0         49139856  2021-01-31
# 2234  4199.0         48925200  2021-01-13
# 2270  4499.0         47398542  2020-08-23
# 2414  3899.0         49144032  2021-01-31
# 2453  2999.0         41646594  2019-04-27
# 2717  1249.0         47320002  2020-08-13
# 2852  13499.0        48691424  2020-12-23
# 2919  24999.0        47452668  2020-08-30
# 3154  9999.0         47174165  2020-07-27
# 3162  4399.0         47921979  2020-10-22
# 3237  3999.0         48392236  2020-12-01
# 3595  2799.0         44988835  2019-12-14
# 3600  2799.0         44594569  2019-10-24
# 3683  2599.0         48864668  2021-01-09
# 3738  1677.0         47411282  2020-08-25
# 3778  3199.0         45127067  2019-12-31
# 3841  1699.0         48142423  2020-11-12
# 4037  11877.0        49211581  2021-02-06
# 4196  6999.0         44473115  2019-10-04
# 4254  2399.0         49348928  2021-02-18
# 4439  4499.0         45620960  2020-03-03
# 4566  13999.0        31892374  2018-08-21
# 4830  2855.0         28263832  2018-05-10
# 4886  2290.0         18627492  2017-05-27
# 5046  4399.0         45118126  2019-12-30
# 5113  1999.0         27654304  2018-04-19
# 5393  2000.0         39691818  2019-03-05
# 5445  2709.0         44358907  2019-09-17
# 5626  3044.0         48227267  2020-11-19
# 5701  1899.0         37560969  2019-01-16
# 59    12999.0        49800822  2021-04-05
# 131   9999.0         49717567  2021-03-28
# 165   3699.0         49813968  2021-04-06
# 201   4999.0         49586107  2021-03-14
# 202   4999.0         49505812  2021-03-06
# 204   14999.0        49647327  2021-03-20
# 217   39999.0        49574041  2021-03-13
# 291   21999.0        49804376  2021-04-06
# 428   4999.0         49774439  2021-04-02
# 736   3499.0         49695170  2021-03-25
# 793   3199.0         49805187  2021-04-06
# 881   7999.0         49521130  2021-03-07
# 999   43999.0        49752489  2021-03-31
# 1227  54999.0        49681447  2021-03-24
# 1687  3499.0         49824762  2021-04-07
# 1712  3269.0         49786318  2021-04-04
# 1751  3899.0         49435779  2021-02-27
# 1975  2399.0         49695996  2021-03-25
# 2092  6499.0         49639780  2021-03-19
# 2202  7499.0         49815109  2021-04-07
# 2263  5599.0         49791396  2021-04-04
# 2274  5599.0         49662099  2021-03-22
# 2303  10999.0        47465833  2020-08-31
# 2305  10999.0        47434719  2020-08-27
# 2350  5999.0         49423287  2021-02-26
# 2358  9999.0         49592885  2021-03-15
# 5104  0.0            49825376  2021-04-07
#
#                                                                                             review_text  \
# 50    Задоволена. Все чудово
# 60    Топ за свои деньги
# 62    Перешел с 5s на 12, телефон не лагает, все четко
# 78    !!!
# 110   Телефон супер (ракета)
# 314   Телефон не працює
# 359   недостатков нет
# 430   Отлично
# 766   Супер скидка!!! Заверните 10 штук.
# 862   нет радио )
# 946   Матрица IPS, сканер на боковой грани, рамка металл, задняя крышка - стекло, зарядка 33 Вт.
# 1036  Смартфон пушка покупай не пожелеєш............
# 1308  Телефон на такі кошти не поганий.Плеймаркет закачали. А от скірншот не можливо зробити.
# 1357  Телефон просто пушка
# 1664  Купила дочери на 8 марта. Нравится. Пока нареканий нет. Дизайн, технические характеристики
# 1794  Все гуд
# 1798  Себя оправдал
# 1894  Спасибо за доставку пришло оперативно без проблем.
# 2202  за свои деньги просто супер !!
# 2234  +++
# 2270  Слов нет, Браво Розетка!!! Тогда тоже кричали- Акция!!! Суперцена!!!
# 2414  за 3500 саме то
# 2453  Телефон супер!! Звук порадував!!
# 2717  не те що прислали, що замовляв
# 2852  Бомба ) Ракета
# 2919  За свои деньги, просто топ!!!
# 3154  Амолед? Стерео нема.
# 3162  пайдет
# 3237  Здравствуйте,отмените пожалуйста заказ номер 486274856
# 3595  Ок!
# 3600  ok
# 3683  ТОП!
# 3738  Деньги на ветер
# 3778  Все ОК
# 3841  купил жене
# 4037  Сразу перезвонили, подтвердили заказ, телефон приехал через два дняСервисом доволен на 100%
# 4196  Supper
# 4254  Все отлично
# 4439  Телефон норм и продавец супир слава Бугу
# 4566  Телефон имба,рад что взял его а не айфона 7+.
# 4830  Все супер ..
# 4886  Не берите !
# 5046  Дитина просто щаслива
# 5113  Дешевле не нашел, купил вполне доволен
# 5393  ПАЦАН ДОВОЛЬНИЙ - БАТЬКО ЩАСЛИВИЙ
# 5445  Через 10 дней после получения телефон завис и не реагирует ни на что.
# 5626  ну и зарядка почти безумна по времени
# 5701  До поломки работал отлично без упреков!
# 59    Поки все ОК
# 131   Приятно что в среднем сегменте добавили 90 Гц экран, влагозащиту IP67 и стереодинамики.
# 165   Брал отцу, отец доволен!
# 201   Телефо0н топ за свои деньги  (Спасибо за конфетки)
# 202   ...
# 204   5 балов
# 217   Все гуд
# 291   Не понятно где тут Акция???! Его цена в Yabloki 19700
# 428   Все супер
# 736   Все отлично ! За свои деньги просто супер  !!!
# 793   купили ребенку, все отлично работает
# 881   Мажна брати
# 999   Наконец-то  дождался телефон. Получил телефон 31.03 , заказал и оплатил телефон 31.01
# 1227  Телефон Тони Старка
# 1687  За такие деньги топ . Лучше не найдьоте .
# 1712  Телефон не видит сим-карт!
# 1751  Дочка дуже задоволена. Щиро дякую
# 1975  Топ
# 2092  Я доволен:)
# 2202  Телефон ракета
# 2263  ТЕЛЕФОН ДОСТОЙНИЙ СВОЇХ ГРОШЕЙ . НЕ ЗАВИСАЄ , ШВИДКО РЕАГУЄ . ТЕЛЕФОН ВЖЕ 2 РІК, СЛУЖИТЬ ДОБРЕ !!
# 2274  Xiaomi Redmi Note 8 Pro 6/64
# 2303  Все просто супер))
# 2305  iPhone
# 2350  Купила и не пожалела
# 2358  Все добре
# 5104  Цена апаратта
#
#       review_rating  thumbs_up  thumbs_down  \
# 50    5.0            0          0
# 60    5.0            1          0
# 62    5.0            0          1
# 78    5.0            1          0
# 110   5.0            0          0
# 314   3.0            0          0
# 359   4.0            0          0
# 430   5.0            0          0
# 766   5.0            7          3
# 862   4.0            1          18
# 946   5.0            47         4
# 1036  5.0            18         17
# 1308  3.0            0          0
# 1357  5.0            0          1
# 1664  5.0            2          15
# 1794  5.0            0          1
# 1798  5.0            0          0
# 1894  5.0            0          0
# 2202  5.0            0          0
# 2234  5.0            0          0
# 2270  5.0            7          5
# 2414  5.0            2          0
# 2453  5.0            11         2
# 2717  1.0            2          1
# 2852  5.0            0          0
# 2919  5.0            5          12
# 3154  5.0            1          1
# 3162  5.0            0          1
# 3237  5.0            0          0
# 3595  5.0            0          0
# 3600  5.0            0          0
# 3683  5.0            0          0
# 3738  1.0            0          1
# 3778  4.0            0          0
# 3841  2.0            0          0
# 4037  5.0            0          0
# 4196  5.0            1          1
# 4254  4.0            0          0
# 4439  5.0            0          0
# 4566  5.0            0          0
# 4830  5.0            1          0
# 4886  1.0            0          0
# 5046  5.0            0          0
# 5113  5.0            1          0
# 5393  5.0            0          0
# 5445  1.0            0          1
# 5626  4.0            0          0
# 5701  3.0            0          0
# 59    5.0            0          2
# 131   5.0            6          7
# 165   5.0            0          0
# 201   5.0            2          2
# 202   5.0            3          0
# 204   5.0            4          6
# 217   5.0            5          0
# 291   5.0            3          0
# 428   5.0            1          2
# 736   5.0            1          0
# 793   5.0            0          0
# 881   4.0            2          2
# 999   5.0            0          1
# 1227  5.0            4          1
# 1687  5.0            0          0
# 1712  1.0            0          0
# 1751  5.0            1          1
# 1975  5.0            0          0
# 2092  5.0            1          0
# 2202  5.0            0          0
# 2263  5.0            1          0
# 2274  5.0            0          0
# 2303  5.0            4          7
# 2305  5.0            9          18
# 2350  5.0            0          0
# 2358  4.0            5          1
# 5104  3.0            0          0
#
#                                                                                                                                                                                                                                                                                                                                               product_advatages  \
# 50    100% якість зображень.
# 60    NaN
# 62    Его хотят все
# 78    NaN
# 110   Швидка зарядка,хороша камера та екран
# 314   NaN
# 359   NaN
# 430   NaN
# 766   NaN
# 862   Рекомендую
# 946   NaN
# 1036  Стереозвук. Камера sony 64mp . 120 hz екран. 240 hz тач. Акум 5160 міліампер. Цена. Дырка в екраны. Раз'ем для наушныков. Usb Tipe-s. Miui 12. Защита от воды ip 53. Зарядка 33w.
# 1308  Ціна бюджетна. Камера хороша. Швидка реакція.
# 1357  Ціна якість
# 1664  NaN
# 1794  NaN
# 1798  Батареи хватает на 3-4 дня
# 1894  Клевый аппарат,не буду прверять на защиту))),Начинка просто бомба на такие деньги!
# 2202  NaN
# 2234  супер
# 2270  Норм телефон
# 2414  Батарея, 3/64 пам'ять
# 2453  Звук дисплей камера відео продуктивність на ураа
# 2717  NaN
# 2852  NaN
# 2919  NaN
# 3154  Реклама відсутня.
# 3162  NaN
# 3237  NaN
# 3595  NaN
# 3600  NaN
# 3683  NaN
# 3738  Нет
# ...
# 4886  Не берите ! Преймущества: большой, красивый , камера процесор телефон летает но. Недостатки: экран живет периодически своей жизнью, батарея садится очень быстро, у  меня на старом нтс 1300 в 3 раза на дольше хватает
# 5046  Дитина просто щаслива Преймущества: Заряджать 2 рас в тиждні. Недостатки: Немае
# 5113  Дешевле не нашел, купил вполне доволен Преймущества: За эту сумму, отличный телефон. Недостатки: None
# 5393  ПАЦАН ДОВОЛЬНИЙ - БАТЬКО ЩАСЛИВИЙ Преймущества: НАДІЙНИЙ. Недостатки: НЕ ЗНАЙШОВ
# 5445  Через 10 дней после получения телефон завис и не реагирует ни на что. Преймущества: не увидел. Недостатки: Завис
# 5626  ну и зарядка почти безумна по времени Преймущества: телефон прикольный. Недостатки: 11 болтов фиксации ужас
# 5701  До поломки работал отлично без упреков! Преймущества: Доступный по цене!. Недостатки: 8 месяцев и уехал в ремонт!
# 59    Поки все ОК Преймущества: samsung. Недостатки: Ціна
# 131   Приятно что в среднем сегменте добавили 90 Гц экран, влагозащиту IP67 и стереодинамики. Преймущества: None. Недостатки: None
# 165   Брал отцу, отец доволен! Преймущества: Шустрый, батарейка держится отлично.. Недостатки: Не обнаружено
# 201   Телефо0н топ за свои деньги  (Спасибо за конфетки) Преймущества: None. Недостатки: None
# 202   ... Преймущества: Если батарею поставить в средний режим, если через ап гелери не получилось установить приложение тогда через поисковик с робочего стола скачивать надо. В общем все хорошо. и не долго сидеть в телефоне то его хватает на три дня, камера норм, есть ночной режим. Так.... Что ещё... Без гугл сервисов все норм, все приложения скачивают я и работают.. Недостатки: Нет
# 204   5 балов Преймущества: None. Недостатки: None
# 217   Все гуд Преймущества: Лучший. Недостатки: Ну не три копейки
# 291   Не понятно где тут Акция???! Его цена в Yabloki 19700 Преймущества: ios. Недостатки: Нет
# 428   Все супер Преймущества: None. Недостатки: None
# 736   Все отлично ! За свои деньги просто супер  !!! Преймущества: Качественный апарат , хороший дисплей , камера , все работает , ни каких проблем !. Недостатки: Не обнаружил .
# 793   купили ребенку, все отлично работает Преймущества: None. Недостатки: None
# 881   Мажна брати Преймущества: None. Недостатки: Прошивка на любителя ...
# 999   Наконец-то  дождался телефон. Получил телефон 31.03 , заказал и оплатил телефон 31.01 Преймущества: На данный момент все нравиться!!!. Недостатки: None
# 1227  Телефон Тони Старка Преймущества: Все люди как люди - один я бог.  С таким то телефоном. Недостатки: Выпустят ФОЛД 3 и я буду в жуткой депресии
# 1687  За такие деньги топ . Лучше не найдьоте . Преймущества: Живучий телефон прожил полтора года и ещо роботает. Недостатки: Не водопроницаемий
# 1712  Телефон не видит сим-карт! Преймущества: Хороший дизайн, мощная батарея. Недостатки: Не видит сим-карт!
# 1751  Дочка дуже задоволена. Щиро дякую Преймущества: Все працює на відмінно. Недостатки: Відсутні
# 1975  Топ Преймущества: None. Недостатки: None
# 2092  Я доволен:) Преймущества: Цена. Недостатки: Пока нет
# 2202  Телефон ракета Преймущества: Память 128гб. Недостатки: Скользкий
# 2263  ТЕЛЕФОН ДОСТОЙНИЙ СВОЇХ ГРОШЕЙ . НЕ ЗАВИСАЄ , ШВИДКО РЕАГУЄ . ТЕЛЕФОН ВЖЕ 2 РІК, СЛУЖИТЬ ДОБРЕ !! Преймущества: None. Недостатки: Немає
# 2274  Xiaomi Redmi Note 8 Pro 6/64 Преймущества: Всё на уровне! За эти деньги мощный и качественный смартфон!. Недостатки: Не обнаружено
# 2303  Все просто супер)) Преймущества: None. Недостатки: None
# 2305  iPhone Преймущества: Всем известны. Недостатки: Всем известны
# 2350  Купила и не пожалела Преймущества: Камера. Недостатки: Фонит на громкой связи
# 2358  Все добре Преймущества: Екран камера.... Недостатки: БАТАРЕЯ
# 5104  Цена апаратта Преймущества: None. Недостатки: None
#
#         price_segments  lang
# 50    2. above_average  mk
# 60    3.expensive       mk
# 62    3.expensive       bg
# 78    2. above_average  None
# 110   3.expensive       mk
# 314   0.cheap           bg
# 359   1.below_average   mk
# 430   1.below_average   bg
# 766   3.expensive       mk
# 862   3.expensive       bg
# 946   3.expensive       bg
# 1036  2. above_average  bg
# 1308  1.below_average   bg
# 1357  1.below_average   mk
# 1664  3.expensive       bg
# 1794  2. above_average  mk
# 1798  2. above_average  bg
# 1894  3.expensive       mk
# 2202  1.below_average   mk
# 2234  1.below_average   None
# 2270  2. above_average  bg
# 2414  1.below_average   bg
# 2453  1.below_average   mk
# 2717  0.cheap           bg
# 2852  3.expensive       mk
# 2919  3.expensive       mk
# 3154  3.expensive       bg
# 3162  1.below_average   bg
# 3237  1.below_average   bg
# 3595  0.cheap           bg
# 3600  0.cheap           sk
# 3683  0.cheap           bg
# 3738  0.cheap           bg
# 3778  1.below_average   mk
# 3841  0.cheap           mk
# 4037  3.expensive       bg
# 4196  2. above_average  sv
# 4254  0.cheap           bg
# 4439  2. above_average  mk
# 4566  3.expensive       bg
# 4830  1.below_average   mk
# 4886  0.cheap           mk
# 5046  1.below_average   bg
# 5113  0.cheap           mk
# 5393  0.cheap           bg
# 5445  0.cheap           bg
# 5626  1.below_average   bg
# 5701  0.cheap           bg
# 59    3.expensive       bg
# 131   3.expensive       bg
# 165   1.below_average   bg
# 201   2. above_average  mk
# 202   2. above_average  None
# 204   3.expensive       mk
# 217   3.expensive       mk
# 291   3.expensive       bg
# 428   2. above_average  mk
# 736   1.below_average   mk
# 793   1.below_average   mk
# 881   3.expensive       mk
# 999   3.expensive       bg
# 1227  3.expensive       bg
# 1687  1.below_average   bg
# 1712  1.below_average   bg
# 1751  1.below_average   bg
# 1975  0.cheap           bg
# 2092  2. above_average  bg
# 2202  2. above_average  bg
# 2263  2. above_average  bg
# 2274  2. above_average  pt
# 2303  3.expensive       mk
# 2305  3.expensive       en
# 2350  2. above_average  mk
# 2358  3.expensive       mk
# 5104  0.cheap           bg

# %% [markdown]
# *From inspecting the table above we can make conclusion that language for some records was not detected correctly: some reviews in Russian and Ukrainian were wrongly classified as other languages (Bulgarian, Macedonian, Rumanian, etc).
# Since the fraction of misclassified records is nor significant, we still can conclude that about ¾ of all reviews are written in Russian and ¼ in Ukrainian languages.*

# %% [markdown]
# ## review_text exploration - Unigrams, Bigrams, Trigrams

# %% [markdown]
# In this section we will explore the most common words and phrases in the review_text column for positive and negative reviews.  To do so we will create the new column review_sentiment which will correspond to the value “1” for positive reviews (with 4 and 5 stars) and “0” for negative reviews (with 1, 2 and 3 stars).

# %%
#Create review_sentiment to show negative and positive reviews
data_wth_rating.loc[(data_wth_rating['review_rating']==1)|(data_wth_rating['review_rating']==2)|(data_wth_rating['review_rating']==3), 'review_sentiment'] = '0' 
data_wth_rating.loc[(data_wth_rating['review_rating']==4)|(data_wth_rating['review_rating']==5), 'review_sentiment'] = '1'

#Drop rows with NA values for review_text
review_text_clean = pd.DataFrame(data_wth_rating.dropna(subset = ['review_text']))

#Create boolean masks to filter negative and positive reviews 
negative_rev = review_text_clean['review_sentiment'] == '0'
positive_rev = review_text_clean['review_sentiment'] == '1'

#Create STOPWORDS list: take pre-made lists in russian and ukrainian and complement them
STOPWORDS_ukr = adv.stopwords['ukrainian']
STOPWORDS_rus = adv.stopwords['russian']
STOPWORDS = STOPWORDS_ukr.union(STOPWORDS_rus)
STOPWORDS = STOPWORDS.union(['-', 'і', ",", "1", "2", "3", "4", "5", "6", "7", "8", "9", "телефон", "—", ".", "под", "10", "телефон", "телефон,", "смартфон"])

#Fuction to create ngrams
def generate_ngrams(text, n_gram=1):
    token = [token for token in text.lower().split(' ') if token != '' if token not in STOPWORDS]
    ngrams = zip(*[token[i:] for i in range(n_gram)])
    return [' '.join(ngram) for ngram in ngrams]

#Number of records to show in plot
N = 10

#Function to genarate plots with ngrams
def create_view_of_n_grams(n_gram):
    ###Takes number of n_gram to show n_grams of review_text for negative and positive reviews
    positive_unigrams = {}
    negative_unigrams = {}

    for rev in review_text_clean[negative_rev]['review_text']:
        for word in generate_ngrams(rev, n_gram=n_gram):
            try:
                negative_unigrams[word] += 1
            except:
                negative_unigrams[word] =1
        

    for rev in review_text_clean[positive_rev]['review_text']:
        for word in generate_ngrams(rev, n_gram=n_gram):
            try:
                positive_unigrams[word] += 1
            except:
                positive_unigrams[word] =1
        
    df_neg = pd.DataFrame(sorted(negative_unigrams.items(), key=lambda x: x[1])[::-1])
    df_pos = pd.DataFrame(sorted(positive_unigrams.items(), key=lambda x: x[1])[::-1])

    
    fig, axes = plt.subplots(ncols=2, figsize=(18, 10), dpi=45)
    plt.tight_layout()

    sns.barplot(y=df_neg[0].values[:N], x=df_neg[1].values[:N], ax=axes[0], color='red')
    sns.barplot(y=df_pos[0].values[:N], x=df_pos[1].values[:N], ax=axes[1], color='green')
    for i in range(2):
        axes[i].spines['right'].set_visible(False)
        axes[i].set_xlabel('')
        axes[i].set_ylabel('')
        axes[i].tick_params(axis='x', labelsize=13)
        axes[i].tick_params(axis='y', labelsize=13)

    axes[0].set_title(f'Top {N} most common {n_gram}-grams in negative reviews', fontsize=15)
    axes[1].set_title(f'Top {N} most common {n_gram}-grams in positive reviews', fontsize=15)
        
    plt.show()

# %%
#View Unigrams, Bigrams, Trigrams
create_view_of_n_grams(1)
create_view_of_n_grams(2)
create_view_of_n_grams(3)

# %% [markdown]
# *From the generated plots we can see that unigrams are pretty similar for negative and plosive reviews, while bigrams and trigrams differ much more and also make much more sense as they catch more context from the text.*
#
# *In case of using these features in modeling it’s advisable to explore most common unigrams in more depth.
# Possibly it’s better to use only bigrams and trigrams as features for modeling as unigrams might not capture the context of positive or negative sentiment.*

# %% [markdown]
# ##  review_text - Meta Features analysis
# Lets have a look at meta Features of review_text:
# - word_count - number of words in text
# - unique_word_count - number of unique words in text
# - stop_word_count - number of stop words in text
# - mean_word_length - average character count in words
# - char_count - number of characters in text
# - punctuation_count - number of punctuations in text
# - stop_word_count - number of stopwords in text

# %%
#Define Function to calculate Meta Features
punctuation = ['#', '@', '!', '?', '+', '&', '-', '$', '=', '<', '>', '|', '{', '}', '^', "'", '(', ')' , '[', ']', '*', '%', '...', "'", ".", ':', ';']
def calculate_meta_features (dataframe, text_column):
### This function adds text meta_features to dataframe: word_count, unique_word_count, stop_word_count, mean_word_length, char_count, punctuation_count, stop_word_count
### Function has two arguments:
### - dataframe - dataframe to analyse,it has to contain text for analysis,  
### - text_column - name of the column for which to calculate meta features.
    # word_count
    dataframe.loc[:, 'word_count_{}'.format(text_column)] = dataframe[text_column].apply(lambda x: len(str(x).split()))
    # unique_word_count
    dataframe.loc[:, 'unique_word_count_{}'.format(text_column)] = dataframe[text_column].apply(lambda x: len(set(str(x).split())))
    # mean_word_length
    dataframe.loc[:, 'mean_word_length_{}'.format(text_column)] = dataframe[text_column].apply(lambda x: np.mean([len(w) for w in str(x).split()]))
    # char_count
    dataframe.loc[:, 'char_count_{}'.format(text_column)] = dataframe[text_column].apply(lambda x: len(str(x)))
    # punctuation_count
    dataframe.loc[:, 'punctuation_count_{}'.format(text_column)] = dataframe[text_column].apply(lambda x: len([c for c in str(x) if c in punctuation]))
    # stop_word_count
    dataframe.loc[:, 'stop_word_count_{}'.format(text_column)] = dataframe[text_column].apply(lambda x: len([w for w in str(x).lower().split() if w in STOPWORDS]))

#Calculate Meta Features of review_text using function
calculate_meta_features(review_text_clean, 'review_text')

# %%
review_text_clean.head()
# Out:
#                                                                                                  comment_link  \
# 1  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49190491
# 2  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49299159
# 5  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49228123
# 6  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49212385
# 8  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49285480
#
#                                                                                                                  product_title  \
# 1   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 2   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 5   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 6   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 8   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
#
#    product_price  review_id review_date  \
# 1  39999.0        49190491  2021-02-04
# 2  39999.0        49299159  2021-02-14
# 5  39999.0        49228123  2021-02-08
# 6  39999.0        49212385  2021-02-06
# 8  39999.0        49285480  2021-02-12
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              review_text  \
# 1  Датчик адаптивной яркости работает не корректно в темноте дисплей светит на 90 процентов. Когда тресешь телефон раздается звук как будто внутри что то отвалилось, до этого s9 plus таких проблем не было, да Самсунг уже не тот))
# 2  Я не буду расписывать плюсы телефона - о них можно почитать в обзорах. Поэтому напишу о том, почему лично у меня с телефоном пока не сложились отношения. Отпечаток пальца работает плохо. То срабатывает без проблем, то с 5й попытки не желает. Камера – неплохо, но не очень нравится постобработка - она придает любой фотографии неестественные, перенасыщенные цвета. После активного часа игры в Асфальт 9 телефон перегревается и игра вылетает. Поэтому в чем прикол нового эксиноса я не поняла.Телефон слишком длинный. Ок, я могу прочесть на одну строчку больше текста, но за счет этого телефон габаритный, пальцем не достать до центра экрана, а ряд приложений не поддерживают такую длину. Сам девайс в руках довольно скользкий, поэтому придется покупать чехол. Кстати, похоже, что при создании чехлов устроили соревнование - кто придумает максимально уродливый и неудобный чехол. В результате все идеи номинантов были реализованы. Так что в целом, удовольствия от пользования телефоном у меня нет.
# 5  Не опубликован мой отзыв.Значит телефон г
# 6  За эти деньги телефон должен быть не просто телефоном, но на деле ничего кроме камеры не получить.Камера хороша, корпус глянец и держать без чехла очень тяжело, хуже было только с пиксель 4.Размер телефона явно слишком велик. Ни о какой женской ручке и речи быть не может, спасает только режим уменьшения экрана для одной руки.Кроме эффекта "вау я потратил на это 1500 баксов" телефон не вызывает особо ощущений.Работает по началу как и все китайцы - быстро. Экран яркий, но не сказал бы что это особо заметно, хоть и имеет 1500 Нит яркость.Как игрушка на пару недель, а дальше неудобный Лопатник.Разве что наушники бадс про порадовали звучанием и шумодавом.Перезагрузил перед сном его, а на утро он как грелка горячий и где-то 30% аккумулятора ушло. Не знаю что это было.Спасибо что в комплекте хоть телефон есть. Зарядки нет, кабель тайп-с на тайп-с. Вот зачем надо такой вариант? Если все ещё пользуются тайп на юсб.Просто выкинутый на ветер кабель.Бестрая зарядка qc3.0 даёт где-то 3-3.5ампера зарядки. Зарядка где-то часа 2 при этом.Доволен? Ну так себе...
# 8  Очень нравиться samsung тем что оставили изогнутый экран. Пожалуйста учтите этот отзыв)
#
#    review_rating  thumbs_up  thumbs_down  \
# 1  2.0            3          2
# 2  3.0            3          0
# 5  1.0            5          7
# 6  3.0            2          0
# 8  5.0            0          1
#
#                                                                                                                     product_advatages  \
# 1  от других флагманских телефонов нет
# 2  Камера, батарея
# 5  NaN
# 6  Камера Обратная зарядка устройств Понты для самого себя  Аккумулятор (держит 2 дня без игр)  "Подарочные" наушники бадс про хороши
# 8  NaN
#
#                                                                                                                                                 product_disadvantages  \
# 1  дисплей, при тряске шум
# 2  Сканер отпечатка, эргономичность, аксессуары
# 5  NaN
# 6  - Размер- Корпус из супер скользкого материала- толстый как я- Доктилоскоп под экраном не очень- Огромная цена. - Передняя камера для разблокировки по лицу ужасна
# 8  NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 full_text  \
# 1  Датчик адаптивной яркости работает не корректно в темноте дисплей светит на 90 процентов. Когда тресешь телефон раздается звук как будто внутри что то отвалилось, до этого s9 plus таких проблем не было, да Самсунг уже не тот)) Преймущества: от других флагманских телефонов нет. Недостатки: дисплей, при тряске шум
# 2  Я не буду расписывать плюсы телефона - о них можно почитать в обзорах. Поэтому напишу о том, почему лично у меня с телефоном пока не сложились отношения. Отпечаток пальца работает плохо. То срабатывает без проблем, то с 5й попытки не желает. Камера – неплохо, но не очень нравится постобработка - она придает любой фотографии неестественные, перенасыщенные цвета. После активного часа игры в Асфальт 9 телефон перегревается и игра вылетает. Поэтому в чем прикол нового эксиноса я не поняла.Телефон слишком длинный. Ок, я могу прочесть на одну строчку больше текста, но за счет этого телефон габаритный, пальцем не достать до центра экрана, а ряд приложений не поддерживают такую длину. Сам девайс в руках довольно скользкий, поэтому придется покупать чехол. Кстати, похоже, что при создании чехлов устроили соревнование - кто придумает максимально уродливый и неудобный чехол. В результате все идеи номинантов были реализованы. Так что в целом, удовольствия от пользования телефоном у меня нет. Преймущества: Камера, батарея. Недостатки: Сканер отпечатка, эргономичность, аксессуары
# 5  Не опубликован мой отзыв.Значит телефон г Преймущества: None. Недостатки: None
# 6  За эти деньги телефон должен быть не просто телефоном, но на деле ничего кроме камеры не получить.Камера хороша, корпус глянец и держать без чехла очень тяжело, хуже было только с пиксель 4.Размер телефона явно слишком велик. Ни о какой женской ручке и речи быть не может, спасает только режим уменьшения экрана для одной руки.Кроме эффекта "вау я потратил на это 1500 баксов" телефон не вызывает особо ощущений.Работает по началу как и все китайцы - быстро. Экран яркий, но не сказал бы что это особо заметно, хоть и имеет 1500 Нит яркость.Как игрушка на пару недель, а дальше неудобный Лопатник.Разве что наушники бадс про порадовали звучанием и шумодавом.Перезагрузил перед сном его, а на утро он как грелка горячий и где-то 30% аккумулятора ушло. Не знаю что это было.Спасибо что в комплекте хоть телефон есть. Зарядки нет, кабель тайп-с на тайп-с. Вот зачем надо такой вариант? Если все ещё пользуются тайп на юсб.Просто выкинутый на ветер кабель.Бестрая зарядка qc3.0 даёт где-то 3-3.5ампера зарядки. Зарядка где-то часа 2 при этом.Доволен? Ну так себе... Преймущества: Камера Обратная зарядка устройств Понты для самого себя  Аккумулятор (держит 2 дня без игр)  "Подарочные" наушники бадс про хороши. Недостатки: - Размер- Корпус из супер скользкого материала- толстый как я- Доктилоскоп под экраном не очень- Огромная цена. - Передняя камера для разблокировки по лицу ужасна
# 8  Очень нравиться samsung тем что оставили изогнутый экран. Пожалуйста учтите этот отзыв) Преймущества: None. Недостатки: None
#
#   price_segments review_sentiment  word_count_review_text  \
# 1  3.expensive    0                37
# 2  3.expensive    0                152
# 5  3.expensive    0                6
# 6  3.expensive    0                170
# 8  3.expensive    1                12
#
#    unique_word_count_review_text  mean_word_length_review_text  \
# 1  35                             5.135135
# 2  128                            5.546053
# 5  6                              6.000000
# 6  137                            5.247059
# 8  12                             6.333333
#
#    char_count_review_text  punctuation_count_review_text  \
# 1  226                     3
# 2  994                     16
# 5  41                      1
# 6  1061                    32
# 8  87                      2
#
#    stop_word_count_review_text
# 1  15
# 2  59
# 5  4
# 6  66
# 8  3

# %%
#Plot meta features distribution in relation to Target variable - Review rating
fig, axes = plt.subplots(6, figsize=(18,35))
for count, column in enumerate(['word_count_review_text', 'unique_word_count_review_text', 'mean_word_length_review_text', 'char_count_review_text', 'punctuation_count_review_text', 'stop_word_count_review_text']):
    sns.kdeplot(ax = axes[count], data=review_text_clean[review_text_clean['review_rating'] == 1.0][column], shade=False, color='red', label ='1 star')
    sns.kdeplot(ax = axes[count], data=review_text_clean[review_text_clean['review_rating'] == 2.0][column], shade=False, color='orange', label ='2 stars')
    sns.kdeplot(ax = axes[count], data=review_text_clean[review_text_clean['review_rating'] == 3.0][column], shade=False, color='black', label ='3 stars')
    sns.kdeplot(ax = axes[count], data=review_text_clean[review_text_clean['review_rating'] == 4.0][column], shade=False, color='blue', label ='4 stars')
    sns.kdeplot(ax = axes[count], data=review_text_clean[review_text_clean['review_rating'] == 5.0][column], shade=False, color='green', label ='5 stars')
    axes[count].set_title('{} of review_text Rating distribution'.format(column))
fig.tight_layout()

# %% [markdown]
# *From the plots we can see that distribution of almost all meta features of review_text slightly differ for reviews with different rating.*
#
# *But generated plots look pretty cluttered, let’s simplify them by displaying distribution of review_text meta features only for negative and positive reviews.*

# %%
#Plot meta features distribution in relation to simplified Target variable - Review rating
fig, axes = plt.subplots(6, figsize=(18,35))
for count, column in enumerate(['word_count_review_text', 'unique_word_count_review_text', 'mean_word_length_review_text', 'char_count_review_text', 'punctuation_count_review_text', 'stop_word_count_review_text']):
    sns.kdeplot(ax = axes[count], data=review_text_clean[review_text_clean['review_sentiment'] == '0'][column], shade=False, color='red', label ='negative')
    sns.kdeplot(ax = axes[count], data=review_text_clean[review_text_clean['review_sentiment'] == '1'][column], shade=False, color='green', label ='positive')
    axes[count].set_title('{} of review_text Sentiment distribution'.format(column))
fig.tight_layout()

# %% [markdown]
# *Distributions of majority of meta features are slightly different for reviews with negative and positive sentiment. These features can be helpful in modeling stage.*

# %% [markdown]
# ##  product_advatages - Meta Features analysis

# %%
#Lets remove rows with empty product_advatages and calculate meta features
product_advatages_clean = pd.DataFrame(data_wth_rating.dropna(subset = ['product_advatages']))

#Calculate Meta Features of product_advatages using function calculate_meta_features
calculate_meta_features(product_advatages_clean, 'product_advatages')

#Plot meta features distribution in relation to  simplified Target variable - Review rating
fig, axes = plt.subplots(6, figsize=(18,35))
for count, column in enumerate(['word_count_product_advatages', 'unique_word_count_product_advatages', 'mean_word_length_product_advatages', 'char_count_product_advatages', 'punctuation_count_product_advatages', 'stop_word_count_product_advatages']):
    sns.kdeplot(ax = axes[count], data=product_advatages_clean[product_advatages_clean['review_sentiment'] == '0'][column], shade=False, color='red', label ='negative')
    sns.kdeplot(ax = axes[count], data=product_advatages_clean[product_advatages_clean['review_sentiment'] == '1'][column], shade=False, color='green', label ='positive')
    axes[count].set_title('{} of product_advatages Sentiment distribution'.format(column))
fig.tight_layout()

# %% [markdown]
# *Distributions of majority of meta features are different for negative and positive reviews. punctuation_count and stop_word_count might be not good enough, but other features can be helpful in modeling stage.*

# %% [markdown]
# ##  product_disadvantages - Meta Features analysis

# %%
#Lets remove rows with empty product_disadvantages and calculate meta features
product_disadvantages_clean = pd.DataFrame(data_wth_rating.dropna(subset = ['product_disadvantages']))

#Calculate Meta Features of product_disadvantages using function calculate_meta_features
calculate_meta_features(product_disadvantages_clean, 'product_disadvantages')

#Plot meta features distribution in ralation to  simplified Target variable - Review rating
fig, axes = plt.subplots(6, figsize=(18,35))
for count, column in enumerate(['word_count_product_disadvantages', 'unique_word_count_product_disadvantages', 'mean_word_length_product_disadvantages', 'char_count_product_disadvantages', 'punctuation_count_product_disadvantages', 'stop_word_count_product_disadvantages']):
    sns.kdeplot(ax = axes[count], data=product_disadvantages_clean[product_disadvantages_clean['review_sentiment'] == '0'][column], shade=False, color='red', label ='negative')
    sns.kdeplot(ax = axes[count], data=product_disadvantages_clean[product_disadvantages_clean['review_sentiment'] == '1'][column], shade=False, color='green', label ='positive')
    axes[count].set_title('{} of product_disadvantages Sentiment distribution'.format(column))
fig.tight_layout()

# %% [markdown]
# *Distributions of all meta features are different for negative and positive reviews. These features can be helpful in modeling stage.*

# %% [markdown]
# # Step 3: Biulding prediction model with BERT

# %% [markdown]
# For this project of text classification by predicting review sentiment it’s suggested to use the BERT model (Bidirectional Encoder Representations from Transformers).
#
# Nowadays it is a very popular model which currently provides outstanding results in text processing because of it bidirectional approach and allows to have a deeper sense of language context and flow than single-direction language models.
#
# To build the model we will use Ktrain - a lightweight wrapper for TensorFlow.Keras and many other libraries, which will allow to use state-of-the-art machine learning model with much fewer coding required.

# %% [markdown]
# ## Preprocessing: Drop rows with missing values

# %%
#Drop rows without rating to train the model on labels data
data_clean = data.dropna(subset = ['review_rating'])

#Drop rows without review_text, product_advatages, product_disadvantages as for these rows we don't have enough information to make prediction
data_clean = data_clean.dropna(subset = ['full_text'])

data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3807 entries, 1 to 5104
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   comment_link           3807 non-null   object
#  1   product_title          3807 non-null   object
#  2   product_price          3807 non-null   float64
#  3   review_id              3807 non-null   int64
#  4   review_date            3807 non-null   datetime64[ns]
#  5   review_text            3752 non-null   object
#  6   review_rating          3807 non-null   float64
#  7   thumbs_up              3807 non-null   int64
#  8   thumbs_down            3807 non-null   int64
#  9   product_advatages      2912 non-null   object
#  10  product_disadvantages  2831 non-null   object
#  11  full_text              3807 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 386.6+ KB

# %%
#Check rows with empty review_text, product_advatages, product_disadvantages   
data_clean[data_clean.review_text.isna()&(data_clean.product_advatages.isna()&data_clean.product_disadvantages.isna())]
# Out:
# Empty DataFrame
# Columns: [comment_link, product_title, product_price, review_id, review_date, review_text, review_rating, thumbs_up, thumbs_down, product_advatages, product_disadvantages, full_text]
# Index: []

# %%
#Check rows with empty review text, but not empty product_advatages, product_disadvantages to see if there is enough information for model training
data_clean[data_clean.review_text.isna()&(data_clean.product_advatages.notna()|data_clean.product_disadvantages.notna())]
# Out:
#                                                                                              comment_link  \
# 69    https://rozetka.com.ua/ua/apple_iphone_12_64gb_product_red/p245162161/comments/#id=48625332
# 256   https://rozetka.com.ua/ua/motorola_page0015rs/p245661253/comments/#id=49338573
# 390   https://rozetka.com.ua/ua/xiaomi_redmi_note_9_3_64gb_midnight_grey/p209754337/comments/#id=49217106
# 821   https://rozetka.com.ua/ua/apple_mhdm3/p260937056/comments/#id=49268094
# 1291  https://rozetka.com.ua/ua/meizu_m6t_2_16gb_black_106738/p111954806/comments/#id=45315357
# 1301  https://rozetka.com.ua/ua/vivo_y1s_2_32gb_black/p237030031/comments/#id=49385707
# 1944  https://rozetka.com.ua/ua/71671101/p71671101/comments/#id=44725464
# 1959  https://rozetka.com.ua/ua/55904076/p55904076/comments/#id=39592455
# 1975  https://rozetka.com.ua/ua/28782137/p28782137/comments/#id=36964164
# 2105  https://rozetka.com.ua/ua/samsung_galaxy_m31_6_128gb_blue/p175401451/comments/#id=46321174
# 2182  https://rozetka.com.ua/ua/apple_iphone_11_pro_max_64gb_space_gray/p137227775/comments/#id=46893508
# 2224  https://rozetka.com.ua/ua/nokia_2_3_2_32gb_black/p159096638/comments/#id=48945253
# 2226  https://rozetka.com.ua/ua/nokia_2_3_2_32gb_black/p159096638/comments/#id=48889811
# 2437  https://rozetka.com.ua/ua/apple_iphone_11_pro_64gb_space_gray/p135813894/comments/#id=49023157
# 2618  https://rozetka.com.ua/ua/realme_c3_2_32gb_blue/p210636577/comments/#id=48575739
# 2715  https://rozetka.com.ua/ua/2e_e450a_2018_dualsim_black/p51927996/comments/#id=47338989
# 2864  https://rozetka.com.ua/ua/huawei_p30_aurora/p76639638/comments/#id=47152986
# 3286  https://rozetka.com.ua/ua/tecno_camon_12_air_cc6_bay_blue/p142151745/comments/#id=46593624
# 3363  https://rozetka.com.ua/ua/zte_blade_v10_vita_3_64gb_green/p99194710/comments/#id=44621698
# 3365  https://rozetka.com.ua/ua/assistant_as_502_shot_black/p32105951/comments/#id=47310010
# 3443  https://rozetka.com.ua/ua/zte_blade_a5_2_32gb_black/p213750829/comments/#id=47209280
# 3587  https://rozetka.com.ua/ua/tecno_pouvoir_2_la7_pro_gold/p55399962/comments/#id=44433797
# 3627  https://rozetka.com.ua/ua/prestigio_psp3515duoblack/p63313990/comments/#id=49209761
# 3633  https://rozetka.com.ua/ua/tecno_4895180747427/p102580422/comments/#id=48492587
# 3649  https://rozetka.com.ua/ua/doogee_y7_obsidian_black/p70934534/comments/#id=46589710
# 3753  https://rozetka.com.ua/ua/impression_imsmart_c571/p18132564/comments/#id=44549436
# 4096  https://rozetka.com.ua/ua/117931855/p117931855/comments/#id=44547856
# 4234  https://rozetka.com.ua/ua/xiaomi_redmi_note_9s_6_128gb_grey/p204698749/comments/#id=46321211
# 4301  https://rozetka.com.ua/ua/107415330/p107415330/comments/#id=44220887
# 4421  https://rozetka.com.ua/ua/71671107/p71671107/comments/#id=45431142
# 4433  https://rozetka.com.ua/ua/55909158/p55909158/comments/#id=44741136
# 4436  https://rozetka.com.ua/ua/55909158/p55909158/comments/#id=45008030
# 4510  https://rozetka.com.ua/ua/68057099/p68057099/comments/#id=45355356
# 4593  https://rozetka.com.ua/ua/51610266/p51610266/comments/#id=35848512
# 4674  https://rozetka.com.ua/ua/91537100/p91537100/comments/#id=44379522
# 4721  https://rozetka.com.ua/ua/73796121/p73796121/comments/#id=44700828
# 4984  https://rozetka.com.ua/ua/66806117/p66806117/comments/#id=44482280
# 5019  https://rozetka.com.ua/ua/58997710/p58997710/comments/#id=44275831
# 5108  https://rozetka.com.ua/ua/63393419/p63393419/comments/#id=38110076
# 5136  https://rozetka.com.ua/ua/47509400/p47509400/comments/#id=37574187
# 5152  https://rozetka.com.ua/ua/65289378/p65289378/comments/#id=34131028
# 5165  https://rozetka.com.ua/ua/71661723/p71661723/comments/#id=39550881
# 5203  https://rozetka.com.ua/ua/71336518/p71336518/comments/#id=40108920
# 5267  https://rozetka.com.ua/ua/55908756/p55908756/comments/#id=33827572
# 5375  https://rozetka.com.ua/ua/32906919/p32906919/comments/#id=36844604
# 5405  https://rozetka.com.ua/ua/58659226/p58659226/comments/#id=44430591
# 5428  https://rozetka.com.ua/ua/google_pixel_3a_4_64gb_just_black/p211122481/comments/#id=44560668
# 5516  https://rozetka.com.ua/ua/63748480/p63748480/comments/#id=44024989
# 5695  https://rozetka.com.ua/ua/32907007/p32907007/comments/#id=43029830
# 10    https://rozetka.com.ua/ua/samsung_galaxy_a52_8_256gb_lavender/p280539218/comments/#id=49618692
# 259   https://rozetka.com.ua/ua/tecno_camon_16_se_6_128gb_cloud_white/p277699053/comments/#id=49402422
# 1755  https://rozetka.com.ua/ua/xiaomi_redmi_9_3_32gb_carbon_grey_global/p256344911/comments/#id=49791000
# 1981  https://rozetka.com.ua/ua/tecno_4895180760280/p235254139/comments/#id=49571361
# 2012  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49732582
# 2319  https://rozetka.com.ua/ua/samsung_sm_a515fzbusek/p168809096/comments/#id=49632860
#
#                                                                                product_title  \
# 69     Мобільний телефон Apple iPhone 12 64GB PRODUCT Red Офіційна гарантія
# 256    Мобільний телефон Motorola G8 Plus 4/64GB Cosmic Blue (PAGE0015RS)
# 390    Мобільний телефон Xiaomi Redmi Note 9 3/64GB Midnight Grey
# 821    Мобільний телефон Apple iPhone 11 128 GB Purple Slim Box (MHDM3) Офіційна гарантія
# 1291   Мобільний телефон Meizu M6T 2/16GB Black
# 1301   Мобільний телефон Vivo Y1S 2/32 GB Black
# 1944   Мобильный телефон Doogee S60 Lite 4/32GB Black
# 1959   Захищений Land rover X18 orang 2+16GB
# 1975   Land rover G1 Green
# 2105   Мобільний телефон Samsung Galaxy M31 6/128GB Blue (SM-M315FZBVSEK)
# 2182   Мобільний телефон Apple iPhone 11 Pro Max 64GB Space Gray Офіційна гарантія
# 2224   Мобільний телефон Nokia 2.3 2/32GB Charcoal
# 2226   Мобільний телефон Nokia 2.3 2/32GB Charcoal
# 2437   Мобільний телефон Apple iPhone 11 Pro 64GB Space Gray Офіційна гарантія
# 2618   Мобільний телефон Realme C3 2/32GB Blue
# 2715   Мобільний телефон 2E E450A 2018 DualSim Black
# 2864   Мобільний телефон Huawei P30 6/128GB Aurora
# 3286   Мобільний телефон Tecno Camon 12 Air (CC6) Bay Blue
# 3363   Мобільний телефон ZTE Blade V10 Vita 3/64GB Green
# 3365   Мобільний телефон Assistant AS-502 Shot Black
# 3443   Мобільний телефон ZTE Blade A5 2/32GB Black
# 3587   Мобільний телефон Tecno Pouvoir 2 Pro 3/16GB (LA7 pro) DualSim Champagne Gold
# 3627   Мобільний телефон Prestigio Muze U3 LTE Black (PSP3515DUOBLACK)
# 3633   Мобільний телефон Tecno POP 2 Power (B1P) 1/16GB DualSim City Blue
# 3649   Мобільний телефон Doogee Y7 Obsidian Black
# 3753   Мобільний телефон Impression ImSmart С571
# 4096   Мобільний телефон Blackview BV9700 (6+128Gb) Pro Black
# 4234   Мобільний телефон Xiaomi Redmi Note 9S 6/128GB Interstellar Grey (Міжнародна версія)
# 4301   Blackview BV1000 Black-Green
# 4421   Мобильный телефон Doogee S80 Black
# 4433   Blackview BV6000 Yellow
# 4436   Blackview BV6000 Yellow
# 4510   DOOGEE BL9000 Silver
# 4593   Maze Alpha X 6/64GB Black
# 4674   Мобільний телефон Aelion i8 (2+16Gb) Blue
# 4721   Мобильный телефон Doogee BL5500 Lite Blue (6924351668013)
# 4984   Мобільний телефон Homtom S12 Black
# 5019   Homtom HT70 Black 4/64GB 10000mAh
# 5108   DOOGEE X5 Pro Black
# 5136   Doogee T3 Коричневий
# 5152   Assistant AS-5412 Max Gold (000000201)
# 5165   Смартфон QUMO QUEST 503 white
# 5203   Leagoo T5 Золотий
# 5267   Oukitel K6000 Білий
# 5375   Мобільний телефон Doogee X5 Max White
# 5405   Смартфон Doogee X10S 1/8GB Black
# 5428   Мобільний телефон Google Pixel 3a 4/64GB Just Black
# 5516   Ulefone Armor 5 Black (111899)
# 5695   Мобільний телефон Doogee X9 Pro White
# 10     Мобільний телефон Samsung Galaxy A52 8/256 GB Lavender
# 259    Мобільний телефон Tecno Camon 16 SE 6/128 GB Cloud White
# 1755   Мобільний телефон Xiaomi Redmi 9 3/32GB Carbon Grey (Міжнародна версія)
# 1981   Мобільний телефон Tecno Spark 5 Pro 4/128GB Orange (4895180760280)
# 2012   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 2319   Мобільний телефон Samsung Galaxy A51 4/64GB Blue (SM-A515FZBUSEK)
#
#       product_price  review_id review_date review_text  review_rating  \
# 69    28999.0        48625332  2020-12-18   NaN         5.0
# 256   4999.0         49338573  2021-02-18   NaN         2.0
# 390   4799.0         49217106  2021-02-07   NaN         5.0
# 821   23999.0        49268094  2021-02-11   NaN         5.0
# 1291  2699.0         45315357  2020-01-24   NaN         5.0
# 1301  3199.0         49385707  2021-02-22   NaN         5.0
# 1944  3599.0         44725464  2019-11-13   NaN         4.0
# 1959  2299.0         39592455  2019-03-03   NaN         4.0
# 1975  2799.0         36964164  2019-01-02   NaN         4.0
# 2105  7299.0         46321174  2020-05-12   NaN         5.0
# 2182  30999.0        46893508  2020-07-10   NaN         5.0
# 2224  2799.0         48945253  2021-01-15   NaN         1.0
# 2226  2799.0         48889811  2021-01-11   NaN         4.0
# 2437  31999.0        49023157  2021-01-21   NaN         3.0
# 2618  3399.0         48575739  2020-12-15   NaN         5.0
# 2715  1249.0         47338989  2020-08-16   NaN         1.0
# 2864  14999.0        47152986  2020-07-25   NaN         5.0
# 3286  3199.0         46593624  2020-06-08   NaN         2.0
# 3363  2599.0         44621698  2019-10-28   NaN         4.0
# 3365  999.0          47310010  2020-08-12   NaN         1.0
# 3443  2199.0         47209280  2020-07-31   NaN         3.0
# 3587  2799.0         44433797  2019-09-28   NaN         5.0
# 3627  2199.0         49209761  2021-02-06   NaN         1.0
# 3633  1399.0         48492587  2020-12-09   NaN         5.0
# 3649  2499.0         46589710  2020-06-08   NaN         1.0
# 3753  1699.0         44549436  2019-10-16   NaN         1.0
# 4096  7699.0         44547856  2019-10-16   NaN         5.0
# 4234  5599.0         46321211  2020-05-12   NaN         5.0
# 4301  1299.0         44220887  2019-08-27   NaN         4.0
# 4421  7500.0         45431142  2020-02-08   NaN         5.0
# 4433  4499.0         44741136  2019-11-15   NaN         5.0
# 4436  4499.0         45008030  2019-12-16   NaN         4.0
# 4510  5486.0         45355356  2020-01-29   NaN         1.0
# 4593  5049.0         35848512  2018-12-10   NaN         4.0
# 4674  1649.0         44379522  2019-09-20   NaN         4.0
# 4721  2336.0         44700828  2019-11-09   NaN         4.0
# 4984  1299.0         44482280  2019-10-06   NaN         4.0
# 5019  3999.0         44275831  2019-09-04   NaN         4.0
# 5108  1800.0         38110076  2019-01-29   NaN         3.0
# 5136  3470.0         37574187  2019-01-16   NaN         3.0
# 5152  1849.0         34131028  2018-11-02   NaN         1.0
# 5165  820.0          39550881  2019-03-02   NaN         4.0
# 5203  2355.0         40108920  2019-03-16   NaN         5.0
# 5267  2520.0         33827572  2018-10-24   NaN         4.0
# 5375  1999.0         36844604  2018-12-30   NaN         3.0
# 5405  1029.0         44430591  2019-09-27   NaN         1.0
# 5428  11849.0        44560668  2019-10-18   NaN         5.0
# 5516  5453.0         44024989  2019-07-24   NaN         5.0
# 5695  1999.0         43029830  2019-06-06   NaN         2.0
# 10    11999.0        49618692  2021-03-17   NaN         5.0
# 259   4999.0         49402422  2021-02-24   NaN         5.0
# 1755  3499.0         49791000  2021-04-04   NaN         4.0
# 1981  3499.0         49571361  2021-03-12   NaN         4.0
# 2012  3999.0         49732582  2021-03-29   NaN         4.0
# 2319  7299.0         49632860  2021-03-19   NaN         5.0
#
#       thumbs_up  thumbs_down  \
# 69    31         2
# 256   0          0
# 390   0          0
# 821   1          2
# 1291  0          0
# 1301  0          0
# 1944  1          0
# 1959  0          0
# 1975  2          0
# 2105  0          0
# 2182  12         5
# 2224  0          0
# 2226  0          0
# 2437  1          3
# 2618  1          0
# 2715  7          0
# 2864  1          2
# 3286  2          2
# 3363  1          0
# 3365  0          0
# 3443  0          0
# 3587  1          0
# 3627  0          0
# 3633  0          0
# 3649  0          0
# 3753  1          0
# 4096  4          2
# 4234  13         2
# 4301  0          1
# 4421  0          0
# 4433  0          0
# 4436  0          0
# 4510  1          3
# 4593  2          0
# 4674  1          0
# 4721  4          1
# 4984  0          0
# 5019  0          0
# 5108  2          0
# 5136  0          0
# 5152  1          0
# 5165  0          0
# 5203  2          0
# 5267  1          0
# 5375  0          0
# 5405  1          2
# 5428  6          0
# 5516  0          0
# 5695  1          2
# 10    27         8
# 259   1          0
# 1755  0          0
# 1981  2          0
# 2012  1          0
# 2319  0          0
#
#                                                                                                                                                                         product_advatages  \
# 69    Телефон мне очень понравился. Так Как перешел с 6s сразу на 12 5 лет разниця ощущается сильно конечно! Но думаю владельцам 11 го 10 го Нету смысла обновляться, лично мое мнение...
# 256   NaN
# 390   NaN
# 821   NaN
# 1291  Легкий у використанні, чудовий телефон для такої ціни.
# 1301  полет нормальный
# 1944  Смартфон работает хорошо
# 1959  Батерея, відсутність передустановленого непотребу
# 1975  защитана 4 у меня не чайно упало и поломался держатель а так все хорошо
# 2105  Отличный телефон.успел купить.
# 2182  Процессор, камера, батарея, OLED, хороша 18в зарядка
# 2224  NaN
# 2226  Батарея, не греется, обратная связь, хорошо сеть ловит
# 2437  Экран,материал корпуса,батарея,звук,
# 2618  Отличный недорогой смартфон, для повседневного использования. Хорошая оптимизация оболочки.
# 2715  NaN
# 2864  Отличный телефон, пользуюсь уже 6 месяцев.
# 3286  Внешний вид.
# 3363  Разговорный динамик очень громкий, качество звука из основного тоже на высоте, батарея при активном использовании садится за сутки, сканер отпечатков работает быстро и четко,
# 3365  NaN
# 3443  Цена
# 3587  Не плохой телефон, за сравнительно не большие деньги.
# 3627  Нету.
# 3633  Долго держит батарея,очень удобный в исползовпнии
# 3649  Не знаю что сказать проработал месяц и умер
# 3753  Большой дисплей
# 4096  Добротный защищенный корпус, достойная начинка, быстрота и четкость работы.
# 4234  A цена покупки что указана  или еще плюс100$ доставка
# 4301  NaN
# 4421  Акумулятор , пам'ять , звук , інтерфейс , "броня"
# 4433  Надёжный, функциональный.
# 4436  Прочный, удобный. Работает быстро. Пользуюсь две недели.
# 4510  NaN
# 4593  Хороший телефон за свою цену.
# 4674  ціна
# 4721  Мягкий сенсор, громкий, шустрый в интернете, держит зарядку в активном режиме до двух суток
# 4984  Работает хорошо, пока без глюков
# 5019  NaN
# 5108  Телефон хороший но...
# 5136  Емкий аккумулятор, хорошее быстродействие, 2 СИМ-карты, эффектный внешний вид.
# 5152  выглядит и в руке отличный телефон
# 5165  бюджетный
# 5203  цена---качество
# 5267  функциональность, дизайн
# 5375  Хорошая батарея, хороший дизайн для своей модели, фронтальная камера, удобный
# 5405  нету
# 5428  Камера, ціна, чистий андроід
# 5516  Отличный телефон. Доволен по всем параметрам. Никуда специально его не ронял, но окунал в воду — все ок.
# 5695  Нет
# 10    Тел сам по себе не плохой.. но вроде как и дороговато по сравнение с А51.
# 259   Крутой дизанй
# 1755  NaN
# 1981  шустренький, яркий, неплохая камера, приемлемая цена, простой в управлении.
# 2012  Быстрый, тонкий, лёгкий.
# 2319  Все
#
#                                                                                                                                                                                                                                                                                                                                        product_disadvantages  \
# 69    Пока недостатков не нашёл
# 256   Слабкий сигнал з wi fi
# 390   Немає
# 821   Маркетологам магазина огромный АНТИреспект. Вчера купил за 24499 по акции, сегодня 23999 и новая акция.Теперь вопрос где всё-таки лучше покупать?! И кому доверять в плане адекватной цены?
# 1291  Немає.
# 1301  нету
# 1944  Греется при работе
# 1959  сантиметрова тріщина в корпусі, ціна не відповідає заявленій
# 1975  Нету 4джи не обмануйте
# 2105  Отвратительный сервис розетки. Предложили как дополнение купить по скидке защитное стекло. Я взял и согласился. Стекло ужасное по всем граням до 2-3 мм нестыковка с экраном. Но верх цинизма сегодня присылают в вайбер смс, не хотите купить правильное стекло? Да фото прилагаю. К сожалению сейчас розетка это, не та розетка которая была раньше.
# 2182  no
# 2224  Пользуюсь пол года виснет тач скрин
# 2226  Камера, иногда глючит, это не совсем недостаток но не type c
# 2437  Для меня заметны микроподтормаживания, пролистывая в верх в них в приложениях.
# 2618  скорость зарядки и разъём юсб
# 2715  Связи ноль
# 2864  Пока их нету
# 3286  для меня очень огромным не достатком является то что через раз приходят уведомления на мои приложения,соц.сети и.т.д. В настройках все выставлено,разрешено работать в фоновом режиме,стоит галочка "не экономить заряд",но к сожалению толка нет! Зато от родных встроенных каждых пять минут пиликает.Очень розачарована
# 3363  Акселерометр подкачал, очень плохо поворачивается экран, иногда по три раза нужно наклонить телефон,
# 3365  Глючть з першого дня
# 3443  Пластиковый корпус
# 3587  Слабенькие наушники в комплекте, но это наверное у всех.
# 3627  Виснет. Тупит. Разочарован
# 3633  Экран темноват,
# 3649  Тупит
# 3753  1 неделя: Телефон начал чуть быстрее разряжаться
# 4096  Довольно увесистый. Вряд ли подойдет для девочек
# 4234  NaN
# 4301  на клавішах латинський алфавіт
# 4421  Вага
# 4433  NaN
# 4436  Батареи хватает только на два дня! При нажатии на кнопку сворачивание, которая слева, то она не подсвечивается. В отличии от других: центрольной и что справа.
# 4510  Прислали телефон 64 ГБ встроенной памяти, врут в объявлении
# 4593  На морозе начинает тормозить.
# 4674  батарейка слаба і зарядне ніяке. динаміки то робить то неробить. а вобщому нормальний.
# 4721  Долго заряжается (около 8 часов)
# 4984  Диагональ не 5, а 4,5 дюйма, гарантийный талон не прислали. Основная камера на самом деле одна
# 5019  Камера
# 5108  Система заражена рекламными вирусами
# 5136  Не лучший звук (басы не прописаны), небольшой экран, не лучшая камера.
# 5152  третий раз в ремонте, составили акт о невозможности ремонта
# 5165  слабый аккумулятор
# 5203  пока не обнаружены
# 5267  не обнаружено
# 5375  Упадет на ногу - сломает кости, плохая основная камера. Со временем начинает лагать, ужасный процессор.
# 5405  не ставятся программы на сд карту
# 5428  NaN
# 5516  NaN
# 5695  Куча реклам на нем! Куда не зайди одни рекламы, ужаааас.
# 10    цена
# 259   Не хватает стерео и NFC
# 1755  Підторможує,іноді при вхідному дзвінку перезавантажується,та не зберігає вхідний дзвінок,при перезавантаженні продовжує грати мелодія дзвінка
# 1981  Немного разочаровал внешний динамик
# 2012  Кнопка "домой", кнопка "назад"
# 2319  Немає
#
# ...
# 2864  None Преймущества: Отличный телефон, пользуюсь уже 6 месяцев.. Недостатки: Пока их нету
# 3286  None Преймущества: Внешний вид.. Недостатки: для меня очень огромным не достатком является то что через раз приходят уведомления на мои приложения,соц.сети и.т.д. В настройках все выставлено,разрешено работать в фоновом режиме,стоит галочка "не экономить заряд",но к сожалению толка нет! Зато от родных встроенных каждых пять минут пиликает.Очень розачарована
# 3363  None Преймущества: Разговорный динамик очень громкий, качество звука из основного тоже на высоте, батарея при активном использовании садится за сутки, сканер отпечатков работает быстро и четко,. Недостатки: Акселерометр подкачал, очень плохо поворачивается экран, иногда по три раза нужно наклонить телефон,
# 3365  None Преймущества: None. Недостатки: Глючть з першого дня
# 3443  None Преймущества: Цена. Недостатки: Пластиковый корпус
# 3587  None Преймущества: Не плохой телефон, за сравнительно не большие деньги.. Недостатки: Слабенькие наушники в комплекте, но это наверное у всех.
# 3627  None Преймущества: Нету.. Недостатки: Виснет. Тупит. Разочарован
# 3633  None Преймущества: Долго держит батарея,очень удобный в исползовпнии. Недостатки: Экран темноват,
# 3649  None Преймущества: Не знаю что сказать проработал месяц и умер. Недостатки: Тупит
# 3753  None Преймущества: Большой дисплей. Недостатки: 1 неделя: Телефон начал чуть быстрее разряжаться
# 4096  None Преймущества: Добротный защищенный корпус, достойная начинка, быстрота и четкость работы.. Недостатки: Довольно увесистый. Вряд ли подойдет для девочек
# 4234  None Преймущества: A цена покупки что указана  или еще плюс100$ доставка. Недостатки: None
# 4301  None Преймущества: None. Недостатки: на клавішах латинський алфавіт
# 4421  None Преймущества: Акумулятор , пам'ять , звук , інтерфейс , "броня". Недостатки: Вага
# 4433  None Преймущества: Надёжный, функциональный.. Недостатки: None
# 4436  None Преймущества: Прочный, удобный. Работает быстро. Пользуюсь две недели.. Недостатки: Батареи хватает только на два дня! При нажатии на кнопку сворачивание, которая слева, то она не подсвечивается. В отличии от других: центрольной и что справа.
# 4510  None Преймущества: None. Недостатки: Прислали телефон 64 ГБ встроенной памяти, врут в объявлении
# 4593  None Преймущества: Хороший телефон за свою цену.. Недостатки: На морозе начинает тормозить.
# 4674  None Преймущества: ціна. Недостатки: батарейка слаба і зарядне ніяке. динаміки то робить то неробить. а вобщому нормальний.
# 4721  None Преймущества: Мягкий сенсор, громкий, шустрый в интернете, держит зарядку в активном режиме до двух суток. Недостатки: Долго заряжается (около 8 часов)
# 4984  None Преймущества: Работает хорошо, пока без глюков. Недостатки: Диагональ не 5, а 4,5 дюйма, гарантийный талон не прислали. Основная камера на самом деле одна
# 5019  None Преймущества: None. Недостатки: Камера
# 5108  None Преймущества: Телефон хороший но.... Недостатки: Система заражена рекламными вирусами
# 5136  None Преймущества: Емкий аккумулятор, хорошее быстродействие, 2 СИМ-карты, эффектный внешний вид.. Недостатки: Не лучший звук (басы не прописаны), небольшой экран, не лучшая камера.
# 5152  None Преймущества: выглядит и в руке отличный телефон. Недостатки: третий раз в ремонте, составили акт о невозможности ремонта
# 5165  None Преймущества: бюджетный. Недостатки: слабый аккумулятор
# 5203  None Преймущества: цена---качество. Недостатки: пока не обнаружены
# 5267  None Преймущества: функциональность, дизайн. Недостатки: не обнаружено
# 5375  None Преймущества: Хорошая батарея, хороший дизайн для своей модели, фронтальная камера, удобный. Недостатки: Упадет на ногу - сломает кости, плохая основная камера. Со временем начинает лагать, ужасный процессор.
# 5405  None Преймущества: нету. Недостатки: не ставятся программы на сд карту
# 5428  None Преймущества: Камера, ціна, чистий андроід. Недостатки: None
# 5516  None Преймущества: Отличный телефон. Доволен по всем параметрам. Никуда специально его не ронял, но окунал в воду — все ок.. Недостатки: None
# 5695  None Преймущества: Нет. Недостатки: Куча реклам на нем! Куда не зайди одни рекламы, ужаааас.
# 10    None Преймущества: Тел сам по себе не плохой.. но вроде как и дороговато по сравнение с А51.. Недостатки: цена
# 259   None Преймущества: Крутой дизанй. Недостатки: Не хватает стерео и NFC
# 1755  None Преймущества: None. Недостатки: Підторможує,іноді при вхідному дзвінку перезавантажується,та не зберігає вхідний дзвінок,при перезавантаженні продовжує грати мелодія дзвінка
# 1981  None Преймущества: шустренький, яркий, неплохая камера, приемлемая цена, простой в управлении.. Недостатки: Немного разочаровал внешний динамик
# 2012  None Преймущества: Быстрый, тонкий, лёгкий.. Недостатки: Кнопка "домой", кнопка "назад"
# 2319  None Преймущества: Все. Недостатки: Немає

# %% [markdown]
# *From table above we see that majority of records with empty review_text have useful information in product_advatages, product_disadvantages columns, so we will keep these recods*

# %% [markdown]
# ## Preprocessing: Preparation of target variable

# %% [markdown]
# We will train a model to predict sentiment of review based on it's text. Target variable (review sentiment) will be calculated based on review_rating column:
# - positive sentiment will have the value “1” and correspond to rating of 4 and 5 stars;
# - negative sentiment will have the value “0” and correspond to rating of 1, 2 and 3 stars.

# %%
#Create new column review_sentiment for target variable
data_clean.loc[(data_clean['review_rating']==1)|(data_clean['review_rating']==2)|(data_clean['review_rating']==3), 'review_sentiment'] = '0' 
data_clean.loc[(data_clean['review_rating']==4)|(data_clean['review_rating']==5), 'review_sentiment'] = '1'
display(data_clean.review_sentiment.head())
# Out:
# 1    0
# 2    0
# 5    0
# 6    0
# 8    1
# Name: review_sentiment, dtype: object

# %%
#Check proportions of negative and positive reviews
display(round(data_clean.groupby('review_sentiment')['comment_link'].count()/data_clean.shape[0], 2))
# Out:
# review_sentiment
# 0    0.23
# 1    0.77
# Name: comment_link, dtype: float64

# %% [markdown]
# *Class distribution of target variable is imbalanced, 77% of all reviews are positive.*

# %%
# Write created cleaned DaraFrame to csv file for easier access to prepared data for training models
data_clean.to_csv('./reviews_data/data_clean.csv', index=False)

# %%
#Encode target variable (format required for the modeling)
target = pd.get_dummies(data_clean.review_sentiment)
data_clean['0'] = target.iloc[:, 0]
data_clean['1'] = target.iloc[:, 1]

# %% [markdown]
# ## Preprocessing: train/test split and preprocessing pipeline with Bert mode

# %% [markdown]
# For training the model we will use the column full_text which contains all text from reviews (review_text, product_advatages, product_disadvantages).

# %%
#Split dataset into training and test. Test dataframe can be used later to check model performance on the unseen data.
#Add stratify parameter to ensure the same proportions of examples in each class as observed in the original dataset.
df_train, df_test = train_test_split(data_clean, test_size=0.2, stratify=data_clean.review_sentiment)

# %%
#Check proportions of examples in each class for training and test dataset.
display(round(df_test.groupby('review_sentiment')['review_id'].count()/df_test.shape[0], 2))
display(round(df_train.groupby('review_sentiment')['review_id'].count()/df_train.shape[0], 2))
# Out:
# review_sentiment
# 0    0.23
# 1    0.77
# Name: review_id, dtype: float64
# review_sentiment
# 0    0.23
# 1    0.77
# Name: review_id, dtype: float64

# %%
#Data preprocessing with bert mode
(x_train, y_train), (x_test, y_test), preproc = text.texts_from_df(df_train, 
                                                                   'full_text', # name of column containing review text
                                                                   label_columns=['0', '1'],
                                                                   maxlen=200, 
                                                                   max_features=100000,
                                                                   preprocess_mode='bert',
                                                                   val_pct=0.1)
# Out:
# preprocessing train...
# language: ru
# done.
# Is Multi-Label? False
# preprocessing test...
# language: ru
# done.

# %% [markdown]
# ## Building Bert model with ktrain

# %%
#Initializing pre-trained Bert model
model = text.text_classifier(name='bert',
                             train_data=(x_train, y_train),
                             preproc=preproc)
# Out:
# Is Multi-Label? False
# maxlen is 200
# done.

# %%
#View loaded model architecture summary
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input-Token (InputLayer)        [(None, 200)]        0
# __________________________________________________________________________________________________
# Input-Segment (InputLayer)      [(None, 200)]        0
# __________________________________________________________________________________________________
# Embedding-Token (TokenEmbedding [(None, 200, 768), ( 91812096    Input-Token[0][0]
# __________________________________________________________________________________________________
# Embedding-Segment (Embedding)   (None, 200, 768)     1536        Input-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Token-Segment (Add)   (None, 200, 768)     0           Embedding-Token[0][0]
#                                                                  Embedding-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Position (PositionEmb (None, 200, 768)     153600      Embedding-Token-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Dropout (Dropout)     (None, 200, 768)     0           Embedding-Position[0][0]
# __________________________________________________________________________________________________
# Embedding-Norm (LayerNormalizat (None, 200, 768)     1536        Embedding-Dropout[0][0]
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 200, 768)     2362368     Embedding-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-1-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 200, 768)     0           Embedding-Norm[0][0]
#                                                                  Encoder-1-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 200, 768)     1536        Encoder-1-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-1-FeedForward (FeedForw (None, 200, 768)     4722432     Encoder-1-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-1-FeedForward-Dropout ( (None, 200, 768)     0           Encoder-1-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-1-FeedForward-Add (Add) (None, 200, 768)     0           Encoder-1-MultiHeadSelfAttention-
#                                                                  Encoder-1-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-1-FeedForward-Norm (Lay (None, 200, 768)     1536        Encoder-1-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 200, 768)     2362368     Encoder-1-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-2-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-1-FeedForward-Norm[0][0]
#                                                                  Encoder-2-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 200, 768)     1536        Encoder-2-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-2-FeedForward (FeedForw (None, 200, 768)     4722432     Encoder-2-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-2-FeedForward-Dropout ( (None, 200, 768)     0           Encoder-2-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-2-FeedForward-Add (Add) (None, 200, 768)     0           Encoder-2-MultiHeadSelfAttention-
#                                                                  Encoder-2-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-2-FeedForward-Norm (Lay (None, 200, 768)     1536        Encoder-2-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-3-MultiHeadSelfAttentio (None, 200, 768)     2362368     Encoder-2-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-3-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-3-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-3-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-2-FeedForward-Norm[0][0]
#                                                                  Encoder-3-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-3-MultiHeadSelfAttentio (None, 200, 768)     1536        Encoder-3-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-3-FeedForward (FeedForw (None, 200, 768)     4722432     Encoder-3-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-3-FeedForward-Dropout ( (None, 200, 768)     0           Encoder-3-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-3-FeedForward-Add (Add) (None, 200, 768)     0           Encoder-3-MultiHeadSelfAttention-
#                                                                  Encoder-3-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-3-FeedForward-Norm (Lay (None, 200, 768)     1536        Encoder-3-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-4-MultiHeadSelfAttentio (None, 200, 768)     2362368     Encoder-3-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-4-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-4-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-4-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-3-FeedForward-Norm[0][0]
#                                                                  Encoder-4-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-4-MultiHeadSelfAttentio (None, 200, 768)     1536        Encoder-4-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-4-FeedForward (FeedForw (None, 200, 768)     4722432     Encoder-4-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-4-FeedForward-Dropout ( (None, 200, 768)     0           Encoder-4-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-4-FeedForward-Add (Add) (None, 200, 768)     0           Encoder-4-MultiHeadSelfAttention-
#                                                                  Encoder-4-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-4-FeedForward-Norm (Lay (None, 200, 768)     1536        Encoder-4-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-5-MultiHeadSelfAttentio (None, 200, 768)     2362368     Encoder-4-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-5-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-5-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-5-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-4-FeedForward-Norm[0][0]
#                                                                  Encoder-5-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-5-MultiHeadSelfAttentio (None, 200, 768)     1536        Encoder-5-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-5-FeedForward (FeedForw (None, 200, 768)     4722432     Encoder-5-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-5-FeedForward-Dropout ( (None, 200, 768)     0           Encoder-5-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-5-FeedForward-Add (Add) (None, 200, 768)     0           Encoder-5-MultiHeadSelfAttention-
#                                                                  Encoder-5-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-5-FeedForward-Norm (Lay (None, 200, 768)     1536        Encoder-5-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-6-MultiHeadSelfAttentio (None, 200, 768)     2362368     Encoder-5-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-6-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-6-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-6-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-5-FeedForward-Norm[0][0]
#                                                                  Encoder-6-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-6-MultiHeadSelfAttentio (None, 200, 768)     1536        Encoder-6-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-6-FeedForward (FeedForw (None, 200, 768)     4722432     Encoder-6-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-6-FeedForward-Dropout ( (None, 200, 768)     0           Encoder-6-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-6-FeedForward-Add (Add) (None, 200, 768)     0           Encoder-6-MultiHeadSelfAttention-
#                                                                  Encoder-6-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-6-FeedForward-Norm (Lay (None, 200, 768)     1536        Encoder-6-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-7-MultiHeadSelfAttentio (None, 200, 768)     2362368     Encoder-6-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-7-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-7-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-7-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-6-FeedForward-Norm[0][0]
#                                                                  Encoder-7-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-7-MultiHeadSelfAttentio (None, 200, 768)     1536        Encoder-7-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-7-FeedForward (FeedForw (None, 200, 768)     4722432     Encoder-7-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-7-FeedForward-Dropout ( (None, 200, 768)     0           Encoder-7-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-7-FeedForward-Add (Add) (None, 200, 768)     0           Encoder-7-MultiHeadSelfAttention-
#                                                                  Encoder-7-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-7-FeedForward-Norm (Lay (None, 200, 768)     1536        Encoder-7-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-8-MultiHeadSelfAttentio (None, 200, 768)     2362368     Encoder-7-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-8-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-8-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-8-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-7-FeedForward-Norm[0][0]
#                                                                  Encoder-8-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-8-MultiHeadSelfAttentio (None, 200, 768)     1536        Encoder-8-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-8-FeedForward (FeedForw (None, 200, 768)     4722432     Encoder-8-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-8-FeedForward-Dropout ( (None, 200, 768)     0           Encoder-8-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-8-FeedForward-Add (Add) (None, 200, 768)     0           Encoder-8-MultiHeadSelfAttention-
#                                                                  Encoder-8-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-8-FeedForward-Norm (Lay (None, 200, 768)     1536        Encoder-8-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-9-MultiHeadSelfAttentio (None, 200, 768)     2362368     Encoder-8-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-9-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-9-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-9-MultiHeadSelfAttentio (None, 200, 768)     0           Encoder-8-FeedForward-Norm[0][0]
#                                                                  Encoder-9-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-9-MultiHeadSelfAttentio (None, 200, 768)     1536        Encoder-9-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-9-FeedForward (FeedForw (None, 200, 768)     4722432     Encoder-9-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-9-FeedForward-Dropout ( (None, 200, 768)     0           Encoder-9-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-9-FeedForward-Add (Add) (None, 200, 768)     0           Encoder-9-MultiHeadSelfAttention-
#                                                                  Encoder-9-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-9-FeedForward-Norm (Lay (None, 200, 768)     1536        Encoder-9-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-10-MultiHeadSelfAttenti (None, 200, 768)     2362368     Encoder-9-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-10-MultiHeadSelfAttenti (None, 200, 768)     0           Encoder-10-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-10-MultiHeadSelfAttenti (None, 200, 768)     0           Encoder-9-FeedForward-Norm[0][0]
#                                                                  Encoder-10-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-10-MultiHeadSelfAttenti (None, 200, 768)     1536        Encoder-10-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-10-FeedForward (FeedFor (None, 200, 768)     4722432     Encoder-10-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-10-FeedForward-Dropout  (None, 200, 768)     0           Encoder-10-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-10-FeedForward-Add (Add (None, 200, 768)     0           Encoder-10-MultiHeadSelfAttention
#                                                                  Encoder-10-FeedForward-Dropout[0]
# __________________________________________________________________________________________________
# Encoder-10-FeedForward-Norm (La (None, 200, 768)     1536        Encoder-10-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-11-MultiHeadSelfAttenti (None, 200, 768)     2362368     Encoder-10-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-11-MultiHeadSelfAttenti (None, 200, 768)     0           Encoder-11-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-11-MultiHeadSelfAttenti (None, 200, 768)     0           Encoder-10-FeedForward-Norm[0][0]
#                                                                  Encoder-11-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-11-MultiHeadSelfAttenti (None, 200, 768)     1536        Encoder-11-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-11-FeedForward (FeedFor (None, 200, 768)     4722432     Encoder-11-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-11-FeedForward-Dropout  (None, 200, 768)     0           Encoder-11-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-11-FeedForward-Add (Add (None, 200, 768)     0           Encoder-11-MultiHeadSelfAttention
#                                                                  Encoder-11-FeedForward-Dropout[0]
# __________________________________________________________________________________________________
# Encoder-11-FeedForward-Norm (La (None, 200, 768)     1536        Encoder-11-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-12-MultiHeadSelfAttenti (None, 200, 768)     2362368     Encoder-11-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-12-MultiHeadSelfAttenti (None, 200, 768)     0           Encoder-12-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-12-MultiHeadSelfAttenti (None, 200, 768)     0           Encoder-11-FeedForward-Norm[0][0]
#                                                                  Encoder-12-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-12-MultiHeadSelfAttenti (None, 200, 768)     1536        Encoder-12-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-12-FeedForward (FeedFor (None, 200, 768)     4722432     Encoder-12-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-12-FeedForward-Dropout  (None, 200, 768)     0           Encoder-12-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-12-FeedForward-Add (Add (None, 200, 768)     0           Encoder-12-MultiHeadSelfAttention
#                                                                  Encoder-12-FeedForward-Dropout[0]
# __________________________________________________________________________________________________
# Encoder-12-FeedForward-Norm (La (None, 200, 768)     1536        Encoder-12-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Extract (Extract)               (None, 768)          0           Encoder-12-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# NSP-Dense (Dense)               (None, 768)          590592      Extract[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            1538        NSP-Dense[0][0]
# ==================================================================================================
# Total params: 177,615,362
# Trainable params: 177,615,362
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Wrap the model and data in a Learner object
learner = ktrain.get_learner(model=model,
                             train_data=(x_train, y_train),
                             val_data=(x_test, y_test),
                             batch_size=6)

# %%
#Run Learning Rate Finder
#learner.lr_find(max_epochs=1)

# %%
#Visually inspect the loss plot 
#learner.lr_plot()

# %% [markdown]
# **Learning Rate Finder**
# The Learner object can be used to find a good learning rate for the model using the lr_find and lr_plot methods. The lr_find method simulates training at different learning rates and tracks the loss. After visually inspecting the plot generated by lr_plot, we choose the highest learning rate still associated with the smallest loss - 1e-5

# %%
#Set learner to use default weight decay rate 
learner.get_weight_decay()
learner.set_weight_decay()
# Out:
# C:\Users\Anna\anaconda3\lib\site-packages\ktrain\core.py:357: UserWarning: recompiling model to use AdamWeightDecay as opimizer with weight decay of 0.01
#   warnings.warn('recompiling model to use AdamWeightDecay as opimizer with weight decay of %s' % (wd) )

# %% [markdown]
# **Weight decay**
# Weight decay is a form of regularization, we will use it in order to reduce overfitting caused by target classes imbalance.
# By default, ktrain uses no weight decay, but for our model we will set default weight decay rate of 0.01 implemented using the AdamWeightDecay optimizer.

# %% [markdown]
# Next two sections are commented as training takes a lot of time and computationally expensive, trained model was saved and can be downloaded by link: https://files.fm/u/2msz9eexf – file `sentiment_prediction.data-00000-of-00001`.

# %%
#Create TensorBoard calback to use it later to analyse model performance
#tbCallBack = tf.keras.callbacks.TensorBoard(log_dir='/tmp/Tensor_Board', histogram_freq=0, write_graph=True, write_images=True)

#Training the model
#learner.fit_onecycle(lr=1e-5,
#                     epochs=3,
#                    callbacks=[tbCallBack])
# Out:
# begin training using onecycle policy with max lr of 1e-05...
# Epoch 1/3
# 457/457 [==============================] - 3156s 7s/step - loss: 0.4804 - accuracy: 0.7763 - val_loss: 0.3344 - val_accuracy: 0.8557
# Epoch 2/3
# 457/457 [==============================] - 3255s 7s/step - loss: 0.3258 - accuracy: 0.8566 - val_loss: 0.2951 - val_accuracy: 0.8754
# Epoch 3/3
# 457/457 [==============================] - 3363s 7s/step - loss: 0.1730 - accuracy: 0.9332 - val_loss: 0.2759 - val_accuracy: 0.8984

# %%
#Save trained model
#learner.model.save_weights("sentiment_prediction")

# %% [markdown]
# # Step 4: Evaluating model performance

# %% [markdown]
# ## Check model performance metrics on the Training dataset

# %%
#Load trained model
learner.model.load_weights('./models/sentiment_prediction')

# %%
#Check learner performance metrics
display(learner.validate())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.78        71
#            1       0.94      0.93      0.93       234
#
#     accuracy                           0.90       305
#    macro avg       0.86      0.86      0.86       305
# weighted avg       0.90      0.90      0.90       305
# array([[ 56,  15],
#        [ 16, 218]], dtype=int64)

# %% [markdown]
# *From the table above we can see that the model has pretty high accuracy – 90% of predictions were correct.
# Predictions for positive reviews are more precise: 94% of all predicted reviews are truly positive and 93% of all positive reviews were detected correctly.*
# *For negative reviews precision is less: only 78% of all predicted reviews are truly negative and 79% of all negative reviews were detected correctly.*
# *From f1-score we can see that the model is pretty good at predicting positive reviews and works worse for predicting negative reviews which is expected due to class imbalance.*

# %%
#This section is commented because we can’t view losses if training of the model is not done in current session. 

#View 5 top losses of the model.
#Reviewing where model made mistakes can help to understand better how algorithm works and if anything can be improved in preprocessing stage. 
#txt = learner.view_top_losses(n=5, preproc=preproc)
# Out:
# ----------
# id:64 | loss:4.45 | true:0 | pred:1)
#
# [CLS] от ##ли ##чны ##и теле ##фон , но нет ##у г ##уг ##л се ##рве ##ра . не при ##вы ##чно , не у ##до ##бно пре ##им ##у ##щества : none . не ##до ##стат ##ки : none [SEP]
# ----------
# id:229 | loss:3.8 | true:0 | pred:1)
#
# [CLS] кит ##аи ##ски ##и де ##шев ##ы ##и теле ##фон . пока а ##и ##фон в ремонт ##е , по ##ид ##ет . пре ##им ##у ##щества : их нет . при ##сла ##ли с бит ##ыми п ##ик ##сел ##ями э ##к ##ран . . не ##до ##стат ##ки : none [SEP]
# ----------
# id:10 | loss:3.68 | true:0 | pred:1)
#
# [CLS] теле ##фон дуже ди ##вно себе пов ##оди ##ть , часто живе сам по собі , гл ##ючи ##ть . пре ##им ##у ##щества : де ##шев ##ии . не ##до ##стат ##ки : none [SEP]
# ----------
# id:65 | loss:3.66 | true:0 | pred:1)
#
# [CLS] в принцип ##е , не ##п ##ло ##хо ##и теле ##фон , но на фоне опыт ##а владения nok ##ia 5 . 3 , с ##ка ##жу , что nok ##ia 5 . 4 - это не э ##вол ##ю ##ция и труд ##но с ##каз ##ать . . . и даже не де ##града ##ция . . . это ша ##г в ##перед и ша ##г назад одновременно . мне труд ##но назва ##ть эту модель п ##ло ##хо ##и , либо же хор ##ош ##еи . у ##вы , правил ##ьным о ##пределение ##м , будет " б ##ес ##по ##ле ##зная " и более до ##сто ##ина названия " nok ##ia 5 . 29 " , либо , " nok ##ia 5 . 31 " . и дал ##ь ##ше я поста ##ра ##ю ##сь об ##ъя ##сни ##ть по ##чему я так с ##чита ##ю . дава ##ите все же на ##чну из хор ##ош ##их сторон нас ##ле ##дни ##цы nok ##ia 5 . 3 . очень по ##н ##рав ##ился ди ##за ##ин э ##к ##рана - нет з ##лос ##час ##тно ##и " ка ##п ##ли " в виде фронта ##льно [SEP]
# ----------
# id:259 | loss:3.59 | true:0 | pred:1)
#
# [CLS] # м ##о ##є ##ро ##з ##пак ##ування ##уль ##тра б ##ю ##дж ##ет ##нии теле ##фон ) ) 1 ##г ##б опера ##тивно ##і пам ##ят ##і . . . ла ##ги . . . пре ##им ##у ##щества : ці ##на , на ##яв ##ність на ##ву ##шни ##ків та за ##хи ##сна п ##лів ##ка в комп ##лект ##і , з ##нім ##на ба ##тар ##ея . . не ##до ##стат ##ки : мало пам ##ят ##і , сл ##аби ##и процес ##ор , немає на ##ву ##шни ##ків в комп ##лект ##і . [SEP]

# %% [markdown]
# *From reviewing records with the biggest loss, we can see that for all of them model predicted positive sentiment when true value was negative sentiment.
# Some of reviews contain contradicting information: positive and negative feedback which may be confusing for classification. Other reviews seem to be clearly negative but were wrongly classified as positive*

# %% [markdown]
# ## Check model performance metrics on the Testing dataset

# %% [markdown]
# Test data set can be used to evaluate performance of the model on the unseen by model data. It will help to confirm model performance results and define if there are any overfitting issues.

# %%
#Get predictor 
predictor = ktrain.get_predictor(learner.model, preproc)

# %%
#Make predictions on the Test dataset
df_test_pred = pd.DataFrame(df_test)
df_test_pred['bert_prediction'] = [predictor.predict(i) for i in df_test.full_text]

# %%
#Check proportions of predicted class for test dataset.
display(round(df_test_pred.groupby('bert_prediction')['review_id'].count()/df_test_pred.shape[0], 2))
# Out:
# bert_prediction
# 0    0.19
# 1    0.81
# Name: review_id, dtype: float64

# %%
#Check model perfomance merics
print("Accuracy score of model's predictions on test dataset is {}".format(round(accuracy_score(df_test_pred.review_sentiment, df_test_pred.bert_prediction), 2)))
print("Area Under the Receiver Operating Characteristic Curve on test dataset is {}. It means that there is a {}% chance that the model will be able to distinguish between positive and negative class for reviews.".format(round(roc_auc_score(df_test_pred.review_sentiment, df_test_pred.bert_prediction), 2),round(roc_auc_score(df_test_pred.review_sentiment, df_test_pred.bert_prediction)*100, 1)))
# Out:
# Accuracy score of model's predictions on test dataset is 0.87
# Area Under the Receiver Operating Characteristic Curve on test dataset is 0.79. It means that there is a 79.3% chance that the model will be able to distinguish between positive and negative class for reviews.

# %%
#Check confusion matrix
display(pd.DataFrame(confusion_matrix(df_test_pred.review_sentiment, df_test_pred.bert_prediction), 
             columns=['Predicted class 0', 'Predicted class 1'],
            index=['True class 0', 'True class 1']))
# Out:
#               Predicted class 0  Predicted class 1
# True class 0  114                63
# True class 1  34                 551

# %% [markdown]
# *From confusion matrix above we can see the same situation as in training data set, on positive reviews model performing much better than on negative reviews.*

# %%
confusion_matrix_1 = pd.DataFrame(confusion_matrix(df_test_pred.review_sentiment, df_test_pred.bert_prediction, normalize='true'), 
             columns=['Predicted class 0', 'Predicted class 1'],
            index=['True class 0', 'True class 1'])
display(confusion_matrix_1)
print('Table above shows that {}% of all negative reviews and {}% of all positive reviews were detected correctly.'.format(round(confusion_matrix_1.iloc[0,0]*100, 1), round(confusion_matrix_1.iloc[1,1]*100,1)))
# Out:
#               Predicted class 0  Predicted class 1
# True class 0  0.644068           0.355932
# True class 1  0.058120           0.941880
# Table above shows that 64.4% of all negative reviews and 94.2% of all positive reviews were detected correctly.

# %%
confusion_matrix_2 = pd.DataFrame(confusion_matrix(df_test_pred.review_sentiment, df_test_pred.bert_prediction, normalize='pred'), 
             columns=['Predicted class 0', 'Predicted class 1'],
            index=['True class 0', 'True class 1'])
display(confusion_matrix_2)
print("Table above shows that {}% of predictions as class 'negative' and {}% of predictions of class 'positive' were correct.".format(round(confusion_matrix_2.iloc[0,0]*100, 1), round(confusion_matrix_2.iloc[1,1]*100,1)))
# Out:
#               Predicted class 0  Predicted class 1
# True class 0  0.77027            0.102606
# True class 1  0.22973            0.897394
# Table above shows that 77.0% of predictions as class 'negative' and 89.7% of predictions of class 'positive' were correct.

# %% [markdown]
# # Step 5: Predict sentiment for reviews without rating

# %%
#Drop recods without text
data_to_pred = data.dropna(subset = ['full_text'])
#Select records without rating
data_to_pred = data_to_pred[data_to_pred.review_rating.isna()]
data_to_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1898 entries, 0 to 5119
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   comment_link           1898 non-null   object
#  1   product_title          1898 non-null   object
#  2   product_price          1898 non-null   float64
#  3   review_id              1898 non-null   int64
#  4   review_date            1898 non-null   datetime64[ns]
#  5   review_text            1841 non-null   object
#  6   review_rating          0 non-null      float64
#  7   thumbs_up              1898 non-null   int64
#  8   thumbs_down            1898 non-null   int64
#  9   product_advatages      820 non-null    object
#  10  product_disadvantages  868 non-null    object
#  11  full_text              1898 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 192.8+ KB

# %%
#Make predictions of sentiment for reviews without rating
data_to_pred['bert_prediction'] = [predictor.predict(i) for i in data_to_pred.full_text]

# %%
#Look at proportion of predicted negative and positive sentiments
display(round(data_to_pred.groupby('bert_prediction')['review_id'].count()/data_to_pred.shape[0], 2))
# Out:
# bert_prediction
# 0    0.33
# 1    0.67
# Name: review_id, dtype: float64

# %%
display(data_to_pred.head(20))
# Out:
#                                                                                                   comment_link  \
# 0   https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49293156
# 7   https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49360716
# 11  https://rozetka.com.ua/ua/samsung_sma715fzbusek/p174226312/comments/#id=49395870
# 19  https://rozetka.com.ua/ua/samsung_sma715fzbusek/p174226312/comments/#id=49342195
# 22  https://rozetka.com.ua/ua/samsung_sma715fzbusek/p174226312/comments/#id=49366754
# 25  https://rozetka.com.ua/ua/apple_iphone_12_pro_max_128gb_silver/p245162461/comments/#id=49287407
# 29  https://rozetka.com.ua/ua/apple_iphone_12_pro_max_128gb_silver/p245162461/comments/#id=49123777
# 33  https://rozetka.com.ua/ua/apple_iphone_12_pro_max_128gb_silver/p245162461/comments/#id=49116680
# 34  https://rozetka.com.ua/ua/apple_iphone_12_pro_max_128gb_silver/p245162461/comments/#id=49159463
# 40  https://rozetka.com.ua/ua/samsung_sm_a025fzkesek/p268107536/comments/#id=49390694
# 43  https://rozetka.com.ua/ua/samsung_sm_a025fzkesek/p268107536/comments/#id=49350462
# 55  https://rozetka.com.ua/ua/samsung_sm_a315fzwvsek/p199478977/comments/#id=49384061
# 64  https://rozetka.com.ua/ua/apple_iphone_12_64gb_product_red/p245162161/comments/#id=49396807
# 70  https://rozetka.com.ua/ua/apple_iphone_12_64gb_product_red/p245162161/comments/#id=48857432
# 73  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49300772
# 75  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49297066
# 76  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49268051
# 81  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49311850
# 83  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49291997
# 86  https://rozetka.com.ua/ua/samsung_sm_a515fzkwsek/p168813961/comments/#id=49272310
#
#                                                                                                                   product_title  \
# 0    Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 7    Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 11   Мобільний телефон Samsung Galaxy A71 6/128GB Blue (SM-A715FZBUSEK)
# 19   Мобільний телефон Samsung Galaxy A71 6/128GB Blue (SM-A715FZBUSEK)
# 22   Мобільний телефон Samsung Galaxy A71 6/128GB Blue (SM-A715FZBUSEK)
# 25   Мобільний телефон Apple iPhone 12 Pro Max 128 GB Silver Офіційна гарантія
# 29   Мобільний телефон Apple iPhone 12 Pro Max 128 GB Silver Офіційна гарантія
# 33   Мобільний телефон Apple iPhone 12 Pro Max 128 GB Silver Офіційна гарантія
# 34   Мобільний телефон Apple iPhone 12 Pro Max 128 GB Silver Офіційна гарантія
# 40   Мобільний телефон Samsung Galaxy A02s 3/32 GB Black (SM-A025FZKESEK)
# 43   Мобільний телефон Samsung Galaxy A02s 3/32 GB Black (SM-A025FZKESEK)
# 55   Мобільний телефон Samsung Galaxy A31 4/128GB Prism Crush White (SM-A315FZWVSEK)
# 64   Мобільний телефон Apple iPhone 12 64GB PRODUCT Red Офіційна гарантія
# 70   Мобільний телефон Apple iPhone 12 64GB PRODUCT Red Офіційна гарантія
# 73   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 75   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 76   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 81   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 83   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 86   Мобільний телефон Samsung Galaxy A51 6/128GB Black (SM-A515FZKWSEK)
#
#     product_price  review_id review_date  \
# 0   39999.0        49293156  2021-02-13
# 7   39999.0        49360716  2021-02-20
# 11  9499.0         49395870  2021-02-23
# 19  9499.0         49342195  2021-02-18
# 22  9499.0         49366754  2021-02-20
# 25  40499.0        49287407  2021-02-13
# 29  40499.0        49123777  2021-01-29
# 33  40499.0        49116680  2021-01-28
# 34  40499.0        49159463  2021-02-01
# 40  3799.0         49390694  2021-02-23
# 43  3799.0         49350462  2021-02-19
# 55  5999.0         49384061  2021-02-22
# 64  28999.0        49396807  2021-02-23
# 70  28999.0        48857432  2021-01-08
# 73  4499.0         49300772  2021-02-14
# 75  4499.0         49297066  2021-02-14
# 76  4499.0         49268051  2021-02-11
# 81  4499.0         49311850  2021-02-15
# 83  4499.0         49291997  2021-02-13
# 86  7999.0         49272310  2021-02-11
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               review_text  \
# 0   Розетка, подскажите телефон без сканера лица и желательно без сканера отпечатков пальцев. Спасибо
# 7   Отдать ,за телефон !  40000...    За самсунг...   Это просто глупо !
# 11  Він захищений по IPxx
# 19  Користуюсь даною моделью вже 10 місяць, і що хочу сказати стосовно даного телефону: потужний - все працює без жодного зависання чи якихось глюків, дуже якісний екран , дивишся не наче у воду так все чітко, якісна камера як для фото так і для відео, по корпусу також нарікань не має, ні чого не скрипить і не люфтить. До цього користувався різними не дешевими а також потужними ксіомі і хуавей моделями з +/- такими ж а той вище параметрами, то все проти самсунга а71 дно. Вважаю А71 топ в своїй серії.
# 22  7 тис грн максимально б дав за нього
# 25  Блин ну зачем опять эту челку вставили, сколько ещё лет ждать экран без моноброви? Даже для китайцев это не проблема. Эпл пора открыть глаза!!!
# 29  Завис при попытке скачать файл с помощью фирменного софта «файлы» с локального сервера через протокол Самба smb:// Помогло удаление «файлы», перезагрузка телефона, переустановка приложения, без включенного интернета зайти в файлы и вернуться в первоначальное меню.
# 33  В этом году ничего не придумали ни одни ни другие, что 12 айфон тупо 11, что с21ультра - с20ультра, год смело можно пропускать, подожду осени 21 года, может удивят, а пока с пикселем 4хл похожу
# 34  У кого проблема с автопереключением LTE--&gt;3G на Lifecell - включите VoLTE. В моем случае это решило проблему, не смотря на то, что оператор не поддерживает эту функцию. Надеюсь, это не приведет к повышенному разряду аккумулятора.
# 40  У Самсунга, то акула глухая, то свисток без дырки... Здесь вот сканер отпечатка пальца зажидили.. А там где от допустим есть, значится или проц совсем Г. или на емкости аккум. сэкономят (как пример). Ох уж этот брендовый маркетинг.
# 43  Слава пластику :)
# 55  В нас в магазині 5999. Можна і провірити  Який смисл у розетці купувати? Розетка  дуже дорогий Інтернет магазин.
# 64  Брати s21 чи ip 12
# 70  вопрос к експертам у тел фонит, шипит динамик не знаю как назвать особенно выделяется при оповещениях и прослушивании громких видео, музыки подскажите брак или нет? ( не ронял и ничего с ним не делал, изначально так было)
# 73  Телефон купила недавно. Пока месть все нравится, как будет работать дальше посмотрю.
# 75  Слабая упаковка для пересылки от магазина. Ранее, такого не наблюдалось. Радует, что телефон не пострадал. И уже не ясно, то ли такой отгрузили, то ли повредили на Новой почте...
# 76  Дуже вдячна ще й за обслуговування Розетки
# 81  Смартфон купил ребенку. Уже минимум два отзыва в Розетке по этой проблеме. Этот будет третьим. Выскакивает верхнее меню на активном дисплее (во время игр). Выскакивает очень часто. Бывает по несколько раз в минуту. Происходит это во время игр "Роблакс" и "Майнкрафт". Я думал, что после обновления системы этот баг исчез навсегда, но он опять начал провялятся. Нокия, займитесь вопросом и устраните этот баг путем обновления программного обеспечения!
# 83  Як в кого маю телефон 2 місяць я задоволений без глюків за таку ціну все влаштовує можливо відіграє роль хто де придбав або рулетка)
# 86  Доброго дня, півроку тому придбав у подарунок дружині цей телефон. Дружина була задоволена даною покупкою. Кілька днів тому телефон завис та вимкнувся. Увімкнули, але він далі ніж екран загрузки не запускався. Занесли в ремонт. Експерт сказав, що проблема в заводському браці материнської плати. Замовили нову але і нова виявилася з аналогічним дефектом. Експерт сказав що кожен 5 телефон даної моделі брачний. Висновок: 9тис. в смітник +3тис. нова плата.Не рекомендую купувати даний телефон.
#
#     review_rating  thumbs_up  thumbs_down  \
# 0  NaN             0          1
# 7  NaN             1          4
# 11 NaN             0          0
# 19 NaN             0          0
# 22 NaN             0          1
# 25 NaN             3          1
# 29 NaN             6          11
# 33 NaN             0          0
# 34 NaN             9          0
# 40 NaN             1          1
# 43 NaN             0          0
# 55 NaN             1          1
# 64 NaN             0          0
# 70 NaN             0          0
# 73 NaN             1          0
# 75 NaN             0          0
# 76 NaN             2          0
# 81 NaN             1          1
# 83 NaN             0          0
# 86 NaN             0          1
#
#                                            product_advatages  \
# 0   NaN
# 7   Нет
# 11  NaN
# 19  Якість, потужність
# 22  NaN
# 25  NaN
# 29  Их не так много
# 33  NaN
# 34  NaN
# 40  NaN
# 43  NaN
# 55  Нема
# 64  NaN
# 70  не знаю
# 73  NaN
# 75  NaN
# 76  Подобається  телефон. Дуже вдячна ще й за обслуговування
# 81  NaN
# 83  батарея
# 86  Екран
#
#               product_disadvantages  \
# 0   NaN
# 7   Сам факт существования самсунга
# 11  NaN
# 19  Не має.
# 22  NaN
# 25  NaN
# 29  Их больше чем преимуществ
# 33  NaN
# 34  NaN
# 40  NaN
# 43  NaN
# 55  Дорого
# 64  NaN
# 70  не знаю
# 73  NaN
# 75  NaN
# 76  немає
# 81  NaN
# 83  -
# 86  Глючить, ремонту не підлягає
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       full_text  \
# 0   Розетка, подскажите телефон без сканера лица и желательно без сканера отпечатков пальцев. Спасибо Преймущества: None. Недостатки: None
# 7   Отдать ,за телефон !  40000...    За самсунг...   Это просто глупо ! Преймущества: Нет. Недостатки: Сам факт существования самсунга
# 11  Він захищений по IPxx Преймущества: None. Недостатки: None
# 19  Користуюсь даною моделью вже 10 місяць, і що хочу сказати стосовно даного телефону: потужний - все працює без жодного зависання чи якихось глюків, дуже якісний екран , дивишся не наче у воду так все чітко, якісна камера як для фото так і для відео, по корпусу також нарікань не має, ні чого не скрипить і не люфтить. До цього користувався різними не дешевими а також потужними ксіомі і хуавей моделями з +/- такими ж а той вище параметрами, то все проти самсунга а71 дно. Вважаю А71 топ в своїй серії. Преймущества: Якість, потужність. Недостатки: Не має.
# 22  7 тис грн максимально б дав за нього Преймущества: None. Недостатки: None
# 25  Блин ну зачем опять эту челку вставили, сколько ещё лет ждать экран без моноброви? Даже для китайцев это не проблема. Эпл пора открыть глаза!!! Преймущества: None. Недостатки: None
# 29  Завис при попытке скачать файл с помощью фирменного софта «файлы» с локального сервера через протокол Самба smb:// Помогло удаление «файлы», перезагрузка телефона, переустановка приложения, без включенного интернета зайти в файлы и вернуться в первоначальное меню. Преймущества: Их не так много. Недостатки: Их больше чем преимуществ
# 33  В этом году ничего не придумали ни одни ни другие, что 12 айфон тупо 11, что с21ультра - с20ультра, год смело можно пропускать, подожду осени 21 года, может удивят, а пока с пикселем 4хл похожу Преймущества: None. Недостатки: None
# 34  У кого проблема с автопереключением LTE--&gt;3G на Lifecell - включите VoLTE. В моем случае это решило проблему, не смотря на то, что оператор не поддерживает эту функцию. Надеюсь, это не приведет к повышенному разряду аккумулятора. Преймущества: None. Недостатки: None
# 40  У Самсунга, то акула глухая, то свисток без дырки... Здесь вот сканер отпечатка пальца зажидили.. А там где от допустим есть, значится или проц совсем Г. или на емкости аккум. сэкономят (как пример). Ох уж этот брендовый маркетинг. Преймущества: None. Недостатки: None
# 43  Слава пластику :) Преймущества: None. Недостатки: None
# 55  В нас в магазині 5999. Можна і провірити  Який смисл у розетці купувати? Розетка  дуже дорогий Інтернет магазин. Преймущества: Нема. Недостатки: Дорого
# 64  Брати s21 чи ip 12 Преймущества: None. Недостатки: None
# 70  вопрос к експертам у тел фонит, шипит динамик не знаю как назвать особенно выделяется при оповещениях и прослушивании громких видео, музыки подскажите брак или нет? ( не ронял и ничего с ним не делал, изначально так было) Преймущества: не знаю. Недостатки: не знаю
# 73  Телефон купила недавно. Пока месть все нравится, как будет работать дальше посмотрю. Преймущества: None. Недостатки: None
# 75  Слабая упаковка для пересылки от магазина. Ранее, такого не наблюдалось. Радует, что телефон не пострадал. И уже не ясно, то ли такой отгрузили, то ли повредили на Новой почте... Преймущества: None. Недостатки: None
# 76  Дуже вдячна ще й за обслуговування Розетки Преймущества: Подобається  телефон. Дуже вдячна ще й за обслуговування. Недостатки: немає
# 81  Смартфон купил ребенку. Уже минимум два отзыва в Розетке по этой проблеме. Этот будет третьим. Выскакивает верхнее меню на активном дисплее (во время игр). Выскакивает очень часто. Бывает по несколько раз в минуту. Происходит это во время игр "Роблакс" и "Майнкрафт". Я думал, что после обновления системы этот баг исчез навсегда, но он опять начал провялятся. Нокия, займитесь вопросом и устраните этот баг путем обновления программного обеспечения! Преймущества: None. Недостатки: None
# 83  Як в кого маю телефон 2 місяць я задоволений без глюків за таку ціну все влаштовує можливо відіграє роль хто де придбав або рулетка) Преймущества: батарея. Недостатки: -
# 86  Доброго дня, півроку тому придбав у подарунок дружині цей телефон. Дружина була задоволена даною покупкою. Кілька днів тому телефон завис та вимкнувся. Увімкнули, але він далі ніж екран загрузки не запускався. Занесли в ремонт. Експерт сказав, що проблема в заводському браці материнської плати. Замовили нову але і нова виявилася з аналогічним дефектом. Експерт сказав що кожен 5 телефон даної моделі брачний. Висновок: 9тис. в смітник +3тис. нова плата.Не рекомендую купувати даний телефон. Преймущества: Екран. Недостатки: Глючить, ремонту не підлягає
#
#    bert_prediction
# 0   1
# 7   0
# 11  1
# 19  1
# 22  1
# 25  0
# 29  0
# 33  1
# 34  1
# 40  1
# 43  1
# 55  1
# 64  1
# 70  1
# 73  1
# 75  0
# 76  1
# 81  1
# 83  1
# 86  0

# %% [markdown]
# I would categorize 20 records in the table above the following way:
# -	Questions/orders -  2 records,
# -	Only feedback about shop/service – 3 records,
# -	Reviews and feedback about product – 15 records (among these records I would say that 7 recodes are confusing, but it’s still possible to identify sentiment and 8 records contain more or less constructive feedback).
# It’s important to pay attention that initial data contains information about feedback about product, about shop/service and just questions. While applying model to solve a task or answer a question it may be useful to filter initial data first to get records that actually contain information related to subject of interest.
#
# By manually classifying 20 displayed records to positive/negative sentiment, I would agree with 13 predictions and choose different sentiment in 8 records (all errors are flase positive), it gives accuracy of 60%.

# %%
display(data_to_pred.tail(20))
# Out:
#                                                                                           comment_link  \
# 2474  https://rozetka.com.ua/ua/nokia_1_3_1_16gb_dualsim_charcoal/p197525707/comments/#id=49386107
# 2489  https://rozetka.com.ua/ua/xiaomi_mi_10t_lite_6_128gb_pearl_gray/p252721136/comments/#id=49405897
# 2491  https://rozetka.com.ua/ua/xiaomi_mi_10t_lite_6_128gb_pearl_gray/p252721136/comments/#id=49595895
# 2532  https://rozetka.com.ua/ua/huawei_nova_5t_crush_blue/p149442588/comments/#id=49406579
# 2537  https://rozetka.com.ua/ua/huawei_nova_5t_crush_blue/p149442588/comments/#id=49602258
# 2555  https://rozetka.com.ua/ua/nokia_2_3_2_32gb_black/p159096638/comments/#id=49480378
# 2687  https://rozetka.com.ua/ua/vivo_y15_4_64gb_aqua_blue/p104968494/comments/#id=49459980
# 2730  https://rozetka.com.ua/ua/xiaomi_765959/p282452478/comments/#id=49777611
# 2744  https://rozetka.com.ua/ua/xiaomi_mi_note_10_lite_6_64gb_purple/p210765661/comments/#id=48438761
# 2750  https://rozetka.com.ua/ua/xiaomi_mi_note_10_lite_6_64gb_purple/p210765661/comments/#id=48146024
# 2829  https://rozetka.com.ua/ua/meizu_16_6_128gb_black/p154385183/comments/#id=48750534
# 2890  https://rozetka.com.ua/ua/huawei_p_smart_pro_6_128_black/p145141992/comments/#id=49664266
# 3023  https://rozetka.com.ua/ua/sony_xperia_l1_290742/p15285049/comments/#id=49816723
# 3175  https://rozetka.com.ua/ua/zte_blade_v10_vita_3_64gb_green/p99194710/comments/#id=49790626
# 3225  https://rozetka.com.ua/ua/tp_link_neffos_tp7071a55ua/p106788753/comments/#id=49756783
# 3261  https://rozetka.com.ua/ua/tp_link_tp7061a54ua/p127608821/comments/#id=49515093
# 3300  https://rozetka.com.ua/ua/tp_link_neffos_tp7051_red/p111538058/comments/#id=49679005
# 3448  https://rozetka.com.ua/ua/tp_link_neffos_c7_tp910a24ua/p32644807/comments/#id=49400578
# 4244  https://rozetka.com.ua/ua/39171344/p39171344/comments/#id=39705060
# 5119  https://rozetka.com.ua/ua/sony_xperia_1_ii_black/p189372940/comments/#id=46619100
#
#                                                                      product_title  \
# 2474   Мобільний телефон Nokia 1.3 1/16 GB DualSim Charcoal
# 2489   Мобільний телефон Xiaomi Mi 10T Lite 6/128 GB Pearl Gray
# 2491   Мобільний телефон Xiaomi Mi 10T Lite 6/128 GB Pearl Gray
# 2532   Мобільний телефон Huawei Nova 5T Crush Blue
# 2537   Мобільний телефон Huawei Nova 5T Crush Blue
# 2555   Мобільний телефон Nokia 2.3 2/32GB Charcoal
# 2687   Мобільний телефон Vivo Y15 4/64GB Aqua Blue
# 2730   Мобільний телефон Xiaomi Redmi Note 10 Pro 6/64GB Gradient Bronze (765959)
# 2744   Мобільний телефон Xiaomi Mi Note 10 Lite 6/64GB Purple
# 2750   Мобільний телефон Xiaomi Mi Note 10 Lite 6/64GB Purple
# 2829   Мобільний телефон Meizu 16 6/128GB Black
# 2890   Мобільний телефон Huawei P Smart Pro 6/128GB Black
# 3023   Мобільний телефон Sony Xperia L1 Dual (G3312) Pink
# 3175   Мобільний телефон ZTE Blade V10 Vita 3/64GB Green
# 3225   Мобільний телефон TP-Link Neffos X20 Black
# 3261   Мобільний телефон TP-Link Neffos C9s (TP7061A54UA) Dark Blue
# 3300   Мобільний телефон TP-Link Neffos C7s (TP7051) Red
# 3448   Мобільний телефон TP-Link Neffos C7 (TP910A24UA) Cloudy Grey
# 4244   Смартфон Vivo X20 4/64GB Black Matte
# 5119   Мобільний телефон Sony Xperia 1 II Black
#
#       product_price  review_id review_date  \
# 2474  1999.0         49386107  2021-02-22
# 2489  8999.0         49405897  2021-02-24
# 2491  8999.0         49595895  2021-03-15
# 2532  7999.0         49406579  2021-02-24
# 2537  7999.0         49602258  2021-03-16
# 2555  2799.0         49480378  2021-03-03
# 2687  3997.0         49459980  2021-03-01
# 2730  7699.0         49777611  2021-04-03
# 2744  8499.0         48438761  2020-12-04
# 2750  8499.0         48146024  2020-11-12
# 2829  5499.0         48750534  2020-12-29
# 2890  5999.0         49664266  2021-03-22
# 3023  3197.0         49816723  2021-04-07
# 3175  2599.0         49790626  2021-04-04
# 3225  2599.0         49756783  2021-04-01
# 3261  2099.0         49515093  2021-03-07
# 3300  1709.0         49679005  2021-03-24
# 3448  1999.0         49400578  2021-02-24
# 4244  7159.0         39705060  2019-03-06
# 5119  0.0            46619100  2020-06-11
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                          review_text  \
# 2474  NaN
# 2489  У этого телефона комбинированный слот,а вы пишите что нет..
# 2491  Телефон супер!!!!
# 2532  Вчера был в наличии сегодня уже нет!..
# 2537  Поверніть оплату частинами
# 2555  Сам телефон отличный, но.... Сегодня просто тупо выключился!!! Все!! Ни на зарядку( выключился именно на зарядке),ни на кнопки, не реагирует. Придется высылать в сервис....Он и до этого жил своей жизнью, при малейшем колебании начинал светится... Но это было терпимо, он хотя бы работал...
# 2687  Фантастически бесполезное устройство по простейшей причине: для открытия всех функций, вроде установки приложений из неизвестных источников, или разрешений, нужно зарегистрироваться в учётной записи Vivo, а это исчдие китайского ада принимает исключительно азиатские номера. Если кто-то сталкивался с этой проблемой и знает решение, буду очень благодарен.
# 2730  Телефон не плохой,не хватает датчика уведомления
# 2744  Не мешало бы цену вам пересмотреть , уважаемые менеджеры )) вы же мониторингом занимаетесь ? Или на сегодняшний день один из самых крупных интернет магазинов не может и не в состоянии дать своим клиентам если не лучшую цену , то хотя бы конкурентную или рыночную ?) Не впечатляет
# 2750  За такую цену телефон с кучей рекламы ??? Смешно
# 2829  Верните деньги аферисты полтора месяца жду!!! Последняя поокупка здесь!!!
# 2890  Телефон отличный, аккумулятор держит 2 дня, быстрый не зависает, сделан качественно
# 3023  Единственное что мне понравилось в этом телефоне, так это "разделение экрана", очень удобная и нужная штука как по мне. Больше нигде такое не встречал. 4 года прослужил, и то дети разбили, аккумулятор очень слабый.
# 3175  Ужасный смартфон не кому не советую!
# 3225  Телефон спочатку чудово працював але пройшов лиш рік з моменту покупки і сенсор перестав працювати(((
# 3261  Работой магазина розетка довольна а вот телефоном нет,очень тихий,слуховой динамик совсем тихий,не сразу заменили,брали на подарок,обратились в сервис и без результат 0,он у них полежал две недели и вернули назад,сервис ужасный.
# 3300  Спустя 4 мес. после покупки данного аппарата стал отключаться без ведомых причин. Еще через пару месяцев стал пропадать звук  при разговоре (перестал слышать собеседника и он меня), при перезагрузки все восстанавливалось. В итоге через полтора года эксплуатации перестала работать камера. Все проблемы этого телефона начали накапливаться как снежный ком в итоге я буду покупать новый. НИКОМУ НЕ РЕКОМЕНДУЮ ДАННУЮ МОДЕЛЬ К ПОКУПКЕ!
# 3448  Защитное стекло на экран 1шт . Перезвоню
# 4244  Что то странно за такие деньги он 4g не поддерживает.
# 5119  А это правда что смартфоны sony больше не будут поставляться в Украину.  Было бы очень жалко потерять такой иминитый бренд которые не слудеут на поводу новых трендов как чертова монобровь или камера по середине екрана.  Тем более новая линейка достаточно хорошая чтобы составить конкуренцию.
#
#       review_rating  thumbs_up  thumbs_down  \
# 2474 NaN             0          0
# 2489 NaN             1          0
# 2491 NaN             1          1
# 2532 NaN             0          1
# 2537 NaN             0          0
# 2555 NaN             0          0
# 2687 NaN             0          0
# 2730 NaN             0          0
# 2744 NaN             14         0
# 2750 NaN             7          5
# 2829 NaN             1          4
# 2890 NaN             0          0
# 3023 NaN             0          0
# 3175 NaN             0          0
# 3225 NaN             0          0
# 3261 NaN             0          0
# 3300 NaN             0          0
# 3448 NaN             0          0
# 4244 NaN             3          0
# 5119 NaN             24         1
#
#                            product_advatages  \
# 2474  NaN
# 2489  NaN
# 2491  Стерео звук, стабілізація відео.
# 2532  NaN
# 2537  NaN
# 2555  NaN
# 2687  Большинство характеристик
# 2730  NaN
# 2744  NaN
# 2750  NaN
# 2829  NaN
# 2890  Хороший аккумулятор, фото качественные
# 3023  NaN
# 3175  Нету
# 3225  NaN
# 3261  Симпатичный дизайн
# 3300  Дешёвый, отонсительно быстрый
# 3448  NaN
# 4244  За такие деньги особо не увидел.
# 5119  Sony
#
#                                                                                         product_disadvantages  \
# 2474  Самтелефоный тупой
# 2489  NaN
# 2491  Ціна...
# 2532  NaN
# 2537  NaN
# 2555  NaN
# 2687  Невозможность использовать все фунцчии, надоедливый китайский софт
# 2730  NaN
# 2744  NaN
# 2750  NaN
# 2829  NaN
# 2890  Не яркий экран на солнце
# 3023  NaN
# 3175  Плохая камера, ужасная производительность, лаги интерфейса и всех приложений, плохой акамулятор.
# 3225  NaN
# 3261  Очень плохие динамики,не рекомендую!
# 3300  Очень сильно стал глючить спустя год экусплуатации, проблемы появлялись по мере временного устаревания.
# 3448  NaN
# 4244  Судя по описанию 4 g не поддерживает.
# 5119  NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             full_text  \
# 2474  None Преймущества: None. Недостатки: Самтелефоный тупой
# 2489  У этого телефона комбинированный слот,а вы пишите что нет.. Преймущества: None. Недостатки: None
# 2491  Телефон супер!!!! Преймущества: Стерео звук, стабілізація відео.. Недостатки: Ціна...
# 2532  Вчера был в наличии сегодня уже нет!.. Преймущества: None. Недостатки: None
# 2537  Поверніть оплату частинами Преймущества: None. Недостатки: None
# 2555  Сам телефон отличный, но.... Сегодня просто тупо выключился!!! Все!! Ни на зарядку( выключился именно на зарядке),ни на кнопки, не реагирует. Придется высылать в сервис....Он и до этого жил своей жизнью, при малейшем колебании начинал светится... Но это было терпимо, он хотя бы работал... Преймущества: None. Недостатки: None
# 2687  Фантастически бесполезное устройство по простейшей причине: для открытия всех функций, вроде установки приложений из неизвестных источников, или разрешений, нужно зарегистрироваться в учётной записи Vivo, а это исчдие китайского ада принимает исключительно азиатские номера. Если кто-то сталкивался с этой проблемой и знает решение, буду очень благодарен. Преймущества: Большинство характеристик. Недостатки: Невозможность использовать все фунцчии, надоедливый китайский софт
# 2730  Телефон не плохой,не хватает датчика уведомления Преймущества: None. Недостатки: None
# 2744  Не мешало бы цену вам пересмотреть , уважаемые менеджеры )) вы же мониторингом занимаетесь ? Или на сегодняшний день один из самых крупных интернет магазинов не может и не в состоянии дать своим клиентам если не лучшую цену , то хотя бы конкурентную или рыночную ?) Не впечатляет Преймущества: None. Недостатки: None
# 2750  За такую цену телефон с кучей рекламы ??? Смешно Преймущества: None. Недостатки: None
# 2829  Верните деньги аферисты полтора месяца жду!!! Последняя поокупка здесь!!! Преймущества: None. Недостатки: None
# 2890  Телефон отличный, аккумулятор держит 2 дня, быстрый не зависает, сделан качественно Преймущества: Хороший аккумулятор, фото качественные. Недостатки: Не яркий экран на солнце
# 3023  Единственное что мне понравилось в этом телефоне, так это "разделение экрана", очень удобная и нужная штука как по мне. Больше нигде такое не встречал. 4 года прослужил, и то дети разбили, аккумулятор очень слабый. Преймущества: None. Недостатки: None
# 3175  Ужасный смартфон не кому не советую! Преймущества: Нету. Недостатки: Плохая камера, ужасная производительность, лаги интерфейса и всех приложений, плохой акамулятор.
# 3225  Телефон спочатку чудово працював але пройшов лиш рік з моменту покупки і сенсор перестав працювати((( Преймущества: None. Недостатки: None
# 3261  Работой магазина розетка довольна а вот телефоном нет,очень тихий,слуховой динамик совсем тихий,не сразу заменили,брали на подарок,обратились в сервис и без результат 0,он у них полежал две недели и вернули назад,сервис ужасный. Преймущества: Симпатичный дизайн. Недостатки: Очень плохие динамики,не рекомендую!
# 3300  Спустя 4 мес. после покупки данного аппарата стал отключаться без ведомых причин. Еще через пару месяцев стал пропадать звук  при разговоре (перестал слышать собеседника и он меня), при перезагрузки все восстанавливалось. В итоге через полтора года эксплуатации перестала работать камера. Все проблемы этого телефона начали накапливаться как снежный ком в итоге я буду покупать новый. НИКОМУ НЕ РЕКОМЕНДУЮ ДАННУЮ МОДЕЛЬ К ПОКУПКЕ! Преймущества: Дешёвый, отонсительно быстрый. Недостатки: Очень сильно стал глючить спустя год экусплуатации, проблемы появлялись по мере временного устаревания.
# 3448  Защитное стекло на экран 1шт . Перезвоню Преймущества: None. Недостатки: None
# 4244  Что то странно за такие деньги он 4g не поддерживает. Преймущества: За такие деньги особо не увидел.. Недостатки: Судя по описанию 4 g не поддерживает.
# 5119  А это правда что смартфоны sony больше не будут поставляться в Украину.  Было бы очень жалко потерять такой иминитый бренд которые не слудеут на поводу новых трендов как чертова монобровь или камера по середине екрана.  Тем более новая линейка достаточно хорошая чтобы составить конкуренцию. Преймущества: Sony. Недостатки: None
#
#      bert_prediction
# 2474  0
# 2489  1
# 2491  1
# 2532  1
# 2537  0
# 2555  0
# 2687  1
# 2730  0
# 2744  0
# 2750  1
# 2829  1
# 2890  1
# 3023  1
# 3175  0
# 3225  0
# 3261  1
# 3300  0
# 3448  1
# 4244  1
# 5119  1

# %% [markdown]
# I would categorize 20 records in the table above the following way:
# -	Questions/orders -  1 record,
# -	Only feedback about shop/service – 4 records,
# -	Reviews and feedback about product – 15 records (among these records I would say that 3 recodes are confusing, but it’s still possible to identify sentiment and 12 records contain more or less constructive feedback).
#
# By manually classifying 20 displayed records to positive/negative sentiment, I would agree with 13 predictions, choose different sentiment in 7 records (6 predictions are false positive 1 false negative) and 1 records is hard to classify.
# If we don't include review that is hard to classify as wrong prediction, accuracy will be 65%
#
# Received results are not so good, so let’s if explore if it’s possible to improve the performance.

# %% [markdown]
# # Step 6: Building BERT model v2: oversample negative class to remove class imbalance in target variable

# %% [markdown]
# This step was performed in the separate script "Build_Bert_model_v2.ipynb"

# %% [markdown]
# # Step 7: Running BERT model v2 and evaluating model performance

# %% [markdown]
# To improve the model performance, it was decided to make an experiment: to oversample negative reviews, so there are the same number of positive and negative reviews in the training set, this will remove bias and allow model to learn more about negative class.
# Preparation of the new training set with uniform classes distribution and training the model was done in the separate script.

# %%
#Load trained model
#learner.load_model('sentiment_prediction_2_3epochs', preproc=preproc)
learner.model.load_weights("./models/sentiment_prediction_v2")

# %% [markdown]
# ## Check model performance metrics on the Training dataset

# %%
#Check learner performance metrics
display(learner.validate())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95        71
#            1       1.00      0.97      0.98       234
#
#     accuracy                           0.97       305
#    macro avg       0.95      0.98      0.96       305
# weighted avg       0.98      0.97      0.97       305
# array([[ 70,   1],
#        [  7, 227]], dtype=int64)

# %% [markdown]
# *From the table above we can see that the model has pretty high accuracy – 97% of predictions were correct.
# Predictions for positive reviews are more precise: 100% of all predicted reviews are truly positive and 97% of all positive reviews were detected correctly.*
# *For negative reviews precision is a bit less: 91% of all predicted reviews are truly negative and 99% of all negative reviews were detected correctly.*
# *From f1-score we can see that the model is doing well at predicting positive and negative reviews. Seems like experiment with oversampling negative class gave a significant improvemnt.*

# %% [markdown]
# ## Check model performance metrics on the Testing dataset

# %%
#Get predictor 
predictor = ktrain.get_predictor(learner.model, preproc)
#Make predictions on the Test dataset
df_test_pred = pd.DataFrame(df_test)
df_test_pred['bert_prediction'] = [predictor.predict(i) for i in df_test.full_text]

# %%
#Check proportions of predicted class for test dataset.
display(round(df_test_pred.groupby('bert_prediction')['review_id'].count()/df_test_pred.shape[0], 2))
# Out:
# bert_prediction
# 0    0.24
# 1    0.76
# Name: review_id, dtype: float64

# %%
#Check model perfomance merics
print("Accuracy score of model's predictions on test dataset is {}".format(round(accuracy_score(df_test_pred.review_sentiment, df_test_pred.bert_prediction), 2)))
print("Area Under the Receiver Operating Characteristic Curve on test dataset is {}. It means that there is a {}% chance that the model will be able to distinguish between positive and negative class for reviews.".format(round(roc_auc_score(df_test_pred.review_sentiment, df_test_pred.bert_prediction), 4),round(roc_auc_score(df_test_pred.review_sentiment, df_test_pred.bert_prediction)*100, 1)))
# Out:
# Accuracy score of model's predictions on test dataset is 0.98
# Area Under the Receiver Operating Characteristic Curve on test dataset is 0.9773. It means that there is a 97.7% chance that the model will be able to distinguish between positive and negative class for reviews.

# %%
confusion_matrix_1 = pd.DataFrame(confusion_matrix(df_test_pred.review_sentiment, df_test_pred.bert_prediction, normalize='true'), 
             columns=['Predicted class 0', 'Predicted class 1'],
            index=['True class 0', 'True class 1'])
display(confusion_matrix_1)
print('Table above shows that {}% of all negative reviews and {}% of all positive reviews were detected correctly.'.format(round(confusion_matrix_1.iloc[0,0]*100, 1), round(confusion_matrix_1.iloc[1,1]*100,1)))
# Out:
#               Predicted class 0  Predicted class 1
# True class 0  0.971751           0.028249
# True class 1  0.017094           0.982906
# Table above shows that 97.2% of all negative reviews and 98.3% of all positive reviews were detected correctly.

# %%
confusion_matrix_2 = pd.DataFrame(confusion_matrix(df_test_pred.review_sentiment, df_test_pred.bert_prediction, normalize='pred'), 
             columns=['Predicted class 0', 'Predicted class 1'],
            index=['True class 0', 'True class 1'])
display(confusion_matrix_2)
print("Table above shows that {}% of predictions as class 'negative' and {}% of predictions of class 'positive' were correct.".format(round(confusion_matrix_2.iloc[0,0]*100, 1), round(confusion_matrix_2.iloc[1,1]*100,1)))
# Out:
#               Predicted class 0  Predicted class 1
# True class 0  0.945055           0.008621
# True class 1  0.054945           0.991379
# Table above shows that 94.5% of predictions as class 'negative' and 99.1% of predictions of class 'positive' were correct.

# %% [markdown]
# ## Predict sentiment for reviews without rating with Bert model v2

# %%
#Drop recods without text
data_to_pred = data.dropna(subset = ['full_text'])
#Select records without rating
data_to_pred = data_to_pred[data_to_pred.review_rating.isna()]
data_to_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1898 entries, 0 to 5119
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   comment_link           1898 non-null   object
#  1   product_title          1898 non-null   object
#  2   product_price          1898 non-null   float64
#  3   review_id              1898 non-null   int64
#  4   review_date            1898 non-null   datetime64[ns]
#  5   review_text            1841 non-null   object
#  6   review_rating          0 non-null      float64
#  7   thumbs_up              1898 non-null   int64
#  8   thumbs_down            1898 non-null   int64
#  9   product_advatages      820 non-null    object
#  10  product_disadvantages  868 non-null    object
#  11  full_text              1898 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 192.8+ KB

# %%
#Make predictions of sentiment for reviews without rating
data_to_pred['bert_prediction'] = [predictor.predict(i) for i in data_to_pred.full_text]

# %%
#Look at proportion of predicted negative and positive sentiments
display(round(data_to_pred.groupby('bert_prediction')['review_id'].count()/data_to_pred.shape[0], 2))
# Out:
# bert_prediction
# 0    0.41
# 1    0.59
# Name: review_id, dtype: float64

# %% [markdown]
# The model predicts quite big proportion of negative sentiment reviews among unrated records.

# %%
# Let's look at top 20 predictions
display(data_to_pred.head(20))
# Out:
#                                                                                                   comment_link  \
# 0   https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49293156
# 7   https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49360716
# 11  https://rozetka.com.ua/ua/samsung_sma715fzbusek/p174226312/comments/#id=49395870
# 19  https://rozetka.com.ua/ua/samsung_sma715fzbusek/p174226312/comments/#id=49342195
# 22  https://rozetka.com.ua/ua/samsung_sma715fzbusek/p174226312/comments/#id=49366754
# 25  https://rozetka.com.ua/ua/apple_iphone_12_pro_max_128gb_silver/p245162461/comments/#id=49287407
# 29  https://rozetka.com.ua/ua/apple_iphone_12_pro_max_128gb_silver/p245162461/comments/#id=49123777
# 33  https://rozetka.com.ua/ua/apple_iphone_12_pro_max_128gb_silver/p245162461/comments/#id=49116680
# 34  https://rozetka.com.ua/ua/apple_iphone_12_pro_max_128gb_silver/p245162461/comments/#id=49159463
# 40  https://rozetka.com.ua/ua/samsung_sm_a025fzkesek/p268107536/comments/#id=49390694
# 43  https://rozetka.com.ua/ua/samsung_sm_a025fzkesek/p268107536/comments/#id=49350462
# 55  https://rozetka.com.ua/ua/samsung_sm_a315fzwvsek/p199478977/comments/#id=49384061
# 64  https://rozetka.com.ua/ua/apple_iphone_12_64gb_product_red/p245162161/comments/#id=49396807
# 70  https://rozetka.com.ua/ua/apple_iphone_12_64gb_product_red/p245162161/comments/#id=48857432
# 73  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49300772
# 75  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49297066
# 76  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49268051
# 81  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49311850
# 83  https://rozetka.com.ua/ua/nokia_5_3_4_64gb_dualsim_charcoal/p197545181/comments/#id=49291997
# 86  https://rozetka.com.ua/ua/samsung_sm_a515fzkwsek/p168813961/comments/#id=49272310
#
#                                                                                                                   product_title  \
# 0    Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 7    Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
# 11   Мобільний телефон Samsung Galaxy A71 6/128GB Blue (SM-A715FZBUSEK)
# 19   Мобільний телефон Samsung Galaxy A71 6/128GB Blue (SM-A715FZBUSEK)
# 22   Мобільний телефон Samsung Galaxy A71 6/128GB Blue (SM-A715FZBUSEK)
# 25   Мобільний телефон Apple iPhone 12 Pro Max 128 GB Silver Офіційна гарантія
# 29   Мобільний телефон Apple iPhone 12 Pro Max 128 GB Silver Офіційна гарантія
# 33   Мобільний телефон Apple iPhone 12 Pro Max 128 GB Silver Офіційна гарантія
# 34   Мобільний телефон Apple iPhone 12 Pro Max 128 GB Silver Офіційна гарантія
# 40   Мобільний телефон Samsung Galaxy A02s 3/32 GB Black (SM-A025FZKESEK)
# 43   Мобільний телефон Samsung Galaxy A02s 3/32 GB Black (SM-A025FZKESEK)
# 55   Мобільний телефон Samsung Galaxy A31 4/128GB Prism Crush White (SM-A315FZWVSEK)
# 64   Мобільний телефон Apple iPhone 12 64GB PRODUCT Red Офіційна гарантія
# 70   Мобільний телефон Apple iPhone 12 64GB PRODUCT Red Офіційна гарантія
# 73   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 75   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 76   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 81   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 83   Мобільний телефон Nokia 5.3 4/64GB DualSim Charcoal
# 86   Мобільний телефон Samsung Galaxy A51 6/128GB Black (SM-A515FZKWSEK)
#
#     product_price  review_id review_date  \
# 0   39999.0        49293156  2021-02-13
# 7   39999.0        49360716  2021-02-20
# 11  9499.0         49395870  2021-02-23
# 19  9499.0         49342195  2021-02-18
# 22  9499.0         49366754  2021-02-20
# 25  40499.0        49287407  2021-02-13
# 29  40499.0        49123777  2021-01-29
# 33  40499.0        49116680  2021-01-28
# 34  40499.0        49159463  2021-02-01
# 40  3799.0         49390694  2021-02-23
# 43  3799.0         49350462  2021-02-19
# 55  5999.0         49384061  2021-02-22
# 64  28999.0        49396807  2021-02-23
# 70  28999.0        48857432  2021-01-08
# 73  4499.0         49300772  2021-02-14
# 75  4499.0         49297066  2021-02-14
# 76  4499.0         49268051  2021-02-11
# 81  4499.0         49311850  2021-02-15
# 83  4499.0         49291997  2021-02-13
# 86  7999.0         49272310  2021-02-11
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               review_text  \
# 0   Розетка, подскажите телефон без сканера лица и желательно без сканера отпечатков пальцев. Спасибо
# 7   Отдать ,за телефон !  40000...    За самсунг...   Это просто глупо !
# 11  Він захищений по IPxx
# 19  Користуюсь даною моделью вже 10 місяць, і що хочу сказати стосовно даного телефону: потужний - все працює без жодного зависання чи якихось глюків, дуже якісний екран , дивишся не наче у воду так все чітко, якісна камера як для фото так і для відео, по корпусу також нарікань не має, ні чого не скрипить і не люфтить. До цього користувався різними не дешевими а також потужними ксіомі і хуавей моделями з +/- такими ж а той вище параметрами, то все проти самсунга а71 дно. Вважаю А71 топ в своїй серії.
# 22  7 тис грн максимально б дав за нього
# 25  Блин ну зачем опять эту челку вставили, сколько ещё лет ждать экран без моноброви? Даже для китайцев это не проблема. Эпл пора открыть глаза!!!
# 29  Завис при попытке скачать файл с помощью фирменного софта «файлы» с локального сервера через протокол Самба smb:// Помогло удаление «файлы», перезагрузка телефона, переустановка приложения, без включенного интернета зайти в файлы и вернуться в первоначальное меню.
# 33  В этом году ничего не придумали ни одни ни другие, что 12 айфон тупо 11, что с21ультра - с20ультра, год смело можно пропускать, подожду осени 21 года, может удивят, а пока с пикселем 4хл похожу
# 34  У кого проблема с автопереключением LTE--&gt;3G на Lifecell - включите VoLTE. В моем случае это решило проблему, не смотря на то, что оператор не поддерживает эту функцию. Надеюсь, это не приведет к повышенному разряду аккумулятора.
# 40  У Самсунга, то акула глухая, то свисток без дырки... Здесь вот сканер отпечатка пальца зажидили.. А там где от допустим есть, значится или проц совсем Г. или на емкости аккум. сэкономят (как пример). Ох уж этот брендовый маркетинг.
# 43  Слава пластику :)
# 55  В нас в магазині 5999. Можна і провірити  Який смисл у розетці купувати? Розетка  дуже дорогий Інтернет магазин.
# 64  Брати s21 чи ip 12
# 70  вопрос к експертам у тел фонит, шипит динамик не знаю как назвать особенно выделяется при оповещениях и прослушивании громких видео, музыки подскажите брак или нет? ( не ронял и ничего с ним не делал, изначально так было)
# 73  Телефон купила недавно. Пока месть все нравится, как будет работать дальше посмотрю.
# 75  Слабая упаковка для пересылки от магазина. Ранее, такого не наблюдалось. Радует, что телефон не пострадал. И уже не ясно, то ли такой отгрузили, то ли повредили на Новой почте...
# 76  Дуже вдячна ще й за обслуговування Розетки
# 81  Смартфон купил ребенку. Уже минимум два отзыва в Розетке по этой проблеме. Этот будет третьим. Выскакивает верхнее меню на активном дисплее (во время игр). Выскакивает очень часто. Бывает по несколько раз в минуту. Происходит это во время игр "Роблакс" и "Майнкрафт". Я думал, что после обновления системы этот баг исчез навсегда, но он опять начал провялятся. Нокия, займитесь вопросом и устраните этот баг путем обновления программного обеспечения!
# 83  Як в кого маю телефон 2 місяць я задоволений без глюків за таку ціну все влаштовує можливо відіграє роль хто де придбав або рулетка)
# 86  Доброго дня, півроку тому придбав у подарунок дружині цей телефон. Дружина була задоволена даною покупкою. Кілька днів тому телефон завис та вимкнувся. Увімкнули, але він далі ніж екран загрузки не запускався. Занесли в ремонт. Експерт сказав, що проблема в заводському браці материнської плати. Замовили нову але і нова виявилася з аналогічним дефектом. Експерт сказав що кожен 5 телефон даної моделі брачний. Висновок: 9тис. в смітник +3тис. нова плата.Не рекомендую купувати даний телефон.
#
#     review_rating  thumbs_up  thumbs_down  \
# 0  NaN             0          1
# 7  NaN             1          4
# 11 NaN             0          0
# 19 NaN             0          0
# 22 NaN             0          1
# 25 NaN             3          1
# 29 NaN             6          11
# 33 NaN             0          0
# 34 NaN             9          0
# 40 NaN             1          1
# 43 NaN             0          0
# 55 NaN             1          1
# 64 NaN             0          0
# 70 NaN             0          0
# 73 NaN             1          0
# 75 NaN             0          0
# 76 NaN             2          0
# 81 NaN             1          1
# 83 NaN             0          0
# 86 NaN             0          1
#
#                                            product_advatages  \
# 0   NaN
# 7   Нет
# 11  NaN
# 19  Якість, потужність
# 22  NaN
# 25  NaN
# 29  Их не так много
# 33  NaN
# 34  NaN
# 40  NaN
# 43  NaN
# 55  Нема
# 64  NaN
# 70  не знаю
# 73  NaN
# 75  NaN
# 76  Подобається  телефон. Дуже вдячна ще й за обслуговування
# 81  NaN
# 83  батарея
# 86  Екран
#
#               product_disadvantages  \
# 0   NaN
# 7   Сам факт существования самсунга
# 11  NaN
# 19  Не має.
# 22  NaN
# 25  NaN
# 29  Их больше чем преимуществ
# 33  NaN
# 34  NaN
# 40  NaN
# 43  NaN
# 55  Дорого
# 64  NaN
# 70  не знаю
# 73  NaN
# 75  NaN
# 76  немає
# 81  NaN
# 83  -
# 86  Глючить, ремонту не підлягає
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       full_text  \
# 0   Розетка, подскажите телефон без сканера лица и желательно без сканера отпечатков пальцев. Спасибо Преймущества: None. Недостатки: None
# 7   Отдать ,за телефон !  40000...    За самсунг...   Это просто глупо ! Преймущества: Нет. Недостатки: Сам факт существования самсунга
# 11  Він захищений по IPxx Преймущества: None. Недостатки: None
# 19  Користуюсь даною моделью вже 10 місяць, і що хочу сказати стосовно даного телефону: потужний - все працює без жодного зависання чи якихось глюків, дуже якісний екран , дивишся не наче у воду так все чітко, якісна камера як для фото так і для відео, по корпусу також нарікань не має, ні чого не скрипить і не люфтить. До цього користувався різними не дешевими а також потужними ксіомі і хуавей моделями з +/- такими ж а той вище параметрами, то все проти самсунга а71 дно. Вважаю А71 топ в своїй серії. Преймущества: Якість, потужність. Недостатки: Не має.
# 22  7 тис грн максимально б дав за нього Преймущества: None. Недостатки: None
# 25  Блин ну зачем опять эту челку вставили, сколько ещё лет ждать экран без моноброви? Даже для китайцев это не проблема. Эпл пора открыть глаза!!! Преймущества: None. Недостатки: None
# 29  Завис при попытке скачать файл с помощью фирменного софта «файлы» с локального сервера через протокол Самба smb:// Помогло удаление «файлы», перезагрузка телефона, переустановка приложения, без включенного интернета зайти в файлы и вернуться в первоначальное меню. Преймущества: Их не так много. Недостатки: Их больше чем преимуществ
# 33  В этом году ничего не придумали ни одни ни другие, что 12 айфон тупо 11, что с21ультра - с20ультра, год смело можно пропускать, подожду осени 21 года, может удивят, а пока с пикселем 4хл похожу Преймущества: None. Недостатки: None
# 34  У кого проблема с автопереключением LTE--&gt;3G на Lifecell - включите VoLTE. В моем случае это решило проблему, не смотря на то, что оператор не поддерживает эту функцию. Надеюсь, это не приведет к повышенному разряду аккумулятора. Преймущества: None. Недостатки: None
# 40  У Самсунга, то акула глухая, то свисток без дырки... Здесь вот сканер отпечатка пальца зажидили.. А там где от допустим есть, значится или проц совсем Г. или на емкости аккум. сэкономят (как пример). Ох уж этот брендовый маркетинг. Преймущества: None. Недостатки: None
# 43  Слава пластику :) Преймущества: None. Недостатки: None
# 55  В нас в магазині 5999. Можна і провірити  Який смисл у розетці купувати? Розетка  дуже дорогий Інтернет магазин. Преймущества: Нема. Недостатки: Дорого
# 64  Брати s21 чи ip 12 Преймущества: None. Недостатки: None
# 70  вопрос к експертам у тел фонит, шипит динамик не знаю как назвать особенно выделяется при оповещениях и прослушивании громких видео, музыки подскажите брак или нет? ( не ронял и ничего с ним не делал, изначально так было) Преймущества: не знаю. Недостатки: не знаю
# 73  Телефон купила недавно. Пока месть все нравится, как будет работать дальше посмотрю. Преймущества: None. Недостатки: None
# 75  Слабая упаковка для пересылки от магазина. Ранее, такого не наблюдалось. Радует, что телефон не пострадал. И уже не ясно, то ли такой отгрузили, то ли повредили на Новой почте... Преймущества: None. Недостатки: None
# 76  Дуже вдячна ще й за обслуговування Розетки Преймущества: Подобається  телефон. Дуже вдячна ще й за обслуговування. Недостатки: немає
# 81  Смартфон купил ребенку. Уже минимум два отзыва в Розетке по этой проблеме. Этот будет третьим. Выскакивает верхнее меню на активном дисплее (во время игр). Выскакивает очень часто. Бывает по несколько раз в минуту. Происходит это во время игр "Роблакс" и "Майнкрафт". Я думал, что после обновления системы этот баг исчез навсегда, но он опять начал провялятся. Нокия, займитесь вопросом и устраните этот баг путем обновления программного обеспечения! Преймущества: None. Недостатки: None
# 83  Як в кого маю телефон 2 місяць я задоволений без глюків за таку ціну все влаштовує можливо відіграє роль хто де придбав або рулетка) Преймущества: батарея. Недостатки: -
# 86  Доброго дня, півроку тому придбав у подарунок дружині цей телефон. Дружина була задоволена даною покупкою. Кілька днів тому телефон завис та вимкнувся. Увімкнули, але він далі ніж екран загрузки не запускався. Занесли в ремонт. Експерт сказав, що проблема в заводському браці материнської плати. Замовили нову але і нова виявилася з аналогічним дефектом. Експерт сказав що кожен 5 телефон даної моделі брачний. Висновок: 9тис. в смітник +3тис. нова плата.Не рекомендую купувати даний телефон. Преймущества: Екран. Недостатки: Глючить, ремонту не підлягає
#
#    bert_prediction
# 0   1
# 7   0
# 11  1
# 19  1
# 22  1
# 25  0
# 29  0
# 33  1
# 34  0
# 40  1
# 43  1
# 55  1
# 64  1
# 70  1
# 73  1
# 75  0
# 76  1
# 81  1
# 83  1
# 86  0

# %% [markdown]
# *By manually classifying 20 displayed records to positive/negative sentiment, I would agree with 14 predictions and choose different sentiment in 6 records (all false positive), it gives accuracy of 70%.*

# %%
# Maybe top 20 records are particularly confusing for the model, let’s look at the last 20 records.
display(data_to_pred.tail(20))
# Out:
#                                                                                           comment_link  \
# 2474  https://rozetka.com.ua/ua/nokia_1_3_1_16gb_dualsim_charcoal/p197525707/comments/#id=49386107
# 2489  https://rozetka.com.ua/ua/xiaomi_mi_10t_lite_6_128gb_pearl_gray/p252721136/comments/#id=49405897
# 2491  https://rozetka.com.ua/ua/xiaomi_mi_10t_lite_6_128gb_pearl_gray/p252721136/comments/#id=49595895
# 2532  https://rozetka.com.ua/ua/huawei_nova_5t_crush_blue/p149442588/comments/#id=49406579
# 2537  https://rozetka.com.ua/ua/huawei_nova_5t_crush_blue/p149442588/comments/#id=49602258
# 2555  https://rozetka.com.ua/ua/nokia_2_3_2_32gb_black/p159096638/comments/#id=49480378
# 2687  https://rozetka.com.ua/ua/vivo_y15_4_64gb_aqua_blue/p104968494/comments/#id=49459980
# 2730  https://rozetka.com.ua/ua/xiaomi_765959/p282452478/comments/#id=49777611
# 2744  https://rozetka.com.ua/ua/xiaomi_mi_note_10_lite_6_64gb_purple/p210765661/comments/#id=48438761
# 2750  https://rozetka.com.ua/ua/xiaomi_mi_note_10_lite_6_64gb_purple/p210765661/comments/#id=48146024
# 2829  https://rozetka.com.ua/ua/meizu_16_6_128gb_black/p154385183/comments/#id=48750534
# 2890  https://rozetka.com.ua/ua/huawei_p_smart_pro_6_128_black/p145141992/comments/#id=49664266
# 3023  https://rozetka.com.ua/ua/sony_xperia_l1_290742/p15285049/comments/#id=49816723
# 3175  https://rozetka.com.ua/ua/zte_blade_v10_vita_3_64gb_green/p99194710/comments/#id=49790626
# 3225  https://rozetka.com.ua/ua/tp_link_neffos_tp7071a55ua/p106788753/comments/#id=49756783
# 3261  https://rozetka.com.ua/ua/tp_link_tp7061a54ua/p127608821/comments/#id=49515093
# 3300  https://rozetka.com.ua/ua/tp_link_neffos_tp7051_red/p111538058/comments/#id=49679005
# 3448  https://rozetka.com.ua/ua/tp_link_neffos_c7_tp910a24ua/p32644807/comments/#id=49400578
# 4244  https://rozetka.com.ua/ua/39171344/p39171344/comments/#id=39705060
# 5119  https://rozetka.com.ua/ua/sony_xperia_1_ii_black/p189372940/comments/#id=46619100
#
#                                                                      product_title  \
# 2474   Мобільний телефон Nokia 1.3 1/16 GB DualSim Charcoal
# 2489   Мобільний телефон Xiaomi Mi 10T Lite 6/128 GB Pearl Gray
# 2491   Мобільний телефон Xiaomi Mi 10T Lite 6/128 GB Pearl Gray
# 2532   Мобільний телефон Huawei Nova 5T Crush Blue
# 2537   Мобільний телефон Huawei Nova 5T Crush Blue
# 2555   Мобільний телефон Nokia 2.3 2/32GB Charcoal
# 2687   Мобільний телефон Vivo Y15 4/64GB Aqua Blue
# 2730   Мобільний телефон Xiaomi Redmi Note 10 Pro 6/64GB Gradient Bronze (765959)
# 2744   Мобільний телефон Xiaomi Mi Note 10 Lite 6/64GB Purple
# 2750   Мобільний телефон Xiaomi Mi Note 10 Lite 6/64GB Purple
# 2829   Мобільний телефон Meizu 16 6/128GB Black
# 2890   Мобільний телефон Huawei P Smart Pro 6/128GB Black
# 3023   Мобільний телефон Sony Xperia L1 Dual (G3312) Pink
# 3175   Мобільний телефон ZTE Blade V10 Vita 3/64GB Green
# 3225   Мобільний телефон TP-Link Neffos X20 Black
# 3261   Мобільний телефон TP-Link Neffos C9s (TP7061A54UA) Dark Blue
# 3300   Мобільний телефон TP-Link Neffos C7s (TP7051) Red
# 3448   Мобільний телефон TP-Link Neffos C7 (TP910A24UA) Cloudy Grey
# 4244   Смартфон Vivo X20 4/64GB Black Matte
# 5119   Мобільний телефон Sony Xperia 1 II Black
#
#       product_price  review_id review_date  \
# 2474  1999.0         49386107  2021-02-22
# 2489  8999.0         49405897  2021-02-24
# 2491  8999.0         49595895  2021-03-15
# 2532  7999.0         49406579  2021-02-24
# 2537  7999.0         49602258  2021-03-16
# 2555  2799.0         49480378  2021-03-03
# 2687  3997.0         49459980  2021-03-01
# 2730  7699.0         49777611  2021-04-03
# 2744  8499.0         48438761  2020-12-04
# 2750  8499.0         48146024  2020-11-12
# 2829  5499.0         48750534  2020-12-29
# 2890  5999.0         49664266  2021-03-22
# 3023  3197.0         49816723  2021-04-07
# 3175  2599.0         49790626  2021-04-04
# 3225  2599.0         49756783  2021-04-01
# 3261  2099.0         49515093  2021-03-07
# 3300  1709.0         49679005  2021-03-24
# 3448  1999.0         49400578  2021-02-24
# 4244  7159.0         39705060  2019-03-06
# 5119  0.0            46619100  2020-06-11
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                          review_text  \
# 2474  NaN
# 2489  У этого телефона комбинированный слот,а вы пишите что нет..
# 2491  Телефон супер!!!!
# 2532  Вчера был в наличии сегодня уже нет!..
# 2537  Поверніть оплату частинами
# 2555  Сам телефон отличный, но.... Сегодня просто тупо выключился!!! Все!! Ни на зарядку( выключился именно на зарядке),ни на кнопки, не реагирует. Придется высылать в сервис....Он и до этого жил своей жизнью, при малейшем колебании начинал светится... Но это было терпимо, он хотя бы работал...
# 2687  Фантастически бесполезное устройство по простейшей причине: для открытия всех функций, вроде установки приложений из неизвестных источников, или разрешений, нужно зарегистрироваться в учётной записи Vivo, а это исчдие китайского ада принимает исключительно азиатские номера. Если кто-то сталкивался с этой проблемой и знает решение, буду очень благодарен.
# 2730  Телефон не плохой,не хватает датчика уведомления
# 2744  Не мешало бы цену вам пересмотреть , уважаемые менеджеры )) вы же мониторингом занимаетесь ? Или на сегодняшний день один из самых крупных интернет магазинов не может и не в состоянии дать своим клиентам если не лучшую цену , то хотя бы конкурентную или рыночную ?) Не впечатляет
# 2750  За такую цену телефон с кучей рекламы ??? Смешно
# 2829  Верните деньги аферисты полтора месяца жду!!! Последняя поокупка здесь!!!
# 2890  Телефон отличный, аккумулятор держит 2 дня, быстрый не зависает, сделан качественно
# 3023  Единственное что мне понравилось в этом телефоне, так это "разделение экрана", очень удобная и нужная штука как по мне. Больше нигде такое не встречал. 4 года прослужил, и то дети разбили, аккумулятор очень слабый.
# 3175  Ужасный смартфон не кому не советую!
# 3225  Телефон спочатку чудово працював але пройшов лиш рік з моменту покупки і сенсор перестав працювати(((
# 3261  Работой магазина розетка довольна а вот телефоном нет,очень тихий,слуховой динамик совсем тихий,не сразу заменили,брали на подарок,обратились в сервис и без результат 0,он у них полежал две недели и вернули назад,сервис ужасный.
# 3300  Спустя 4 мес. после покупки данного аппарата стал отключаться без ведомых причин. Еще через пару месяцев стал пропадать звук  при разговоре (перестал слышать собеседника и он меня), при перезагрузки все восстанавливалось. В итоге через полтора года эксплуатации перестала работать камера. Все проблемы этого телефона начали накапливаться как снежный ком в итоге я буду покупать новый. НИКОМУ НЕ РЕКОМЕНДУЮ ДАННУЮ МОДЕЛЬ К ПОКУПКЕ!
# 3448  Защитное стекло на экран 1шт . Перезвоню
# 4244  Что то странно за такие деньги он 4g не поддерживает.
# 5119  А это правда что смартфоны sony больше не будут поставляться в Украину.  Было бы очень жалко потерять такой иминитый бренд которые не слудеут на поводу новых трендов как чертова монобровь или камера по середине екрана.  Тем более новая линейка достаточно хорошая чтобы составить конкуренцию.
#
#       review_rating  thumbs_up  thumbs_down  \
# 2474 NaN             0          0
# 2489 NaN             1          0
# 2491 NaN             1          1
# 2532 NaN             0          1
# 2537 NaN             0          0
# 2555 NaN             0          0
# 2687 NaN             0          0
# 2730 NaN             0          0
# 2744 NaN             14         0
# 2750 NaN             7          5
# 2829 NaN             1          4
# 2890 NaN             0          0
# 3023 NaN             0          0
# 3175 NaN             0          0
# 3225 NaN             0          0
# 3261 NaN             0          0
# 3300 NaN             0          0
# 3448 NaN             0          0
# 4244 NaN             3          0
# 5119 NaN             24         1
#
#                            product_advatages  \
# 2474  NaN
# 2489  NaN
# 2491  Стерео звук, стабілізація відео.
# 2532  NaN
# 2537  NaN
# 2555  NaN
# 2687  Большинство характеристик
# 2730  NaN
# 2744  NaN
# 2750  NaN
# 2829  NaN
# 2890  Хороший аккумулятор, фото качественные
# 3023  NaN
# 3175  Нету
# 3225  NaN
# 3261  Симпатичный дизайн
# 3300  Дешёвый, отонсительно быстрый
# 3448  NaN
# 4244  За такие деньги особо не увидел.
# 5119  Sony
#
#                                                                                         product_disadvantages  \
# 2474  Самтелефоный тупой
# 2489  NaN
# 2491  Ціна...
# 2532  NaN
# 2537  NaN
# 2555  NaN
# 2687  Невозможность использовать все фунцчии, надоедливый китайский софт
# 2730  NaN
# 2744  NaN
# 2750  NaN
# 2829  NaN
# 2890  Не яркий экран на солнце
# 3023  NaN
# 3175  Плохая камера, ужасная производительность, лаги интерфейса и всех приложений, плохой акамулятор.
# 3225  NaN
# 3261  Очень плохие динамики,не рекомендую!
# 3300  Очень сильно стал глючить спустя год экусплуатации, проблемы появлялись по мере временного устаревания.
# 3448  NaN
# 4244  Судя по описанию 4 g не поддерживает.
# 5119  NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             full_text  \
# 2474  None Преймущества: None. Недостатки: Самтелефоный тупой
# 2489  У этого телефона комбинированный слот,а вы пишите что нет.. Преймущества: None. Недостатки: None
# 2491  Телефон супер!!!! Преймущества: Стерео звук, стабілізація відео.. Недостатки: Ціна...
# 2532  Вчера был в наличии сегодня уже нет!.. Преймущества: None. Недостатки: None
# 2537  Поверніть оплату частинами Преймущества: None. Недостатки: None
# 2555  Сам телефон отличный, но.... Сегодня просто тупо выключился!!! Все!! Ни на зарядку( выключился именно на зарядке),ни на кнопки, не реагирует. Придется высылать в сервис....Он и до этого жил своей жизнью, при малейшем колебании начинал светится... Но это было терпимо, он хотя бы работал... Преймущества: None. Недостатки: None
# 2687  Фантастически бесполезное устройство по простейшей причине: для открытия всех функций, вроде установки приложений из неизвестных источников, или разрешений, нужно зарегистрироваться в учётной записи Vivo, а это исчдие китайского ада принимает исключительно азиатские номера. Если кто-то сталкивался с этой проблемой и знает решение, буду очень благодарен. Преймущества: Большинство характеристик. Недостатки: Невозможность использовать все фунцчии, надоедливый китайский софт
# 2730  Телефон не плохой,не хватает датчика уведомления Преймущества: None. Недостатки: None
# 2744  Не мешало бы цену вам пересмотреть , уважаемые менеджеры )) вы же мониторингом занимаетесь ? Или на сегодняшний день один из самых крупных интернет магазинов не может и не в состоянии дать своим клиентам если не лучшую цену , то хотя бы конкурентную или рыночную ?) Не впечатляет Преймущества: None. Недостатки: None
# 2750  За такую цену телефон с кучей рекламы ??? Смешно Преймущества: None. Недостатки: None
# 2829  Верните деньги аферисты полтора месяца жду!!! Последняя поокупка здесь!!! Преймущества: None. Недостатки: None
# 2890  Телефон отличный, аккумулятор держит 2 дня, быстрый не зависает, сделан качественно Преймущества: Хороший аккумулятор, фото качественные. Недостатки: Не яркий экран на солнце
# 3023  Единственное что мне понравилось в этом телефоне, так это "разделение экрана", очень удобная и нужная штука как по мне. Больше нигде такое не встречал. 4 года прослужил, и то дети разбили, аккумулятор очень слабый. Преймущества: None. Недостатки: None
# 3175  Ужасный смартфон не кому не советую! Преймущества: Нету. Недостатки: Плохая камера, ужасная производительность, лаги интерфейса и всех приложений, плохой акамулятор.
# 3225  Телефон спочатку чудово працював але пройшов лиш рік з моменту покупки і сенсор перестав працювати((( Преймущества: None. Недостатки: None
# 3261  Работой магазина розетка довольна а вот телефоном нет,очень тихий,слуховой динамик совсем тихий,не сразу заменили,брали на подарок,обратились в сервис и без результат 0,он у них полежал две недели и вернули назад,сервис ужасный. Преймущества: Симпатичный дизайн. Недостатки: Очень плохие динамики,не рекомендую!
# 3300  Спустя 4 мес. после покупки данного аппарата стал отключаться без ведомых причин. Еще через пару месяцев стал пропадать звук  при разговоре (перестал слышать собеседника и он меня), при перезагрузки все восстанавливалось. В итоге через полтора года эксплуатации перестала работать камера. Все проблемы этого телефона начали накапливаться как снежный ком в итоге я буду покупать новый. НИКОМУ НЕ РЕКОМЕНДУЮ ДАННУЮ МОДЕЛЬ К ПОКУПКЕ! Преймущества: Дешёвый, отонсительно быстрый. Недостатки: Очень сильно стал глючить спустя год экусплуатации, проблемы появлялись по мере временного устаревания.
# 3448  Защитное стекло на экран 1шт . Перезвоню Преймущества: None. Недостатки: None
# 4244  Что то странно за такие деньги он 4g не поддерживает. Преймущества: За такие деньги особо не увидел.. Недостатки: Судя по описанию 4 g не поддерживает.
# 5119  А это правда что смартфоны sony больше не будут поставляться в Украину.  Было бы очень жалко потерять такой иминитый бренд которые не слудеут на поводу новых трендов как чертова монобровь или камера по середине екрана.  Тем более новая линейка достаточно хорошая чтобы составить конкуренцию. Преймущества: Sony. Недостатки: None
#
#      bert_prediction
# 2474  0
# 2489  1
# 2491  1
# 2532  1
# 2537  0
# 2555  1
# 2687  1
# 2730  1
# 2744  0
# 2750  1
# 2829  0
# 2890  1
# 3023  1
# 3175  0
# 3225  0
# 3261  0
# 3300  0
# 3448  1
# 4244  0
# 5119  1

# %% [markdown]
# After reviewing the results in the table above I would conclude that 4 predictions are wrong (all false positive) and sentiment for 1 review is hard to identify due to unclear and contradicting statements.
# Looking at wrong predictions I would note that it seems like the model tends to classify text with exclamation marks as positive sentiment while misclassified reviews from the table contained ‘!’ symbol and expressed negative sentiment.
#
# So if we don't include hard to classify reviews as wrong predictions, accuracy will be 80%.

# %% [markdown]
# ## Plot negative/positive sentiments for only reviews with rating and for all reviews (using predictions)

# %%
#Create Dataframe with column which will combine actual and predicted review sentiment 
data_to_pred['review_sentiment_actual_predicted'] = data_to_pred.bert_prediction
df_test_pred['review_sentiment_actual_predicted'] = df_test_pred.review_sentiment
df_train['review_sentiment_actual_predicted'] = df_train.review_sentiment
data_full = pd.concat([data_to_pred,df_test_pred,df_train])
data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5705 entries, 0 to 2249
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   comment_link                       5705 non-null   object
#  1   product_title                      5705 non-null   object
#  2   product_price                      5705 non-null   float64
#  3   review_id                          5705 non-null   int64
#  4   review_date                        5705 non-null   datetime64[ns]
#  5   review_text                        5593 non-null   object
#  6   review_rating                      3807 non-null   float64
#  7   thumbs_up                          5705 non-null   int64
#  8   thumbs_down                        5705 non-null   int64
#  9   product_advatages                  3732 non-null   object
#  10  product_disadvantages              3699 non-null   object
#  11  full_text                          5705 non-null   object
#  12  bert_prediction                    2660 non-null   object
#  13  review_sentiment_actual_predicted  5705 non-null   object
#  14  review_sentiment                   3807 non-null   object
#  15  0                                  3807 non-null   float64
#  16  1                                  3807 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(9)
# memory usage: 802.3+ KB
# <ipython-input-79-3eda46f96fc6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['review_sentiment_actual_predicted'] = df_train.review_sentiment

# %%
data_full.head(1)
# Out:
#                                                                                                  comment_link  \
# 0  https://rozetka.com.ua/ua/samsung_galaxy_s21_phantom_black_sm_g998bzkgsek/p272562736/comments/#id=49293156
#
#                                                                                                                  product_title  \
# 0   Мобільний телефон Samsung Galaxy S21 Ultra 12/256 GB Phantom Black (SM-G998BZKGSEK) + Сертифiкат на 4000 грн у подарунок!
#
#    product_price  review_id review_date  \
# 0  39999.0        49293156  2021-02-13
#
#                                                                                          review_text  \
# 0  Розетка, подскажите телефон без сканера лица и желательно без сканера отпечатков пальцев. Спасибо
#
#    review_rating  thumbs_up  thumbs_down product_advatages  \
# 0 NaN             0          1            NaN
#
#   product_disadvantages  \
# 0  NaN
#
#                                                                                                                                 full_text  \
# 0  Розетка, подскажите телефон без сканера лица и желательно без сканера отпечатков пальцев. Спасибо Преймущества: None. Недостатки: None
#
#   bert_prediction review_sentiment_actual_predicted review_sentiment   0   1
# 0  1               1                                 NaN             NaN NaN

# %%
#Plot sentiment of text only for records with rating
labels, frequencies = np.unique(data_full.dropna(subset = ['review_rating']).review_sentiment.values, return_counts = True)
plt.figure(figsize = (5,5))
labels = 'Negative','Positive'
plt.pie(frequencies,labels =labels, autopct = '%1.1f%%')
plt.title('Reviews by sentiment for reviews with rating')
plt.savefig('reviews_sentiment_calculated_from_review_rating.png', transparent=True)
plt.show()

# %%
#Plot sentiment of text for records with rating and recods with prediction
labels, frequencies = np.unique(data_full.review_sentiment_actual_predicted.values, return_counts = True)
plt.figure(figsize = (5,5))
labels = 'Negative','Positive'
plt.pie(frequencies,labels = labels, autopct = '%1.1f%%')
plt.title('Reviews by sentiment for all reviews')
plt.savefig('reviews_sentiment_calculated_from_review_rating_prediction.png', transparent=True)
plt.show()

# %% [markdown]
# *From the plots above we can see that the model predicts bigger fraction of negative sentiment reviews among records without filled rating in comparison to reviews with rating.
# If we compare data with only filled rating and all data (with predicted sentiment), we can see that fraction of positive sentiment reviews drops by 5.9% (from 76.8% to 70.9%).*
